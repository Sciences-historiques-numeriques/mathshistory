# %% [markdown]
# # Entity linking with Spacy plugins
#
# Use pip environment : cf. instructions.md
#
#
# * EntityLinker
# * Tapioca

# %%
import spacy
import psycopg2
import pandas as pd
from spacy.tokens import Span
from spacy import displacy
from time import strftime, gmtime

# %%
from itables import init_notebook_mode, show
import re
from importlib import reload

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import postgresql_functions as pgf
import settings as stt

# %%
# reload(pgf)

# %%
### connect to the local database
conn = psycopg2.connect(host="localhost", port = 5432, database="espace_intellectuel", 
                        user="postgres", password=stt.dbw)
#conn

# %%
#conn.close()

# %%
q1 = """
select pk_mathshistory, "name", url, dates, length(biography) as eff, coreferenced_txt, biography 
from mathshistory.mathshistory m 
where pk_mathshistory in (103, 117, 133, 159, 186);
"""

# %%
result = pgf.sql_explore(q1, conn)
# print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')

# %%
textes = pd.DataFrame(result[0])
textes.columns = ['id', 'name', 'url', 'dates', 'length_bio', 'coref_texte', 'biog']

# %%
textes.head()
# Out:
#     id                 name  \
# 0  103  Christopher Clavius
# 1  117      Michael Mästlin
# 2  133    Giuseppe Biancani
# 3  159    Wilhelm Schickard
# 4  186    Johannes Hevelius
#
#                                                  url      dates  length_bio  \
# 0  https://mathshistory.st-andrews.ac.uk/Biograph...  1538-1612       10616
# 1  https://mathshistory.st-andrews.ac.uk/Biograph...  1550-1631       10122
# 2  https://mathshistory.st-andrews.ac.uk/Biograph...  1566-1624       10035
# 3  https://mathshistory.st-andrews.ac.uk/Biograph...  1592-1635       10272
# 4  https://mathshistory.st-andrews.ac.uk/Biograph...  1611-1687       10856
#
#                                          coref_texte  \
# 0  Christopher Clavius was born in a German regio...
# 1  Michael Mästlin was born in Göppingen which wa...
# 2  Giuseppe Biancani's name also appears in name ...
# 3  Wilhelm Schickard's name is sometimes written ...
# 4  The first problem that we have to address is t...
#
#                                                 biog
# 0  Christopher Clavius was born in a German regio...
# 1  Michael Mästlin was born in Göppingen which wa...
# 2  Giuseppe Biancani's name also appears in its L...
# 3  Wilhelm Schickard's name is sometimes written ...
# 4  The first problem that we have to address is t...

# %%
### Choose one document
txt = textes.iloc[1].coref_texte #[:1600]
print(txt)
# Out:
# Michael Mästlin was born in Göppingen which was a village about 50 km east of Tübingen. Mästlin father, Jakob Mästlin, and Mästlin mother, Dorothea Simon, were both devout Lutherans and Michael was brought up in that faith and remained strongly committed to father throughout Mästlin life. Mästlin was the middle child of the family, having an older sister and a younger brother. Mästlin attended the monastic school in Königsbronn then, after Mästlin studies there, entered Tübingen University in 1568. [3]:-
# As was the case with many young scholars including Kepler, Mästlin most famous student, [Mästlin ] did Mästlin undergraduate studies at a preparatory school and came to the university to take Mästlin final exams and pick up Mästlin baccalaureate degree.At Tübingen University Mästlin studied mathematics and astronomy for a Master's degree under Philipp Apian who was Peter Apian's son. In 1570, while a student, Mästlin purchased a copy of Copernicus's De revolutionibus from the widow of Victorin Strigel, who had been professor of theology at Leipzig and the author of an astronomy text. Mästlin was awarded a Master 's degree with distinction in 1571. While studying for this degree Mästlin had edited a new edition of the Prutenis Tables which was published in 1571. The Prutenis Tables had been originally compiled by Erasmus Reinhold who had based 1571 on Copernicus's version of the solar system. After graduating, Mästlin spent the following years teaching in Tübingen, and at the same time took [3]:-
# ... the theological programme, because Tübingen University's primary mission wa

# %% [markdown]
# ## EntityLinker
#
# * https://spacy.io/api/entitylinker

# %%
nlp = spacy.load('en_core_web_lg')
nlp.add_pipe("entityLinker", last=True)

# %%
doc = nlp(txt)

# %%
all_linked_entities = doc._.linkedEntities
for sent in doc.sents:
    sent._.linkedEntities.pretty_print()

# %% [markdown]
# ## Tapioca

# %%
nlpt = spacy.blank('en')
nlpt.add_pipe('opentapioca')

# %%
doc = nlpt(txt)

# %%
for span in doc.ents:
    print((span.text, span.kb_id_, span.label_, span._.description, span._.score))
# Out:
# ('Michael Mästlin', 'Q75797', 'PERSON', ['German astronomer and mathematician'], 0.2854680000713362)
# ('Tübingen', 'Q3806', 'LOC', ['town in central Baden-Württemberg, Germany'], 0.17486283790026913)
# ('Lutherans', 'Q75809', 'ORG', ['form of Protestantism commonly associated with the teachings of Martin Luther'], 0.5236875221224303)
# ('baccalaureate degree', 'Q163727', 'ORGLOC', ['undergraduate academic degree lasting from three to seven years'], 0.9245065136261129)
# ('Philipp Apian', 'Q68523', 'PERSON', ['German mathematician and cartographer'], 0.8226047751456572)
# ('who', 'Q7817', 'ORG', ['specialized agency of the United Nations that is concerned with international public health'], 0.29657195961276084)
# ('Peter Apian', 'Q58662', 'PERSON', ['German astronomer, mathematician and cartographer'], 0.4184618420675229)
# ('Copernicus', 'Q619', 'PERSON', ['Polish mathematician and astronomer (1473–1543)'], 0.27609939171053066)
# ('De', 'Q183', 'LOC', ['country in Central Europe'], 0.9377298576625565)
# ('who', 'Q7817', 'ORG', ['specialized agency of the United Nations that is concerned with international public health'], 0.5048839392703942)
# ('Leipzig', 'Q2079', 'LOC', ['largest city in Saxony, Germany'], 0.42133095236296036)
# ('Erasmus Reinhold', 'Q544169', 'PERSON', ['German astronomer and mathematician'], 0.3157337224094091)
# ('who', 'Q7817', 'ORG', ['specialized agency of the United Nations that is concerned with international public health'], 0.07678731103919634)
# ('Copernicus', 'Q619', 'PERSON', ['Polish mathematician and astronomer (1473–1543)'], 0.24243810747189298)
# ('Tübingen', 'Q3806', 'LOC', ['town in central Baden-Württemberg, Germany'], 0.6835745999585295)
# ('Tübingen', 'Q3806', 'LOC', ['town in central Baden-Württemberg, Germany'], 0.23408993695401803)

# %% [markdown]
# * https://www.wikidata.org/wiki/Q544169

# %% [markdown]
# ## Test on a list of named entities

# %%
q2 = """
select regexp_replace(e_text, 'the |The ', '') e_name, e_label as e_class, count(*) as eff
from mathshistory.entity e 
where TRUE
and e_label in ('ORG', 'GPE')
--and e_text ~ 'Society'
group by regexp_replace(e_text, 'the |The ', ''), e_label 
order by eff desc;
"""

# %%
result = pgf.sql_explore(q2, conn)
print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')
# Out:
# Lines count: 28495, errors count: 0,
# First lines: [('Paris', 'GPE', 2593), ('United States', 'GPE', 1781), ('Germany', 'GPE', 1664), ('France', 'GPE', 1568), ('London', 'GPE', 1481)]

# %%
nam_en = pd.DataFrame(result[0])
nam_en.columns = ['e_name', 'e_class', 'eff']

# %%
nam_en.head()
# Out:
#           e_name e_class   eff
# 0          Paris     GPE  2593
# 1  United States     GPE  1781
# 2        Germany     GPE  1664
# 3         France     GPE  1568
# 4         London     GPE  1481

# %%
nam_en.groupby(by='e_class').size().sort_values(ascending=False)
# Out:
# e_class
# ORG    21125
# GPE     7370
# dtype: int64

# %%
# apply function on two columns 

def create_label(row):
    if row.e_class == 'GPE':
        label = row.e_name + ' is a geographical place'
    elif row.e_class == 'ORG':
        label = row.e_name + ' is an organization'
    else:
        label = row.e_name

    return label

# %%
nam_en['label'] = nam_en.apply(create_label, axis=1)
nam_en.head()
# Out:
#           e_name e_class   eff                                  label
# 0          Paris     GPE  2593          Paris is a geographical place
# 1  United States     GPE  1781  United States is a geographical place
# 2        Germany     GPE  1664        Germany is a geographical place
# 3         France     GPE  1568         France is a geographical place
# 4         London     GPE  1481         London is a geographical place

# %% [markdown]
# ### Test with Tapioca

# %%
doc = nlpt(', '.join(list(nam_en.label)[:30]))

# %%
entities = [span for span in doc.ents]

for e in entities:
    print((e.text, e.kb_id_, e.label_, e._.description, e._.score))
# Out:
# ('Paris', 'Q90', 'LOC', ['capital and largest city of France'], 0.1214906373005522)
# ('United States', 'Q30', 'LOC', ['country in North America'], 1.0127116327362797)
# ('Germany', 'Q183', 'LOC', ['country in Central Europe'], 0.7112720552567512)
# ('France', 'Q142', 'LOC', ['country in Western Europe'], 1.3557242937411331)
# ('London', 'Q84', 'LOC', ['capital and largest city of the United Kingdom'], 1.2238206631655175)
# ('England', 'Q21', 'LOC', ['country in north-west Europe, part of the United Kingdom'], 0.7924021860505607)
# ('Cambridge', 'Q350', 'LOC', ['city in Cambridgeshire, England'], 0.4328834914830876)
# ('Berlin', 'Q64', 'LOC', ['federal state, capital and largest city of Germany'], 0.680059181539742)
# ('Cambridge', 'Q350', 'LOC', ['city in Cambridgeshire, England'], 0.4206936526319923)
# ('Italy', 'Q38', 'LOC', ['country in Southern Europe'], 0.5552404961659491)
# ('Rome', 'Q220', 'LOC', ['capital and largest city of Italy'], 0.8699414931328439)
# ('New York', 'Q60', 'LOC', ['most populous city in the United States of America'], 0.5174878372682846)
# ('Royal Society', 'Q123885', 'ORG', ['English learned society for science'], 0.32954903906260136)
# ('Poland', 'Q36', 'LOC', ['country in Central Europe'], 0.5735104442533655)
# ('Moscow', 'Q649', 'LOC', ['capital and most populous city of Russia'], 1.161915443188299)
# ('Russia', 'Q159', 'ORGLOC', ['former empire in Eurasia (1721–1917) and North America (1721–1867)'], 0.4242091542158647)
# ('Vienna', 'Q1741', 'LOC', ['capital of and state in Austria'], 0.3382602663230495)
# ('American Mathematical Society', 'Q465654', 'ORG', ['association of professional mathematicians'], 0.7861161502633417)
# ('École Polytechnique', 'Q273626', 'ORG', ['French institution of higher education and research in Palaiseau'], 1.0232802801585854)
# ('Scotland', 'Q22', 'LOC', ['constituent country of the United Kingdom'], 0.13864404340338543)

# %% [markdown]
# ### Test with entityLinker

# %%
doc = nlp(', '.join(list(nam_en.label)[:30]))

# %%
all_linked_entities = doc._.linkedEntities
for sent in doc.sents:
    sent._.linkedEntities.pretty_print()
# Out:
# <EntityElement: https://www.wikidata.org/wiki/Q90 Paris                     capital and largest city of France                >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q30 United States of America  federal republic in North America                 >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q142 France                    republic with mainland in Europe and numerous oversea territories>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q84 London                    capital and largest city of the United Kingdom    >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q21 England                   country in north-west Europe, part of the United Kingdom>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q35794 University of Cambridge   collegiate public research university in Cambridge, England, United Kingdom>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q64 Berlin                    capital and largest city of Germany               >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q35794 University of Cambridge   collegiate public research university in Cambridge, England, United Kingdom>
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q21578 Princeton University      private Ivy League research university in Princeton, New Jersey, United States>
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q38 Italy                     Republic in Southern Europe, member of the European Union>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q3033 Göttingen                 Large city in Lower Saxony, Germany               >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q220 Rome                      capital and largest city of Italy                 >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q664773 Society                   1989 American horror film directed by Brian Yuzna >
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q60 New York City             city in state of New York, largest city in the United States by population>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q2422019 College                   episode of The Sopranos (S1 E5)                   >
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q23436 Edinburgh                 capital city of Scotland, UK                      >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q123885 Royal Society             English learned society for science               >
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q36 Poland                    republic in Central Europe                        >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q649 Moscow                    capital city and the largest city of Russia; separate federal subject of Russia>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q159 Russia                    transcontinental country in Eastern Europe and Northern Asia>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q13371 Harvard University        private research university in Cambridge, Massachusetts, United States>
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q4780357 Apollo Theatre            former Broadway theatre in Manhattan, New York City>
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q1741 Vienna                    capital and one of nine States of Austria         >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q465654 American Mathematical Society association of professional mathematicians        >
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q273626 École Polytechnique       French institution of higher education and research in Palaiseau>
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q7894492 University                episode of The Sopranos (S3 E6)                   >
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q72 Zürich                    capital of the canton of Zürich, Switzerland      >
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>
# <EntityElement: https://www.wikidata.org/wiki/Q34433 University of Oxford      university in Oxfordshire, UK                     >
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q22 Scotland                  country in Northwest Europe, part of the United Kingdom>
# <EntityElement: https://www.wikidata.org/wiki/Q82794 geographic region         2D or 3D defined space, mainly in terrestrial and astrophysics sciences>

# %%
ent = doc._.linkedEntities[0]
ent
# Out:
# <EntityElement: https://www.wikidata.org/wiki/Q90 Paris                     capital and largest city of France                >

# %%
print(ent.get_span(), ent.get_label(), 'https://www.wikidata.org/wiki/Q' + str(ent.get_id()), ent.get_description())
# Out:
# Paris Paris https://www.wikidata.org/wiki/Q90 capital and largest city of France

# %%
en_linked = []
for ent in doc._.linkedEntities:
    en_linked.append([str(ent.get_span()), ent.get_label(), 'https://www.wikidata.org/wiki/Q' + str(ent.get_id()), ent.get_description()])
len(en_linked)
# Out:
# 60

# %%
df_en_linked = pd.DataFrame(en_linked)
df_en_linked. columns = ['label_loc', 'label_wkd', 'URI_Wkd', 'definition']
df_en_linked.head()
# Out:
#        label_loc                 label_wkd  \
# 0          Paris                     Paris
# 1          place         geographic region
# 2  United States  United States of America
# 3          place         geographic region
# 4        Germany                   Germany
#
#                                 URI_Wkd  \
# 0     https://www.wikidata.org/wiki/Q90
# 1  https://www.wikidata.org/wiki/Q82794
# 2     https://www.wikidata.org/wiki/Q30
# 3  https://www.wikidata.org/wiki/Q82794
# 4    https://www.wikidata.org/wiki/Q183
#
#                                           definition
# 0                 capital and largest city of France
# 1  2D or 3D defined space, mainly in terrestrial ...
# 2                  federal republic in North America
# 3  2D or 3D defined space, mainly in terrestrial ...
# 4  federal parliamentary republic in central-west...

# %%
nam_en_linked = pd.merge(nam_en, df_en_linked, how="left", left_on="e_name", right_on="label_loc", copy=True)

# %%
nam_en_linked.head(10)
# Out:
#           e_name e_class   eff                                  label  \
# 0          Paris     GPE  2593          Paris is a geographical place
# 1  United States     GPE  1781  United States is a geographical place
# 2        Germany     GPE  1664        Germany is a geographical place
# 3         France     GPE  1568         France is a geographical place
# 4         London     GPE  1481         London is a geographical place
# 5        England     GPE  1309        England is a geographical place
# 6      Cambridge     GPE  1236      Cambridge is a geographical place
# 7      Cambridge     GPE  1236      Cambridge is a geographical place
# 8         Berlin     GPE  1182         Berlin is a geographical place
# 9      Cambridge     ORG  1051           Cambridge is an organization
#
#        label_loc                 label_wkd  \
# 0          Paris                     Paris
# 1  United States  United States of America
# 2        Germany                   Germany
# 3         France                    France
# 4         London                    London
# 5        England                   England
# 6      Cambridge   University of Cambridge
# 7      Cambridge   University of Cambridge
# 8         Berlin                    Berlin
# 9      Cambridge   University of Cambridge
#
#                                 URI_Wkd  \
# 0     https://www.wikidata.org/wiki/Q90
# 1     https://www.wikidata.org/wiki/Q30
# 2    https://www.wikidata.org/wiki/Q183
# 3    https://www.wikidata.org/wiki/Q142
# 4     https://www.wikidata.org/wiki/Q84
# 5     https://www.wikidata.org/wiki/Q21
# 6  https://www.wikidata.org/wiki/Q35794
# 7  https://www.wikidata.org/wiki/Q35794
# 8     https://www.wikidata.org/wiki/Q64
# 9  https://www.wikidata.org/wiki/Q35794
#
#                                           definition
# 0                 capital and largest city of France
# 1                  federal republic in North America
# 2  federal parliamentary republic in central-west...
# 3  republic with mainland in Europe and numerous ...
# 4     capital and largest city of the United Kingdom
# 5  country in north-west Europe, part of the Unit...
# 6  collegiate public research university in Cambr...
# 7  collegiate public research university in Cambr...
# 8                capital and largest city of Germany
# 9  collegiate public research university in Cambr...

# %% [markdown]
# ## Use entities list

# %%
doc = nlp(', '.join(list(nam_en.label)[:30]))

# %%
en_linked = []
for span in doc.ents:
    en_linked.append([span.text, span.kb_id_, span.label_, span._.description, span._.score])
len(en_linked)
# Out:
# 20

# %%
df_en_linked = pd.DataFrame(en_linked)
df_en_linked. columns = ['label', 'Wiki_Q', 'class', 'definitions', 'matching_score']
df_en_linked.head()
# Out:
#            label Wiki_Q class  \
# 0          Paris    Q90   LOC
# 1  United States    Q30   LOC
# 2        Germany   Q183   LOC
# 3         France   Q142   LOC
# 4         London    Q84   LOC
#
#                                         definitions  matching_score
# 0              [capital and largest city of France]        0.121491
# 1                        [country in North America]        1.012712
# 2                       [country in Central Europe]        0.711272
# 3                       [country in Western Europe]        1.355724
# 4  [capital and largest city of the United Kingdom]        1.223821

# %%
nam_en_linked = pd.merge(nam_en, df_en_linked, how="left", left_on="e_name", right_on="label", copy=True)

# %%
nam_en_linked.head(50)
# Out:
#                            e_name e_class   eff  \
# 0                           Paris     GPE  2593
# 1                   United States     GPE  1781
# 2                         Germany     GPE  1664
# 3                          France     GPE  1568
# 4                          London     GPE  1481
# 5                         England     GPE  1309
# 6                       Cambridge     GPE  1236
# 7                       Cambridge     GPE  1236
# 8                          Berlin     GPE  1182
# 9                       Cambridge     ORG  1051
# 10                      Cambridge     ORG  1051
# 11                      Princeton     ORG   946
# 12                          Italy     GPE   903
# 13                      Göttingen     GPE   887
# 14                           Rome     GPE   782
# 15                        Society     ORG   744
# 16                       New York     GPE   723
# 17                        College     ORG   662
# 18                      Edinburgh     GPE   635
# 19                  Royal Society     ORG   623
# 20                         Poland     GPE   609
# 21                         Moscow     GPE   562
# 22                         Russia     GPE   561
# 23                        Harvard     ORG   544
# 24                        Academy     ORG   539
# 25                         Vienna     GPE   521
# 26  American Mathematical Society     ORG   493
# 27            École Polytechnique     ORG   487
# 28                     University     ORG   468
# 29                         Zürich     GPE   463
# 30                         Oxford     ORG   457
# 31                       Scotland     GPE   414
# 32                         Oxford     GPE   396
# 33   Institute for Advanced Study     ORG   367
# 34                        Bologna     GPE   363
# 35                         Warsaw     GPE   356
# 36                      Institute     ORG   350
# 37                        Hungary     GPE   348
# 38                          India     GPE   331
# 39                         Dublin     GPE   323
# 40                Trinity College     ORG   319
# 41                  St Petersburg     GPE   312
# 42          University of Chicago     ORG   309
# 43      Department of Mathematics     ORG   309
# 44                          Spain     GPE   308
# 45           University of Berlin     ORG   297
# 46                       Budapest     GPE   294
# 47                        Britain     GPE   287
# 48                         Canada     GPE   286
# 49                         Prague     GPE   284
#
#                                              label_x  \
# 0                      Paris is a geographical place
# 1              United States is a geographical place
# 2                    Germany is a geographical place
# 3                     France is a geographical place
# 4                     London is a geographical place
# 5                    England is a geographical place
# 6                  Cambridge is a geographical place
# 7                  Cambridge is a geographical place
# 8                     Berlin is a geographical place
# 9                       Cambridge is an organization
# 10                      Cambridge is an organization
# 11                      Princeton is an organization
# 12                     Italy is a geographical place
# 13                 Göttingen is a geographical place
# 14                      Rome is a geographical place
# 15                        Society is an organization
# 16                  New York is a geographical place
# 17                        College is an organization
# 18                 Edinburgh is a geographical place
# 19                  Royal Society is an organization
# 20                    Poland is a geographical place
# 21                    Moscow is a geographical place
# 22                    Russia is a geographical place
# 23                        Harvard is an organization
# 24                        Academy is an organization
# 25                    Vienna is a geographical place
# 26  American Mathematical Society is an organization
# 27            École Polytechnique is an organization
# 28                     University is an organization
# 29                    Zürich is a geographical place
# 30                         Oxford is an organization
# 31                  Scotland is a geographical place
# 32                    Oxford is a geographical place
# 33   Institute for Advanced Study is an organization
# 34                   Bologna is a geographical place
# 35                    Warsaw is a geographical place
# 36                      Institute is an organization
# 37                   Hungary is a geographical place
# 38                     India is a geographical place
# 39                    Dublin is a geographical place
# 40                Trinity College is an organization
# 41             St Petersburg is a geographical place
# 42          University of Chicago is an organization
# 43      Department of Mathematics is an organization
# 44                     Spain is a geographical place
# 45           University of Berlin is an organization
# 46                  Budapest is a geographical place
# 47                   Britain is a geographical place
# 48                    Canada is a geographical place
# 49                    Prague is a geographical place
#
#                           label_y   Wiki_Q   class  \
# 0                           Paris      Q90     LOC
# 1                   United States      Q30     LOC
# 2                         Germany     Q183     LOC
# 3                          France     Q142     LOC
# 4                          London      Q84     LOC
# 5                         England      Q21     LOC
# 6                       Cambridge     Q350     LOC
# 7                       Cambridge     Q350     LOC
# 8                          Berlin      Q64     LOC
# 9                       Cambridge     Q350     LOC
# 10                      Cambridge     Q350     LOC
# 11                            NaN      NaN     NaN
# 12                          Italy      Q38     LOC
# 13                            NaN      NaN     NaN
# 14                           Rome     Q220     LOC
# 15                            NaN      NaN     NaN
# 16                       New York      Q60     LOC
# 17                            NaN      NaN     NaN
# 18                            NaN      NaN     NaN
# 19                  Royal Society  Q123885     ORG
# 20                         Poland      Q36     LOC
# 21                         Moscow     Q649     LOC
# 22                         Russia     Q159  ORGLOC
# 23                            NaN      NaN     NaN
# 24                            NaN      NaN     NaN
# 25                         Vienna    Q1741     LOC
# 26  American Mathematical Society  Q465654     ORG
# 27            École Polytechnique  Q273626     ORG
# 28                            NaN      NaN     NaN
# 29                            NaN      NaN     NaN
# 30                            NaN      NaN     NaN
# 31                       Scotland      Q22     LOC
# 32                            NaN      NaN     NaN
# 33                            NaN      NaN     NaN
# 34                            NaN      NaN     NaN
# 35                            NaN      NaN     NaN
# 36                            NaN      NaN     NaN
# 37                            NaN      NaN     NaN
# 38                            NaN      NaN     NaN
# 39                            NaN      NaN     NaN
# 40                            NaN      NaN     NaN
# 41                            NaN      NaN     NaN
# 42                            NaN      NaN     NaN
# 43                            NaN      NaN     NaN
# 44                            NaN      NaN     NaN
# 45                            NaN      NaN     NaN
# 46                            NaN      NaN     NaN
# 47                            NaN      NaN     NaN
# 48                            NaN      NaN     NaN
# 49                            NaN      NaN     NaN
#
#                                           definitions  matching_score
# 0                [capital and largest city of France]        0.121491
# 1                          [country in North America]        1.012712
# 2                         [country in Central Europe]        0.711272
# 3                         [country in Western Europe]        1.355724
# 4    [capital and largest city of the United Kingdom]        1.223821
# 5   [country in north-west Europe, part of the Uni...        0.792402
# 6                   [city in Cambridgeshire, England]        0.432883
# 7                   [city in Cambridgeshire, England]        0.420694
# 8   [federal state, capital and largest city of Ge...        0.680059
# 9                   [city in Cambridgeshire, England]        0.432883
# 10                  [city in Cambridgeshire, England]        0.420694
# 11                                                NaN             NaN
# 12                       [country in Southern Europe]        0.555240
# 13                                                NaN             NaN
# 14                [capital and largest city of Italy]        0.869941
# 15                                                NaN             NaN
# 16  [most populous city in the United States of Am...        0.517488
# 17                                                NaN             NaN
# 18                                                NaN             NaN
# 19              [English learned society for science]        0.329549
# 20                        [country in Central Europe]        0.573510
# 21         [capital and most populous city of Russia]        1.161915
# 22  [former empire in Eurasia (1721–1917) and Nort...        0.424209
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                  [capital of and state in Austria]        0.338260
# 26       [association of professional mathematicians]        0.786116
# 27  [French institution of higher education and re...        1.023280
# 28                                                NaN             NaN
# 29                                                NaN             NaN
# 30                                                NaN             NaN
# 31        [constituent country of the United Kingdom]        0.138644
# 32                                                NaN             NaN
# 33                                                NaN             NaN
# 34                                                NaN             NaN
# 35                                                NaN             NaN
# 36                                                NaN             NaN
# 37                                                NaN             NaN
# 38                                                NaN             NaN
# 39                                                NaN             NaN
# 40                                                NaN             NaN
# 41                                                NaN             NaN
# 42                                                NaN             NaN
# 43                                                NaN             NaN
# 44                                                NaN             NaN
# 45                                                NaN             NaN
# 46                                                NaN             NaN
# 47                                                NaN             NaN
# 48                                                NaN             NaN
# 49                                                NaN             NaN
