# %% [markdown]
# # Link biographies with URIs
#
# * Find URIs of resources in DBPedia etc. corresponding to the persons metioned in the biographies

# %%
### Importation de modules
#import requests
import psycopg2
from psycopg2.extras import execute_batch
# import lxml.html
# from lxml import etree
from importlib import reload
from matplotlib import pyplot as plt
import sqlite3 as sql
import settings as st
import pandas as pd
import re
import csv
from itables import init_notebook_mode, show

# %%
### itables : activation facultative avec la fonction show()
init_notebook_mode(all_interactive=False)
# Out:
# <script>
#   // Create a pending promise immediately (this script is not deferred).
#   window.dataTablePromise = new Promise((resolve) => {
#     window.__resolveDataTablePromise__ = resolve;
#   });
# </script>
# <script type="module">
#   // Module scripts are automatically deferred, so this code will not execute immediately.
#   // See https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Modules#other_differences_between_modules_and_standard_scripts
#   if ($.prototype.DataTable === undefined) {
#       const dt = (await import("data:text/javascript;base64,...")).default;
#       dt(window.$);
#       // Resolve the pending promise above, indicating that DataTable is now ready to be used.
#       window.__resolveDataTablePromise__();
#   }
# </script>
# <style>table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{height:1em;width:1em;margin-top:-9px;display:inline-block;color:white;border:.15em solid white;border-radius:1em;box-shadow:0 0 .2em #444;box-sizing:content-box;text-align:center;text-indent:0 !important;font-family:"Courier New",Courier,monospace;line-height:1em;content:"+";background-color:#31b131}table.dataTable tr.dt-hasChild td.dt-control:before{content:"-";background-color:#d33333}table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc,table.dataTable thead>tr>th.sorting_asc_disabled,table.dataTable thead>tr>th.sorting_desc_disabled,table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>td.sorting_asc_disabled,table.dataTable thead>tr>td.sorting_desc_disabled{cursor:pointer;position:relative;padding-right:26px}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after{position:absolute;display:block;opacity:.125;right:10px;line-height:9px;font-size:.8em}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:before{bottom:50%;content:"▲"}table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:after{top:50%;content:"▼"}table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:after{opacity:.6}table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting_asc_disabled:before{display:none}table.dataTable thead>tr>th:active,table.dataTable thead>tr>td:active{outline:none}div.dataTables_scrollBody table.dataTable thead>tr>th:before,div.dataTables_scrollBody table.dataTable thead>tr>th:after,div.dataTables_scrollBody table.dataTable thead>tr>td:before,div.dataTables_scrollBody table.dataTable thead>tr>td:after{display:none}div.dataTables_processing{position:absolute;top:50%;left:50%;width:200px;margin-left:-100px;margin-top:-26px;text-align:center; ...

# %%
from SPARQLWrapper import SPARQLWrapper, SPARQLWrapper2, JSON, TURTLE, XML, RDFXML

# %%
import sparql_functions as spqf

# %%
reload(spqf)
# Out:
# <module 'sparql_functions' from '/home/francesco/shared_files/python_notebooks/Early-Modern-Astronomy/mathshistory/sparql_functions.py'>

# %% [markdown]
# ## Explore mathematician's list

# %% [markdown]
# ## PostgreSQL

# %% [markdown]
# ## Documentation
#
# * https://www.psycopg.org/docs/usage.html
# * https://towardsdatascience.com/python-and-postgresql-how-to-access-a-postgresql-database-like-a-data-scientist-b5a9c5a0ea43
#   * noter toutefois que la connection directe avec psychopg2 et pandas ne marche plus
#
# __NB__
# * soit on passe par du SQL pur, et alors on peut utiliser _psycopg2_ comme on utilise sqlite3
# * soit on utilise Pandas, mais là il faut un objet SQLAlchemy pour accéder à la base de données

# %%
conn = psycopg2.connect(host="localhost", port = 5432, database="espace_intellectuel", 
                        user="postgres", password=st.dbw)

# %%
conn.close()

# %% [markdown]
# astronomers.mathshistory :
#
# pk_mathshistory serial PRIMARY KEY,<br/>
# name varchar NOT NULL,<br/>
# dates varchar,<br/>
# url varchar,<br/>
# short_name varchar,<br/>
# page_html xml,<br/>
# page_html_txt text,<br/>
# notes text,<br/>
# ts_creation timestamp

# %% [markdown]
# ## Find DBPedia's persons' URIs

# %% [markdown]
# ### Get persons list from database

# %%
q2 = """
select pk_mathshistory, "name", substring(dates, 1, 4)::INT as birth_date
from mathshistory.mathshistory m 
order by birth_date
"""

# %%
### Get the list of persons with birth year
with conn.cursor() as curs:
    curs.execute(q2)
    rs = curs.fetchall()

# %%
rs[100:103]
# Out:
# [(101, 'Egnatio Danti', 1536),
#  (102, 'Francesco Barozzi', 1537),
#  (103, 'Christopher Clavius', 1538)]

# %% [markdown]
# ### Prepare SPARQL query

# %% [markdown]
# #### DBPedia text search syntax
#
# * https://docs.openlinksw.com/virtuoso/textexprsyntax/
# * Search string here: https://dbpedia.org/fct/ (e.g. Mästlin or Hérigone)
#   * https://dbpedia.org/fct/facet.vsp?cmd=text&sid=11757
#   * Then click on View query as SPARQL
#
#
# This syntax seems to work:
#
#  * ?label bif:contains '("pierre" AND "Hérigone")'
#  * the language is to restrictive, I commented the line

# %%
endpoint = "https://dbpedia.org/sparql"

# %%
q1 = """
SELECT DISTINCT ?s ?label ( substr(str(?date), 1, 4)  as ?birthYear) ?dct 
WHERE {
            # ?s a dbo:Person;
                   rdfs:label ?label . 
     OPTIONAL {?s   dbo:birthDate|dbp:birthDate ?date.}
      OPTIONAL { ?s dcterms:subject ?dct.
      FILTER (contains(str(?dct), 'births'))
}
            FILTER (lang(?label) = 'en'). 
            # ?label bif:contains "'Francesco Barozzi'"
}
"""

# %%
rs[:3]
# Out:
# [(2, 'Jia Xian', 1010),
#  (1, 'al-Nasawi', 1010),
#  (3, 'Hermann of Reichenau', 1013)]

# %%
### Execute the SPARQL query
qr = spqf.get_json_sparql_result(endpoint,q1)

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:50]
# Out:
# 2
# [['http://dbpedia.org/resource/Francesco_Barozzi',
#   'Francesco Barozzi',
#   '',
#   'http://dbpedia.org/resource/Category:1537_births'],
#  ['http://dbpedia.org/resource/Francesco_Barozzi_(bishop)',
#   'Francesco Barozzi (bishop)',
#   '',
#   '']]

# %%
type(r[:50])
# Out:
# list

# %%
for t_pers in rs[:3]:
    
    p = list(t_pers)
    parts = p[1].replace("'", ' ')\
                .replace('-', ' ').replace('  ', ' ').split(' ')
    pp = [part for part in parts if len(part) > 2]
    ppt = '"'+ '" AND "'.join(pp) + '"'
    print(ppt)
# Out:
# "Jia" AND "Xian"
# "Nasawi"
# "Hermann" AND "Reichenau"

# %% [markdown]
# ### Find mathematicians in DBPedia
#
# This SPARQL query leverages the Virtuoso full text query syntax of DBPedia

# %%
l = ['pk_mathshistory', 'name', 'birthDate', 'error']
### Commented to avoid emptying logs
# with open("data/logs_1_bis.csv", "w") as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(l)

# %%
### This script retrieves the DBPedia persons using the name
q_result= []
for t_pers in rs:
    
    p = list(t_pers)
    
    parts = p[1].replace("'", ' ')\
                .replace('-', ' ').replace('  ', ' ').split(' ')
    pp = [part for part in parts if len(part) > 2]
    ppt = '"'+ '" AND "'.join(pp) + '"'
    
    q = """
        SELECT DISTINCT ?s ?label ( substr(str(?date), 1, 4)  as ?birthYear) ?dct 
        WHERE {
                    # ?s a dbo:Person;
                           rdfs:label ?label . 
             OPTIONAL {?s   dbo:birthDate|dbp:birthDate ?date.}
              OPTIONAL { ?s dcterms:subject ?dct.
              FILTER (contains(str(?dct), 'births'))
        }
                    ### This filter was omitted in order to raise the recall
                    # FILTER (lang(?label) = 'en'). 
                    # ?label bif:contains '(""" + ppt + """)'
        }
        """

    
    try:
        sparql = SPARQLWrapper(endpoint)
        sparql.setQuery(q)
        sparql.setReturnFormat(JSON)
        sparql.setMethod('POST')
        qr = sparql.queryAndConvert()
        r = [l for l in spqf.sparql_result_to_list(qr)]
        q_result.append(p + [r[:20]])
    except Exception as e:
        
        print(e)

        ttt = p + [str(e)]
        with open("data/logs_1.csv", "a") as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
            wr.writerow(ttt)

# %%
### All rows where treated without errors
len(q_result), q_result[:5]
# Out:
# (3010,
#  [[2,
#    'Jia Xian',
#    1010,
#    [['http://dbpedia.org/resource/Jia_Xian', 'Jia Xian', '', ''],
#     ['http://dbpedia.org/resource/Jia_Xian', 'Jia Xian', '', ''],
#     ['http://dbpedia.org/resource/Jia_Xian', 'Jia Xian', '', ''],
#     ['http://dbpedia.org/resource/Jia_Xian', 'Jia Xian', '', ''],
#     ['http://dbpedia.org/resource/Jia_Xian', 'Jia Xian', '', '']]],
#   [1,
#    'al-Nasawi',
#    1010,
#    [['http://dbpedia.org/resource/Alī_ibn_Ahmad_al-Nasawī',
#      'Ali ibn Ahmad al-Nasawi',
#      '',
#      'http://dbpedia.org/resource/Category:1010s_births'],
#     ['http://dbpedia.org/resource/Shihab_al-Din_Muhammad_al-Nasawi',
#      'Shihab al-Din Muhammad al-Nasawi',
#      '',
#      '']]],
#   [3,
#    'Hermann of Reichenau',
#    1013,
#    [['http://dbpedia.org/resource/Hermann_of_Reichenau',
#      'Hermann of Reichenau',
#      '1013',
#      'http://dbpedia.org/resource/Category:1013_births'],
#     ['http://dbpedia.org/resource/Hermann_of_Reichenau',
#      'Hermann de Reichenau',
#      '1013',
#      'http://dbpedia.org/resource/Category:1013_births'],
#     ['http://dbpedia.org/resource/Hermann_of_Reichenau',
#      'Hermann von Reichenau',
#      '1013',
#      'http://dbpedia.org/resource/Category:1013_births'],
#     ['http://dbpedia.org/resource/Hermann_of_Reichenau',
#      'Hermann av Reichenau',
#      '1013',
#      'http://dbpedia.org/resource/Category:1013_births'],
#     ['http://dbpedia.org/resource/Hermann_of_Reichenau',
#      'Hermann von Reichenau',
#      '1013',
#      'http://dbpedia.org/resource/Category:1013_births']]],
#   [4,
#    'Sripati',
#    1019,
#    [['http://dbpedia.org/resource/Sripati_Mishra',
#      'Sripati Mishra',
#      '1923',
#      'http://dbpedia.org/resource/Category:1923_births'],
#     ['http://dbpedia.org/resource/Sripati_Chandrasekhar',
#      'Sripati Chandrasekhar',
#      '',
#      'http://dbpedia.org/resource/Category:1918_births']]],
#   [5,
#    'al-Zarqali',
#    1029,
#    [['http://dbpedia.org/resource/Abū_Isḥāq_Ibrāhīm_al-Zarqālī',
#      'Az-Zarqali',
#      '1029',
#      'http://dbpedia.org/resource/Category:1029_births'],
#     ['http://dbpedia.org/resource/Abū_Isḥāq_Ibrāhīm_al-Zarqālī',
#      'Az-Zarqali',
#      '1029',
#      'http://dbpedia.org/resource/Category:1029_births'],
#     ['http://dbpedia.org/resource/Abū_Isḥāq_Ibrāhīm_al-Zarqālī',
#      'Al-Zarqali',
#      '1029',
#      'http://dbpedia.org/resource/Category:1029_births'],
#     ['http://dbpedia.org/resource/Abū_Isḥāq_Ibrāhīm_al-Zarqālī',
#      'Al-Zarqali',
#      '1029',
#      'http://dbpedia.org/resource/Category:1029_births']]]])

# %% [markdown]
# [27 June 2023] no errors in logs, 3010 results

# %% [markdown]
# ### Identify persons using the year of birth
#
# N.B. There are multiple rows in the SPARQL result because of the multiple languages. The 'en' language filter was omittet in order to raise recall
#
# The next cell will reduce the redundant URIs

# %%
l_match = []
l_no_match_alternative = []
l_no_match = []
for r in q_result:  #[:20]:
    
    lm = []
    if len(r[3]) > 0:
        # for each element in the DBPedia answer
        for e in r[3]:
            
            # take the date if it exists
            if e[2]:
                d3 = e[2]
                try:
                    ## add a span of 2 years before or after
                    if ((r[2] <= int(d3) + 2 ) and (r[2] >= int(d3) - 2 )):
                        lm =[r[0],r[1],r[2], d3, e[1], e[0]]
                        l_match.append(lm)
                except Exception as e:
                    print(r[0],r[1],r[2],e)
            if len(lm) > 0:
                break

        if len(lm) == 0:
            l_no_match_alternative.append(r)
    else:
        l_no_match.append(r)

# %% [markdown]
# #### Matches
#
# 1761 matches

# %%
len(l_match), l_match[99:102]
# Out:
# (1761,
#  [[244,
#    'Gottfried Leibniz',
#    1646,
#    '1646',
#    'Gottfried Wilhelm Leibniz',
#    'http://dbpedia.org/resource/Gottfried_Wilhelm_Leibniz'],
#   [246,
#    'Denis Papin',
#    1647,
#    '1647',
#    'Denis Papin',
#    'http://dbpedia.org/resource/Denis_Papin'],
#   [248,
#    'Giovanni Ceva',
#    1647,
#    '1647',
#    'Giovanni Ceva',
#    'http://dbpedia.org/resource/Giovanni_Ceva']])

# %% [markdown]
# #### Persons with no query answer (no match in SPARQL query result)
#
# 558 without any match

# %%
len(l_no_match), l_no_match[30:35]
# Out:
# (558,
#  [[188, 'Andrea Tacquet', 1612, []],
#   [202, 'Nicolaus Mercator', 1620, []],
#   [211, 'Stephano degli Angeli', 1623, []],
#   [218, 'Pietro Mengoli', 1626, []],
#   [221, 'Johann Hudde', 1628, []]])

# %%
df_no_match = pd.DataFrame([e[:3] for e in l_no_match])
df_no_match.columns = ['pk_mathshistory', 'name_year_mathshistory', 'birth_year_mathshistory']
df_no_match.head()
# Out:
#    pk_mathshistory name_year_mathshistory  birth_year_mathshistory
# 0                6               Shen Kua                     1031
# 1               12         Rabbi Ben Ezra                     1092
# 2               15                Gherard                     1114
# 3               17  Sharaf al-Din al-Tusi                     1135
# 4               18   Reinher of Paderborn                     1140

# %%
### Persons with no query answer
fp = "data/df_no_match_dbpedia.csv"
df_no_match.to_csv(fp)

# %% [markdown]
# #### Persons with query answer and match using birthy year

# %%
df_match = pd.DataFrame(l_match)
df_match.columns = ['pk_mathshistory', 'name_year_mathshistory', 
                    'birth_year_mathshistory', 'birth_year_dbpedia', 'name_year_dbpedia', 'uri' ]
df_match.head(3)
# Out:
#    pk_mathshistory name_year_mathshistory  birth_year_mathshistory  \
# 0                3   Hermann of Reichenau                     1013
# 1                5             al-Zarqali                     1029
# 2                7           Omar Khayyam                     1048
#
#   birth_year_dbpedia     name_year_dbpedia  \
# 0               1013  Hermann of Reichenau
# 1               1029            Az-Zarqali
# 2               1048          Omar Khayyam
#
#                                                  uri
# 0   http://dbpedia.org/resource/Hermann_of_Reichenau
# 1  http://dbpedia.org/resource/Abū_Isḥāq_Ibrāhīm_...
# 2           http://dbpedia.org/resource/Omar_Khayyam

# %%
fp = "data/df_match_dbpedia.csv"
df_match.to_csv(fp)

# %% [markdown]
# ### Persons with no match but additional information

# %%
len(l_no_match_alternative), l_no_match_alternative[10:12]
# Out:
# (691,
#  [[22,
#    'Li Zhi',
#    1192,
#    [['http://dbpedia.org/resource/Cao_Zhi',
#      'Cao Zhi',
#      '--12',
#      'http://dbpedia.org/resource/Category:192_births'],
#     ['http://dbpedia.org/resource/Cao_Zhi',
#      'Cao Zhi',
#      '--12',
#      'http://dbpedia.org/resource/Category:192_births'],
#     ['http://dbpedia.org/resource/Cao_Zhi',
#      'Cao Zhi',
#      '--12',
#      'http://dbpedia.org/resource/Category:192_births'],
#     ['http://dbpedia.org/resource/Cao_Zhi',
#      'Cao Zhi',
#      '--12',
#      'http://dbpedia.org/resource/Category:192_births'],
#     ['http://dbpedia.org/resource/Cao_Zhi',
#      'Cao Zhi',
#      '--12',
#      'http://dbpedia.org/resource/Category:192_births'],
#     ['http://dbpedia.org/resource/Cao_Zhi',
#      'Cao Zhi',
#      '--12',
#      'http://dbpedia.org/resource/Category:192_births'],
#     ['http://dbpedia.org/resource/Cao_Zhi',
#      'Cao Zhi',
#      '--12',
#      'http://dbpedia.org/resource/Category:192_births'],
#     ['http://dbpedia.org/resource/Cao_Zhi_(politician)',
#      'Cao Zhi (politician)',
#      'May ',
#      'http://dbpedia.org/resource/Category:1928_births'],
#     ['http://dbpedia.org/resource/Bing_Zhi',
#      'Bing Zhi',
#      '1886',
#      'http://dbpedia.org/resource/Category:1886_births'],
#     ['http://dbpedia.org/resource/Deng_Zhi',
#      'Deng Zhi',
#      '178',
#      'http://dbpedia.org/resource/Category:178_births'],
#     ['http://dbpedia.org/resource/Deng_Zhi',
#      'Deng Zhi',
#      '178',
#      'http://dbpedia.org/resource/Category:178_births'],
#     ['http://dbpedia.org/resource/Deng_Zhi',
#      'Deng Zhi',
#      '178',
#      'http://dbpedia.org/resource/Category:178_births'],
#     ['http://dbpedia.org/resource/Huang_Zhi_Yu',
#      'Huang Zhi Yu',
#      '1979',
#      'http://dbpedia.org/resource/Category:1979_births'],
#     ['http://dbpedia.org/resource/Julian_Yee',
#      'Julian Zhi Jie Yee',
#      '1997',
#      'http://dbpedia.org/resource/Category:1997_births'],
#     ['http://dbpedia.org/resource/Mei_Zhi',
#      'Mei Zhi',
#      '1914',
#      'http://dbpedia.org/resource/Category:1914_births'],
#     ['http://dbpedia.org/resource/Lü_Zhi_(conservationist)',
#      'Lü Zhi (biologiste)',
#      '',
#      'http://dbpedia.org/resource/Category:1965_births'],
#     ['http://dbpedia.org/resource/Lü_Zhi_(conservationist)',
#      'Lü Zhi (Biologin)',
#      '',
#      'http://dbpedia.org/resource/Category:1965_births'],
#     ['http://dbpedia.org/resource/Lü_Zhi_(conservationist)',
#      'Lü Zhi (conservationist)',
#      '',
#      'http://dbpedia.org/resource/Category:1965_births'],
#     ['http://dbpedia.org/resource/Lü_Zhi_(conservationist)',
#      'Lü Zhi (conservacionista)',
#      '',
#      'http://dbpedia.org/resource/Category:1965_births'],
#     ['http://dbpedia.org/resource/Lü_Zhi_(conservationist)',
#      'Lü Zhi',
#      '',
#      'http://dbpedia.org/resource/Category:1965_births']]],
#   [24,
#    'Albertus',
#    1200,
#    [['http://dbpedia.org/resource/Bert_Boom',
#      'Albertus Boom',
#      '1938',
#      'http://dbpedia.org/resource/Category:1938_births'],
#     ['http://dbpedia.org/resource/Bert_Boom',
#      'Albertus Boom',
#      '1938',
#      'http://dbpedia.org/resource/Category:1938_births'],
#     ['http://dbpedia.org/resource/Petrus_Albertus_van_der_Parra',
#      'Petrus Albertus van der Parra',
#      '1714',
#      'http://dbpedia.org/resource/Category:1714_births'],
#     ['http://dbpedia.org/resource/Petrus_Albertus_van_der_Parra',
#      'Petrus Albertus van der Parra',
#      '1714',
#      'http://dbpedia.org/resource/Category:1714_births'],
#     ['http://dbpedia.org/resource/Petrus_Albertus_van_der_Parra',
#      'Petrus Albertus van der Parra',
#      '1714',
#      'http://dbpedia.org/resource/Category:1714_births'],
#     ['http://dbpedia.org/resource/Elvis_Albertus',
#      'Elvis Albertus',
#      '1966',
#      'http://dbpedia.org/resource/Category:1966_births'],
#     ['http://dbpedia.org/resource/Elvis_Albertus',
#      'Elvis Albertus',
#      '1966',
#      'http://dbpedia.org/resource/Category:1966_births'],
#     ['http://dbpedia.org/resource/Elvis_Albertus',
#      'Elvis Albertus',
#      '1966',
#      'http://dbpedia.org/resource/Category:1966_births'],
#     ['http://dbpedia.org/resource/Elvis_Albertus',
#      'Elvis Albertus',
#      '1966',
#      'http://dbpedia.org/resource/Category:1966_births'],
#     ['http://dbpedia.org/resource/George_Albertus_Cox',
#      'George Albertus Cox',
#      '1840',
#      'http://dbpedia.org/resource/Category:1840_births'],
#     ['http://dbpedia.org/resource/Gerard_Bilders',
#      'Albertus Gerardus Bilders',
#      '1838',
#      'http://dbpedia.org/resource/Category:1838_births'],
#     ['http://dbpedia.org/resource/Antipope_Adalbert',
#      'Albertus (Gegenpapst)',
#      '',
#      ''],
#     ['http://dbpedia.org/resource/Hendrikus_Albertus_Lorentz',
#      'Hendrikus Albertus Lorentz',
#      '',
#      'http://dbpedia.org/resource/Category:1871_births'],
#     ['http://dbpedia.org/resource/Hendrikus_Albertus_Lorentz',
#      'Hendrikus Albertus Lorentz',
#      '',
#      'http://dbpedia.org/resource/Category:1871_births'],
#     ['http://dbpedia.org/resource/Hendrikus_Albertus_Lorentz',
#      'Hendrikus Albertus Lorentz',
#      '',
#      'http://dbpedia.org/resource/Category:1871_births'],
#     ['http://dbpedia.org/resource/Hendrikus_Albertus_Lorentz',
#      'Hendrikus Albertus Lorentz',
#      '',
#      'http://dbpedia.org/resource/Category:1871_births'],
#     ['http://dbpedia.org/resource/Hendrikus_Albertus_Lorentz',
#      'Hendrikus Albertus Lorentz',
#      '',
#      'http://dbpedia.org/resource/Category:1871_births'],
#     ['http://dbpedia.org/resource/Hendrikus_Albertus_Lorentz',
#      'Hendrikus Albertus Lorentz',
#      '',
#      'http://dbpedia.org/resource/Category:1871_births'],
#     ['http://dbpedia.org/resource/Hendrikus_Albertus_Lorentz',
#      'Hendrikus Albertus Lorentz',
#      '',
#      'http://dbpedia.org/resource/Category:1871_births'],
#     ['http://dbpedia.org/resource/Albert_Christian_Kruyt',
#      'Albertus Christiaan Kruyt',
#      '1869',
#      'http://dbpedia.org/resource/Category:1869_births']]]])

# %% [markdown]
# ### New match using additional information

# %%
l_match_2 = []
l_no_match_alternative_2 = []
l_no_match_2 = []
for r in l_no_match_alternative:
    
    lm = []
    # for each element in the DBPedia answer
    for e in r[3]:

        # take the date if it exists
        if e[3] and 'birth' in e[3]:
            
            try:
                d3 = str(re.findall(r'\d{4}', e[3])[0])
                # print(d3)
                if (str(r[2])[:3] == str(d3)[:3]):
                    lm =[r[0],r[1],r[2], d3, e[1], e[0]]
                    l_match_2.append(lm)
            except Exception as e:
                print(r[0],r[1],r[2],e)
        if len(lm) > 0:
            break

    if len(lm) == 0:
        l_no_match_alternative_2.append(r)

# %%
len(l_match_2), l_match_2[:5]
# Out:
# (507,
#  [[1,
#    'al-Nasawi',
#    1010,
#    '1010',
#    'Ali ibn Ahmad al-Nasawi',
#    'http://dbpedia.org/resource/Alī_ibn_Ahmad_al-Nasawī'],
#   [9,
#    'Abraham bar Hiyya',
#    1070,
#    '1070',
#    'Abraham bar Hiyya',
#    'http://dbpedia.org/resource/Abraham_bar_Hiyya'],
#   [14,
#    'Bhaskara II',
#    1114,
#    '1110',
#    'Bhaskara II',
#    'http://dbpedia.org/resource/Bhāskara_II'],
#   [19,
#    'Robert Grosseteste',
#    1168,
#    '1168',
#    'Robert Grosseteste',
#    'http://dbpedia.org/resource/Robert_Grosseteste'],
#   [20,
#    'Fibonacci',
#    1170,
#    '1170',
#    'Fibonacci',
#    'http://dbpedia.org/resource/Fibonacci']])

# %% [markdown]
# ### Merge matches

# %%
print(len(l_match))
l_match_1 = l_match + l_match_2; len(l_match_1), len(l_match_2)
# Out:
# 1761
# (2268, 507)

# %%
df_match = pd.DataFrame(sorted(l_match_1, key= lambda row: row[2]))
df_match.columns = ['pk_mathshistory', 'name_year_mathshistory', 
                    'birth_year_mathshistory', 'birth_year_dbpedia', 'name_dbpedia', 'uri' ]
len(df_match)
# Out:
# 2268

# %%
df_match.iloc[200:203]
# Out:
#      pk_mathshistory name_year_mathshistory  birth_year_mathshistory  \
# 200              279          Samuel Clarke                     1675
# 201              281         Jacopo Riccati                     1676
# 202              282        Jacques Cassini                     1677
#
#     birth_year_dbpedia     name_dbpedia  \
# 200               1675    Samuel Clarke
# 201               1676   Jacopo Riccati
# 202               1677  Jacques Cassini
#
#                                              uri
# 200    http://dbpedia.org/resource/Samuel_Clarke
# 201   http://dbpedia.org/resource/Jacopo_Riccati
# 202  http://dbpedia.org/resource/Jacques_Cassini

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(df_match.sort_values(by='pk_mathshistory'), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="708af356-3da4-475d-990b-7100beb018f6" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pk_mathshistory</th>
#       <th>name_year_mathshistory</th>
#       <th>birth_year_mathshistory</th>
#       <th>birth_year_dbpedia</th>
#       <th>name_dbpedia</th>
#       <th>uri</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>pk_mathshistory</th><th>name_year_mathshistory</th><th>birth_year_mathshistory</th><th>birth_year_dbpedia</th><th>name_dbpedia</th><th>uri</th></tfoot></table>
# <script>
#     // We use a namespace per table (= the next curly bracket)
#     // to avoid conflicts between the various tables' data & dt_args
#     {
#         // Define the table data
#         const data = [[0, 1, "al-Nasawi", 1010, "1010", "Ali ibn Ahmad al-Nasawi", "http://dbpedia.org/resource/Al\u012b_ibn_Ahmad_al-Nasaw\u012b"], [1, 3, "Hermann of Reichenau", 1013, "1013", "Hermann of Reichenau", "http://dbpedia.org/resource/Hermann_of_Reichenau"], [2, 5, "al-Zarqali", 1029, "1029", "Az-Zarqali", "http://dbpedia.org/resource/Ab\u016b_Is\u1e25\u0101q_Ibr\u0101h\u012bm_al-Zarq\u0101l\u012b"], [3, 7, "Omar Khayyam", 1048, "1048", "Omar Khayyam", "http://dbpedia.org/resource/Omar_Khayyam"], [4, 8, "Brahmadeva", 1060, "1060", "Brahmadeva", "http://dbpedia.org/resource/Brahmadeva"], [5, 9, "Abraham bar Hiyya", 1070, "1070", "Abraham bar Hiyya", "http://dbpedia.org/resource/Abraham_bar_Hiyya"], [6, 13, "Jabir ibn Aflah", 1100, "1100", "Jabir ibn Aflah", "http://dbpedia.org/resource/Jabir_ibn_Aflah"], [7, 14, "Bhaskara II", 1114, "1110", "Bhaskara II", "http://dbpedia.org/resource/Bh\u0101skara_II"], [8, 19, "Robert Grosseteste", 1168, "1168", "Robert Grosseteste", "http://dbpedia.org/resource/Robert_Grosseteste"], [9, 20, "Fibonacci", 1170, "1170", "Fibonacci", "http://dbpedia.org/resource/Fibonacci"], [10, 21, "Michael Scot", 1175, "1175", "Michael Scot", "http://dbpedia.org/resource/Michael_Scot"], [11, 25, "Nasir al-Din al-Tusi", 1201, "1201", "Nasir al-Din al-Tusi", "http://dbpedia.org/resource/Nasir_al-Din_al-Tusi"], [12, 26, "Qin Jiushao", 1202, "1202", "Qin Jiushao", "http://dbpedia.org/resource/Qin_Jiushao"], [13, 31, "Guo Shoujing", 1231, "1231", "Guo Shoujing", "http://dbpedia.org/resource/Guo_Shoujing"], [14, 32, "Ramon Llull", 1235, "1230", "Ramon Llull", "http://dbpedia.org/resource/Ramon_Llull"], [15, 34, "Yang Hui", 1238, "1238", "Yang Hui", "http://dbpedia.org/resource/Yang_Hui"], [16, 36, "Ibn al-Banna", 1256, "1256", "Ibn al-Banna al-Marr\u0101kusch\u012b", "http://dbpedia.org/resource/Ibn_al-Banna'_al-Marrakushi"], [17, 37, "Al-Farisi", 1260, "1260", "Al-Farisi", "http://dbpedia.org/resource/Kam\u0101l_al-D\u012bn_al-F\u0101ris\u012b"], [18, 39, "Zhao Youqin", 1271, "1271", "Zhao Youqin", "http://dbpedia.org/resource/Zhao_Youqin"], [19, 41, "William of Ockham", 1288, "1287", "William Ockham", "http://dbpedia.org/resource/William_of_Ockham"], [20, 43, "Albert of Saxony", 1316, "1316", "Albert of Saxony (philosopher)", "http://dbpedia.org/resource/Albert_of_Saxony_(philosopher)"], [21, 49, "Qadi Zada", 1364, "1364", "Qadi Zada", "http://dbpedia.org/resource/Q\u0101\u1e0d\u012b_Z\u0101da_al-R\u016bm\u012b"], [22, 51, "Filippo Brunelleschi", 1377, "1377", "Filippo Brunelleschi", "http://dbpedia.org/resource/Filippo_Brunelleschi"], [23, 53, "Ulugh Beg", 1393, "1394", "Ulugh Beg", "http://dbpedia.org/resource/Ulugh_Beg"], [24, 56, "Ali Qushji", 1403, "1403", "Ali Qushji", "http://dbpedia.org/resource/Ali_Qushji"], [25, 58, "Al-Qalasadi", 1412, "1412", "Al-Qalasadi", "http://dbpedia.org/resource/Abu'l-Hasan_ibn_Ali_al-Qalasadi"], [26, 60, "Georg Peurbach", 1423, "1423", "Georg von Peurbach", "http://dbpedia.org/resource/Georg_von_Peuerbach"], [27, 61, "Piero Borgi", 1424, "1424", "Piero Borgi", "http://dbpedia.org/resource/Piero_Borgi"], [28, 62, "Regiomontanus", 1436, "1436", "Regiomontanus", "http://dbpedia.org/resource/Regiomontanus"], [29, 63, "Nilakantha", 1444, "1444", "Nilakantha Somayaji", "http://dbpedia.org/resource/Nilakantha_Somayaji"], [30, 64, "Luca Pacioli", 1445, "1447", "Luca Pacioli", "http://dbpedia.org/resource/Luca_Pacioli"], [31, 66, "Leonardo da Vinci", 1452, "1452", "Leonardo da Vinci", "http://dbpedia.org/resource/Leonardo_da_Vinci"], [32, 68, "Scipione del Ferro", 1465, "1465", "Scipione del Ferro", "http://dbpedia.org/resource/Scipione_del_Ferro"], [33, 69, "Johann Werner", 1468, "1468", "Johann Werner", "http://dbpedia.org/resource/Johannes_Werner"], [34, 71, "Estienne de la Roche", 1470, "1470", "Estienne de La Roche", "http://dbpedia.org/resource/Estienne_de_La_Roche"], [35, 72, "Albrecht D\u00fcrer", 1471, "1471", "Albrecht D\u00fcrer", "http://dbpedia.org/resource/Albr ...

# %%
### replace former file
fp = "data/df_match_dbpedia.csv"
df_match.to_csv(fp)

# %% [markdown]
# ### Import into database

# %%
lv = df_match[['pk_mathshistory', 'uri']].values.tolist()
len(lv), lv[:3]
# Out:
# (2268,
#  [[1, 'http://dbpedia.org/resource/Alī_ibn_Ahmad_al-Nasawī'],
#   [3, 'http://dbpedia.org/resource/Hermann_of_Reichenau'],
#   [5, 'http://dbpedia.org/resource/Abū_Isḥāq_Ibrāhīm_al-Zarqālī']])

# %%
tuples = [tuple(e) for e in lv] ; tuples[:3]
# Out:
# [(1, 'http://dbpedia.org/resource/Alī_ibn_Ahmad_al-Nasawī'),
#  (3, 'http://dbpedia.org/resource/Hermann_of_Reichenau'),
#  (5, 'http://dbpedia.org/resource/Abū_Isḥāq_Ibrāhīm_al-Zarqālī')]

# %%
cur = conn.cursor()

# %%
cq = """
create table mathshistory.dbpedia (id integer, uri varchar);
"""

# %%
cur.execute(cq)

# %%
execute_batch(cur, """INSERT INTO mathshistory.dbpedia (id, uri)
VALUES (%s, %s)""", tuples)

# %%
conn.commit()

# %%
iq = """
insert into mathshistory."statement" (fk_subject_instance, text_value, fk_property, fk_graph, import_metadata)
select id, uri, 1, 3011, '20230627_1'  from mathshistory.dbpedia;
"""

# %%
with conn.cursor() as cur:
    ### Commented to avoid disruption
    # cur.execute(iq)

# %%
conn.commit()

# %% [markdown]
# ## Remainining non matched with additional information

# %%
len(l_no_match_alternative_2)  #, l_no_match_alternative_2[5:7]
# Out:
# 184

# %%
df_no_match_alternative_2 = pd.DataFrame(sorted(l_no_match_alternative_2, key= lambda row: row[2]))
df_no_match_alternative_2.columns = ['pk_mathshistory', 'name_year_mathshistory', 
                    'birth_year_mathshistory', 'dbpedia_query result']
df_no_match_alternative_2.head()
# Out:
#    pk_mathshistory name_year_mathshistory  birth_year_mathshistory  \
# 0                2               Jia Xian                     1010
# 1                4                Sripati                     1019
# 2               11             Hemchandra                     1089
# 3               16             Al-Samawal                     1130
# 4               22                 Li Zhi                     1192
#
#                                 dbpedia_query result
# 0  [[http://dbpedia.org/resource/Jia_Xian, Jia Xi...
# 1  [[http://dbpedia.org/resource/Sripati_Mishra, ...
# 2  [[http://dbpedia.org/resource/Hemchandra_Barua...
# 3  [[http://dbpedia.org/resource/Samawal_Merghani...
# 4  [[http://dbpedia.org/resource/Cao_Zhi, Cao Zhi...

# %%
fp = "data/df_no_match_alternative_2.csv"
df_no_match_alternative_2.to_csv(fp)

# %% [markdown]
# ### New match attempt
#
# [27 June 2023]
#
# * Given the results of this matching, and their uncertainty for the later period:
#   * first inspect wikidata matching and overall matching analysis in the database
#   * analyse and import manually

# %%
len(df_no_match), df_no_match.head()
# Out:
# (558,
#     pk_mathshistory name_year_mathshistory  birth_year_mathshistory
#  0                6               Shen Kua                     1031
#  1               12         Rabbi Ben Ezra                     1092
#  2               15                Gherard                     1114
#  3               17  Sharaf al-Din al-Tusi                     1135
#  4               18   Reinher of Paderborn                     1140)

# %%
len(df_no_match_alternative_2), df_no_match_alternative_2.head()
# Out:
# (177,
#     pk_mathshistory name_year_mathshistory  birth_year_mathshistory  \
#  0                2               Jia Xian                     1010
#  1                4                Sripati                     1019
#  2               11             Hemchandra                     1089
#  3               16             Al-Samawal                     1130
#  4               22                 Li Zhi                     1192
#
#                                  dbpedia_query result
#  0  [[http://dbpedia.org/resource/Jia_Xian, Jia Xi...
#  1  [[http://dbpedia.org/resource/Sripati_Mishra, ...
#  2  [[http://dbpedia.org/resource/Hemchandra_Barua...
#  3  [[http://dbpedia.org/resource/Samawal_Merghani...
#  4  [[http://dbpedia.org/resource/Cao_Zhi, Cao Zhi...  )

# %%
df_no_match_alternative_2.columns
# Out:
# Index(['pk_mathshistory', 'name_year_mathshistory', 'birth_year_mathshistory',
#        'dbpedia_query result'],
#       dtype='object')

# %%
df_to_find = pd.concat([df_no_match, df_no_match_alternative_2[['pk_mathshistory', 'name_year_mathshistory', 'birth_year_mathshistory']]],
                      names=['pk_mathshistory', 'name_year_mathshistory', 'birth_year_mathshistory',])
df_to_find.head()
# Out:
#    pk_mathshistory name_year_mathshistory  birth_year_mathshistory
# 0                6               Shen Kua                     1031
# 1               12         Rabbi Ben Ezra                     1092
# 2               15                Gherard                     1114
# 3               17  Sharaf al-Din al-Tusi                     1135
# 4               18   Reinher of Paderborn                     1140

# %%
len(df_to_find), df_to_find.tail()
# Out:
# (735,
#       pk_mathshistory name_year_mathshistory  birth_year_mathshistory
#  172             2773       Nicolas Bourbaki                     1935
#  173             2768      Hitoshi Kumano-Go                     1935
#  174             2892          John O'Connor                     1945
#  175             2923              John Carr                     1948
#  176             2987         Richard Taylor                     1962)

# %%
df_values = df_to_find.sort_values(by='birth_year_mathshistory').values.tolist()
list(df_values)
# Out:
# [[2, 'Jia Xian', 1010],
#  [4, 'Sripati', 1019],
#  [6, 'Shen Kua', 1031],
#  [11, 'Hemchandra', 1089],
#  [12, 'Rabbi Ben Ezra', 1092],
#  [15, 'Gherard', 1114],
#  [16, 'Al-Samawal', 1130],
#  [17, 'Sharaf al-Din al-Tusi', 1135],
#  [18, 'Reinher of Paderborn', 1140],
#  [22, 'Li Zhi', 1192],
#  [23, 'John Sacrobosco', 1195],
#  [24, 'Albertus', 1200],
#  [27, 'Roger Bacon', 1214],
#  [28, 'Johannes Campanus', 1220],
#  [29, "Muhyi l'din al-Maghribi", 1220],
#  [30, 'Jordanus Nemorarius', 1225],
#  [33, 'Jacob ben Tibbon', 1236],
#  [35, 'Shams al-Din al-Samarqandi', 1250],
#  [38, 'Zhu Shijie', 1260],
#  [40, 'Levi ben Gerson', 1288],
#  [42, 'Thomas Bradwardine', 1295],
#  [44, 'Al-Khalili', 1320],
#  [45, 'Nicholas Oresme', 1323],
#  [46, 'Mahendra Suri', 1340],
#  [47, 'Narayana', 1340],
#  [48, 'Madhava', 1350],
#  [50, 'Paramesvara', 1370],
#  [52, 'al-Kashi', 1390],
#  [54, 'Al-Umawi', 1400],
#  [55, 'Nicholas Kryffs', 1401],
#  [57, 'Leone Battista Alberti', 1404],
#  [59, 'Piero della Francesca', 1420],
#  [65, 'Nicolas Chuquet', 1445],
#  [67, 'Johannes Widman', 1462],
#  [70, 'John Maior', 1469],
#  [73, 'Charles de Bouvelles', 1471],
#  [76, 'Juan de Ortega', 1480],
#  [82, 'Petrus Apianus', 1495],
#  [88, 'Frederico Commandino', 1506],
#  [89, 'Gemma Frisius', 1508],
#  [94, 'Peter Ramus', 1515],
#  [99, 'Cheng Dawei', 1533],
#  [101, 'Egnatio Danti', 1536],
#  [106, 'Thomas Allen', 1540],
#  [121, 'João Delgado', 1553],
#  [123, 'João Baptista Lavanha', 1555],
#  [129, 'Philip van Lansberge', 1561],
#  [126, 'Bartholomeo Pitiscus', 1561],
#  [131, 'Xu Guang-qi', 1562],
#  [137, 'Simon Mayr', 1573],
#  [147, 'Gregory of Saint-Vincent', 1584],
#  [156, 'Jean Beaugrand', 1590],
#  [162, 'Jacob Gool', 1596],
#  [167, 'Claude Hardy', 1598],
#  [169, 'Adriaan Vlacq', 1600],
#  [171, 'Richard Delamain', 1600],
#  [175, 'Jacques de Billy', 1602],
#  [180, 'Maria Cunitz', 1607],
#  [184, 'Jacques Le Tenneur', 1610],
#  [188, 'Andrea Tacquet', 1612],
#  [194, 'Kamalakara', 1616],
#  [202, 'Nicolaus Mercator', 1620],
#  [211, 'Stephano degli Angeli', 1623],
#  [216, 'Jan de Witt', 1625],
#  [218, 'Pietro Mengoli', 1626],
#  [219, 'Jonas Moore', 1627],
#  [221, 'Johann Hudde', 1628],
#  [228, 'Mei Wending', 1633],
#  [227, 'Henry Coley', 1633],
#  [231, 'Valentin Heins', 1637],
#  [241, 'Heinrich Meissner', 1644],
#  [242, 'Siguenza y Gongora', 1645],
#  [247, 'Elisabetha Koopman', 1647],
#  [257, 'Charles René Reyneau', 1656],
#  [267, 'Takebe Katahiro', 1664],
#  [274, 'Leonty Filippovich Magnitsky', 1669],
#  [276, 'Guido Grandi', 1671],
#  [280, 'William Jones', 1675],
#  [284, 'Joseph Privat de Molières', 1677],
#  [289, 'John Machin', 1680],
#  [291, 'Mei Juecheng', 1681],
#  [303, "Willem 'sGravesande", 1688],
#  [302, 'Roger Paman', 1688],
#  [306, 'Jagannatha', 1690],
#  [309, 'Nicolaus (II) Bernoulli', 1695],
#  [330, 'Benjamin Franklin', 1706],
#  [336, 'Giordano Riccati', 1709],
#  [337, 'Johann (II) Bernoulli', 1710],
#  [338, 'Thomas Fuller', 1710],
#  [347, 'Alexander Wilson', 1714],
#  [357, 'Nicole-Reine Etable de Labrière', 1723],
#  [380, 'Monteiro da Rocha', 1734],
#  [382, 'Antonio Mario Lorgna', 1735],
#  [381, 'Alexandre-Theophile Vandermonde', 1735],
#  [394, 'Pietro Giannini', 1740],
#  [396, 'John Wilson', 1741],
#  [399, 'Johann(III) Bernoulli', 1744],
#  [401, 'Adrien Quentin Buée', 1745],
#  [417, 'Lorenzo Mascheroni', 1750],
#  [419, 'William Morgan', 1750],
#  [430, 'Nikolai Fuss', 1755],
#  [433, 'Jacob (II) Bernoulli', 1759],
#  [444, 'Timofei Fedorovic Osipovsky', 1765],
#  [446, 'John Farey', 1766],
#  [447, 'John Leslie', 1766],
#  [445, 'John Brinkley', 1766],
#  [456, 'William Wallace', 1768],
#  [454, 'Li Rui', 1768],
#  [457, 'Annibale Giordano', 1769],
#  [485, 'Jozéf Hoëné Wronski', 1778],
#  [490, 'Giorgio Bidone', 1781],
#  [502, 'Jean-Nicolas Nicollet', 1786],
#  [503, 'John Walsh', 1786],
#  [506, 'John Cruickshank', 1787],
#  [507, 'Louis Lefébure de Fourcy', 1787],
#  [513, 'William Hamilton', 1788],
#  [518, 'Charles Hughes Terrot', 1790],
#  [519, 'Jean-Baptiste Bélanger', 1790],
#  [522, 'Alexis Petit', 1791],
#  [533, 'Nikolai Ivanovich Lobachevsky', 1792],
#  [539, 'Franz Adolph Taurinus', 1794],
#  [547, 'Louis Richard', 1795],
#  [542, 'Arthur Jules Morin', 1795],
#  [553, 'Nikolai Dmetrievich Brashman', 1796],
#  [569, 'Stephen de Gurbs', 1800],
#  [577, 'Mikhail Vasilevich Ostrogradski', 1801],
#  [578, 'Thomas Clausen', 1801],
#  [580, 'Jean-Baptiste Brasseur', 1802],
#  [584, 'Christian Heinrich von Nagel', 1803],
#  [592, 'Viktor Yakovlevich Bunyakovskii', 1804],
#  [602, 'Robert Murphy', 1806],
#  [599, 'James Booth', 1806],
#  [604, 'Józeph Petzval', 1807],
#  [613, 'John Pratt', 1809],
#  [633, 'Franc Mocnik', 1814],
#  [632, 'Fernando Pio Rosellini', 1814],
#  [630, 'Daniel da Silva', 1814],
#  [640, 'Augusta Ada Byron', 1815],
#  [654, 'Joel E Hendricks', 1818],
#  [653, 'Ferdinand Joachimsthal', 1818],
#  [686, 'William Oughter Lonie', 1822],
#  [687, 'August Yulevich Davidov', 1823],
#  [701, 'Zacharias Dase', 1824],
#  [707, 'Mikhail Egorovich Vashchenko-Zakharchenko', 1825],
#  [716, 'Henry Watson', 1827],
#  [721, 'Rudolf Skuherský', 1828],
#  [730, 'Thomas Bond Sprague', 1830],
#  [737, 'P G Tait', 1831],
#  [741, 'Charles Lutwidge Dodgson', 1832],
#  [744, 'Georg Zehfuss', 1832],
#  [756, 'John Venn', 1834],
#  [757, 'William Jack', 1834],
#  [764, 'James Moriarty', 1835],
#  [775, 'Nicolai Vasilievich Bugaev', 1837],
#  [771, 'Hermann Bleuler', 1837],
#  [770, 'Aleksandr Nikolaevich Korkin', 1837],
#  [783, 'Jenő Hunyadi', 1838],
#  [788, 'Christian Adolph Mayer', 1839],
#  [794, 'James Bolam', 1839],
#  [807, 'Ernst Schröder', 1841],
#  [824, 'Otto Stolz', 1842],
#  [827, 'Yulian Vasilievich Sokhotsky', 1842],
#  [834, 'Karl Geiser', 1843],
#  [833, 'John S Mackay', 1843],
#  [832, 'James Stuart', 1843],
#  [840, 'George-Henri Halphen', 1844],
#  [845, 'Thomas Muir', 1844],
#  [855, 'Vaclav Jerabek', 1845],
#  [865, 'Platon Sergeevich Poretsky', 1846],
#  [872, 'George Greenhill', 1847],
#  [875, 'John Wilson', 1847],
#  [870, 'Egor Ivanovich Zolotarev', 1847],
#  [876, 'Nikolai Egorovich Zhukovskii', 1847],
#  [889, 'Lóránd Eötvös', 1848],
#  [888, 'Konstantin Alekseevich Andreev', 1848],
#  [878, 'Adam Günther', 1848],
#  [880, 'Édouard Benjamin Baillaud', 1848],
#  [901, 'Robert Scott', 1849],
#  [899, 'Leopold Gegenbauer', 1849],
#  [907, 'Scott Lang', 1850],
#  [905, 'Jorgen Gram', 1850],
#  [909, 'Sophie Willock Bryant', 1850],
#  [925, 'James Taylor', 1851],
#  [922, 'Gomes Teixeira', 1851],
#  [926, 'Julius Gysel', 1851],
#  [931, 'Andrei Petrovich Kiselev', 1852],
#  [942, 'Albert Badoureau', 1853],
#  [961, 'Leopold Klug', 1854],
#  [959, 'Ivan Śleszyński', 1854],
#  [973, 'Louis Raffy', 1855],
#  [976, 'Thomas Craig', 1855],
#  [977, 'Andrei Andreyevich Markov', 1856],
#  [992, 'William Thomson', 1856],
#  [981, 'Donald Macmillan', 1856],
#  [995, 'Alexander Pell', 1857],
#  [999, 'Hermann Wiener', 1857],
#  [993, 'Adolf Kiefer', 1857],
#  [994, 'Aleksandr Mikhailovich Lyapunov', 1857],
#  [998, 'Henry Ernest Dudeney', 1857],
#  [1007, 'Francesco Gerbaldi', 1858],
#  [1013, 'William Johnson', 1858],
#  [1015, 'Alfonso Del Re', 1859],
#  [1022, 'Ivan Vsevolodovich Meshchersky', 1859],
#  [1027, 'Samuil Osipovich Shatunovsky', 1859],
#  [1016, 'Boris Yakovlevic Bukreev', 1859],
#  [1028, 'Alexander Morgan', 1860],
#  [1034, 'Frank Carey', 1860],
#  [1037, 'John Pullar', 1860],
#  [1055, 'John Alison', 1861],
#  [1063, 'William Briggs', 1861],
#  [1065, 'William Peddie', 1861],
#  [1076, 'John Campbell', 1862],
#  [1077, 'Jules Richard', 1862],
#  [1075, 'James Wattie', 1862],
#  [1071, 'Fritz (Friedrich) Bützberger', 1862],
#  [1087, 'Aleksei Krylov', 1863],
#  [1104, 'Jean-Marie Le Roux', 1863],
#  [1112, 'Matthew Fry', 1863],
#  [1115, 'William Metzler', 1863],
#  [1093, 'Crossley Barlow', 1863],
#  [1094, 'Dmitry Aleksandrovich Grave', 1863],
#  [1124, 'Robert Hardie', 1864],
#  [1133, 'Charles Cailler', 1865],
#  [1142, 'J A Third', 1865],
#  [1134, 'David Tweedie', 1865],
#  [1147, 'Rosenberg, Fabian', 1865],
#  [1132, 'Benjamin Franklin Finkel', 1865],
#  [1167, 'T J J See', 1866],
#  [1166, 'Ralph Sampson', 1866],
#  [1154, 'Clara Bacon', 1866],
#  [1165, 'Mineo Chini', 1866],
#  [1173, 'Gury Vasilievich Kolosov', 1867],
#  [1174, 'Hendrik de Vries', 1867],
#  [1172, 'Dmitrii Matveevich Sintsov', 1867],
#  [1195, 'James Craig', 1868],
#  [1204, 'William Leslie Thomson', 1868],
#  [1182, 'Annie Fitch MacKinnon', 1868],
#  [1185, 'Charles Shirra Dougall', 1868],
#  [1213, 'Sergei Alekseevich Chaplygin', 1869],
#  [1207, 'Dimitri Fedorovich Egorov', 1869],
#  [1206, 'Benjamin Fedorovich Kagan', 1869],
#  [1225, 'Ion Ionescu', 1870],
#  [1219, 'Frank Jackson', 1870],
#  [1227, 'Peter Pinkerton', 1870],
#  [1228, 'Robert de Montessus', 1870],
#  [1217, 'Ellice Horsburgh', 1870],
#  [1216, 'David J Tweedie', 1870],
#  [1237, 'James Mitchell', 1871],
#  [1239, 'John Turner', 1871],
#  [1231, 'Ernst Julius Amberg', 1871],
#  [1243, 'V Ramaswami Aiyar', 1871],
#  [1256, 'Nikolaos Hatzidakis', 1872],
#  [1257, 'Onorato Nicoletti', 1872],
#  [1245, 'Alexander Durie Russell', 1872],
#  [1251, 'Georgii Vasilovich Pfeiffer', 1872],
#  [1253, 'Gustave Dumas', 1872],
#  [1250, 'George Moffat', 1872],
#  [1259, 'Wilhelm Ahrens', 1872],
#  [1254, 'John Meiklejohn', 1872],
#  [1273, 'Richard Fuchs', 1873],
#  [1262, 'Alfred Young', 1873],
#  [1272, 'Patrick Hardie', 1873],
#  [1275, 'Zoárd Geöcze', 1873],
#  [1283, 'Mihály Bauer', 1874],
#  [1285, "Robert d'Adhémar", 1874],
#  [1286, 'Andre-Louis Cholesky', 1875],
#  [1291, 'Ernst Fischer', 1875],
#  [1287, 'Archibald Milne', 1875],
#  [1290, 'Edward Blades', 1875],
#  [1311, 'Evelyn Cave-Browne-Cave', 1876],
#  [1320, 'Tatiana Alexeyevna Afanassjewa', 1876],
#  [1305, 'Anderson McKendrick', 1876],
#  [1335, 'Thomas Havelock', 1877],
#  [1338, 'Ólafur Daníelsson', 1877],
#  [1323, 'Carl Schoy', 1877],
#  [1326, 'David Johnstone', 1877],
#  [1337, 'William Gentle', 1877],
#  [1328, 'G H Hardy', 1877],
#  [1332, 'Luigi Brusotti', 1877],
#  [1349, 'Haroutune Dadourian', 1878],
#  [1342, 'Duilio Gigli', 1878],
#  [1361, 'Roland Richardson', 1878],
#  [1359, 'Panagiotis Zervos', 1878],
#  [1355, 'Matteo Bottasso', 1878],
#  [1347, 'George Samuel Eastwood', 1878],
#  [1365, 'David Picken', 1879],
#  [1366, 'Dougald Mcquistan', 1879],
#  [1373, 'Peter Ramsay', 1879],
#  [1363, 'Anton Dimitrija Bilimovic', 1879],
#  [1372, 'Nikolai Mitrofanovich Krylov', 1879],
#  [1378, 'Filadelfo Insolera', 1880],
#  [1377, 'Evgeny Evgenievich Slutsky', 1880],
#  [1376, 'Alexander Merriles', 1880],
#  [1394, 'Edward Ross', 1881],
#  [1400, 'Lajos Dávid', 1881],
#  [1399, 'L E J Brouwer', 1881],
#  [1424, 'Theodor Angheluță', 1882],
#  [1441, 'Margaret Barr Moir', 1883],
#  [1433, 'Esteban Terradas', 1883],
#  [1442, 'Neil McArthur', 1883],
#  [1430, 'David Gibb', 1883],
#  [1435, 'Frances Chick Wood', 1883],
#  [1436, 'Francisco José Duarte', 1883],
#  [1451, 'Francesco Cecioni', 1884],
#  [1459, 'Nicolae Abramescu', 1884],
#  [1460, 'Otto Szász', 1884],
#  [1456, 'H T H Piaggio', 1884],
#  [1485, 'Salvatore Cherubino', 1885],
#  [1470, 'F F P Bisacre', 1885],
#  [1476, 'John McWhan', 1885],
#  [1483, 'Niels Norlund', 1885],
#  [1491, 'Annibale Comessatti', 1886],
#  [1493, 'Balfour Lockhart', 1886],
#  [1492, 'Aurel Angelescu', 1886],
#  [1501, 'Otto Bruun', 1886],
#  [1490, 'Alexander Barrie Grieve', 1886],
#  [1528, 'David Kennedy Fraser', 1888],
#  [1534, 'John Mackie', 1888],
#  [1548, 'William Brash', 1888],
#  [1527, 'Bibhutibhushan Datta', 1888],
#  [1550, 'Yakov Davydovich Tamarkin', 1888],
#  [1538, 'Louis Antoine', 1888],
#  [1533, 'James Alexander', 1888],
#  [1571, 'Robert Dunbar', 1889],
#  [1573, 'Thomas Lancaster Wren', 1889],
#  [1554, 'Anton Kazimirovich Suschkevich', 1889],
#  [1553, 'Andrei Razmadze', 1889],
#  [1570, 'René Eugène Gateaux', 1889],
#  [1560, 'Eustachy Żyliński', 1889],
#  [1574, 'Vyacheslaw Vassilievich Stepanov', 1889],
#  [1552, 'Adolphe Rome', 1889],
#  [1580, 'Glenny Smeal', 1890],
#  [1576, 'Boris Nikolaevich Delone', 1890],
#  [1587, 'Olive Clio Hazlett', 1890],
#  [1585, 'Joseph Pérès', 1890],
#  [1575, 'Bevan Braithwaite Baker', 1890],
#  [1586, 'Martha Betz Shapley', 1890],
#  [1588, 'Philip Stein', 1890],
#  [1589, 'R A Fisher', 1890],
#  [1583, 'Jakob Nielsen', 1890],
#  [1598, 'Ivan Ivanovich Privalov', 1891],
#  [1606, 'Otto Yulyevich Schmidt', 1891],
#  [1599, 'Ivan Matveevich Vinogradov', 1891],
#  [1600, 'James Cassels', 1891],
#  [1592, 'Abram Samoilovitch Besicovitch', 1891],
#  [1623, 'Tadija Pejovic', 1892],
#  [1620, 'Mikhail Krawtchouk', 1892],
#  [1614, 'Félix Pollaczek', 1892],
#  [1630, 'Charles Henry Rowe', 1893],
#  [1642, 'Mikhail Fedorovich Subbotin', 1893],
#  [1643, 'Mohammed Reda Madwar', 1893],
#  [1646, 'Thomas Arnold Brown', 1893],
#  [1644, 'Petre Sergescu', 1893],
#  [1648, 'Agnes Scott', 1894],
#  [1659, "Jacov Il'ich Frenkel", 1894],
#  [1661, 'Mikhail Yakovlevich Suslin', 1894],
#  [1667, 'Theodoros Varopoulos', 1894],
#  [1656, 'Harry Schmidt', 1894],
#  [1649, 'Aleksandr Yakovlevich Khinchin', 1894],
#  [1672, 'Archil Kirillovich Kharadze', 1895],
#  [1690, 'Thomas Lumsden', 1895],
#  [1684, 'Leslie Cunningham', 1895],
#  [1677, 'Erich Hans Rothe', 1895],
#  [1713, 'Yurii Sokolov', 1896],
#  [1711, 'Vernon Morton', 1896],
#  [1694, 'Bertram Wilson', 1896],
#  [1709, "Sof'ja Aleksandrovna Janovskaja", 1896],
#  [1707, 'Robert Geary', 1896],
#  [1708, 'Rolin Wavre', 1896],
#  [1715, 'Alfonso Gándara', 1897],
#  [1730, 'Sylvia Skan', 1897],
#  [1732, 'Theodore Combridge', 1897],
#  [1725, 'Josif Zakharovich Shtokalo', 1897],
#  [1755, 'Thomas Cherry', 1898],
#  [1741, 'Erich Bessel-Hagen', 1898],
#  [1758, 'Zyoiti Suetuna', 1898],
#  [1739, 'Edwin Olds', 1898],
#  [1735, 'Ali Moustafa Mosharrafa', 1898],
#  [1756, 'Vladimir Aleksandrovich Fock', 1898],
#  [1762, 'Hildegard Ille', 1899],
#  [1775, 'Tomás Rodríguez Bachiller', 1899],
#  [1764, 'Karl Dörge', 1899],
#  [1772, 'Robert Schlapp', 1899],
#  [1771, 'Pelageia Polubarinova Kochina', 1899],
#  [1763, 'Julius Schauder', 1899],
#  [1795, "Mikhail Alekseevich Lavrent'ev", 1900],
#  [1781, 'Cecily Tanner', 1900],
#  [1784, 'Frederick Bath', 1900],
#  [1796, 'Pedro Puig Adam', 1900],
#  [1808, 'John Williamson', 1901],
#  [1816, 'Nikolai Evgrafovich Kochin', 1901],
#  [1818, 'Oene Bottema', 1901],
#  [1830, 'Winifred Deans', 1901],
#  [1811, 'Levan Gokieli', 1901],
#  [1813, 'Machgielis Euwe', 1901],
#  [1824, 'Richard Robb', 1901],
#  [1823, 'Richard Gwilt', 1901],
#  [1822, 'Richard Brauer', 1901],
#  [1820, 'Petr Sergeevich Novikov', 1901],
#  [1807, 'Ivan Georgievich Petrovsky', 1901],
#  [1826, 'Steven Vajda', 1901],
#  [1814, 'Mary Simpson', 1901],
#  [1815, "Naum Il'ich Akhiezer", 1901],
#  [1842, 'Joseph Pierce', 1902],
#  [1838, 'Gheorghe  Calugăreănu', 1902],
#  [1852, 'Reuben R McDaniel', 1902],
#  [1857, 'Udo Wegner', 1902],
#  [1837, 'G Leslie Frewin', 1902],
#  [1855, 'Theodor Estermann', 1902],
#  [1865, 'Bartel van der Waerden', 1903],
#  [1860, 'Alan Broadbent', 1903],
#  [1882, 'Jan Tinbergen', 1903],
#  [1881, 'James Paton', 1903],
#  [1886, 'Leifur Ásgeirsson', 1903],
#  [1867, 'Bertha Swirles Jeffreys', 1903],
#  [1874, 'Geoffrey Timms', 1903],
#  [1905, 'Demetrios Kappos', 1904],
#  [1910, 'George McVittie', 1904],
#  [1926, 'Lyudmila Vsevolodovna Keldysh', 1904],
#  [1908, 'Evan (Ianto) Davies', 1904],
#  [1920, 'Jerzy Słupecki', 1904],
#  [1906, 'Donald Eperson', 1904],
#  [1932, 'Wilhelm Flügge', 1904],
#  [1927, "Nikolai Grigor'evich Chudakov", 1904],
#  [1924, 'Karl Maruhn', 1904],
#  [1960, 'Margaret E Boyle', 1905],
#  [1951, 'Hubert Linfoot', 1905],
#  [1949, 'Harold Ruse', 1905],
#  [1959, 'Lev Shnirelman', 1905],
#  [1952, 'Jan Popken', 1905],
#  [1944, 'Eižens Leimanis', 1905],
#  [1939, 'Anna Adelaide Stafford Henriques', 1905],
#  [1966, 'Serge Mikhalovich Nikolski', 1905],
#  [2000, 'John Smith', 1906],
#  [1991, 'G de B Robinson', 1906],
#  [1975, 'Aleksandr Osipovich Gelfond', 1906],
#  [2006, 'Omar Catunda', 1906],
#  [1981, 'Carlo Federici', 1906],
#  [2008, 'Rafael Laguardia', 1906],
#  [1978, 'Boris Yakovlevich Levin', 1906],
#  [2015, 'Tom Cowling', 1906],
#  [2016, 'Vera Nikolaevna Faddeeva', 1906],
#  [2018, 'Yaroslav Borisovich Lopatynsky', 1906],
#  [1974, 'Adolph Pavlovich Yushkevich', 1906],
#  [1977, 'Andrei Tikhonov', 1906],
#  [2027, 'Gheorghe Pic', 1907],
#  [2021, 'Dmitrii Konstantinovich Faddeev', 1907],
#  [2033, 'Ilya Vekua', 1907],
#  [2024, 'Edgar Raymond Lorch', 1907],
#  [2023, 'Duro Kurepa', 1907],
#  [2049, 'Alfred Hoblitzelle Clifford', 1908],
#  [2067, 'Ivor Etherington', 1908],
#  [2050, 'Archibald Macintyre', 1908],
#  [2064, 'Hermann Ludwig Schmid', 1908],
#  [2073, 'Marceli Stark', 1908],
#  [2061, 'Hans Reichardt', 1908],
#  [2056, 'Guacolda Lazzerini', 1908],
#  [2057, 'Guglielmo Righini', 1908],
#  [2077, 'Solomon Grigoryevich Mikhlin', 1908],
#  [2078, 'Theodore Samuel Motzkin', 1908],
#  [2079, 'Victor Amazaspovich Ambartsumian', 1908],
#  [2080, 'Viktor Vladimirovich Vagner', 1908],
#  [2062, 'Hans Schubert', 1908],
#  [2046, 'Aldo Ghizzetti', 1908],
#  [2075, 'Schieffelin Claytor', 1908],
#  [2083, 'Béla Gyires', 1909],
#  [2107, 'Stan Ulam', 1909],
#  [2097, 'Jerzy Rozycki', 1909],
#  [2098, 'Johannes Haantjes', 1909],
#  [2099, 'Karl Heinrich Weise', 1909],
#  [2110, 'Walter R Talbot', 1909],
#  [2101, 'Mark Aronovich Naimark', 1909],
#  [2103, 'Nikolai Nikolaevich Bogolyubov', 1909],
#  [2104, 'Ottó Varga', 1909],
#  [2082, 'Anatoly Malcev', 1909],
#  [2085, 'Bill Penney', 1909],
#  [2100, 'Kosaku Yosida', 1909],
#  [2119, 'Ernst Mohr', 1910],
#  [2139, 'Paul Turán', 1910],
#  [2125, 'Hua Loo-Keng', 1910],
#  [2120, 'Floyd Burton Jones', 1910],
#  [2122, 'George G Lorentz', 1910],
#  [2136, 'Nikolai Vladimirovich Efimov', 1910],
#  [2153, 'Jack Todd', 1911],
#  [2155, 'Luís Antoni Santaló', 1911],
#  [2146, 'Eizens Arins', 1911],
#  [2157, 'Mstislav Vsevolodovich Keldysh', 1911],
#  [2143, 'Abraham Gelbart', 1911],
#  [2145, 'Dov Jarden', 1911],
#  [2175, 'Cora Ratto de Sadosky', 1912],
#  [2177, 'Demetrios Magiros', 1912],
#  [2188, "Leonid Vital'evich Kantorovich", 1912],
#  [2189, 'Louis Goodstein', 1912],
#  [2171, 'Andy Guinand', 1912],
#  [2208, 'Göran Borg', 1913],
#  [2211, 'Israil Gelfand', 1913],
#  [2210, 'Israel Everett Glover', 1913],
#  [2204, 'Cândido Silva Dias', 1913],
#  [2203, 'Ángel Gros', 1913],
#  [2213, 'Levan Magnaradze', 1913],
#  [2217, 'Muriel Wales', 1913],
#  [2256, 'William Wager Cooper', 1914],
#  [2231, 'Evgeny Sergeevich Lyapin', 1914],
#  [2230, 'Emilio Baiada', 1914],
#  [2239, 'José Sebastiao e Silva', 1914],
#  [2254, 'Walter Samuel McAfee', 1914],
#  [2226, 'András Rapcsák', 1914],
#  [2247, 'Pedro Abellanas', 1914],
#  [2240, "Lev Arkad'evich Kaluznin", 1914],
#  [2248, 'R H Bing', 1914],
#  [2251, 'Stefan Schwarz', 1914],
#  [2252, 'Tadeusz Boleslaw Ślebarski', 1914],
#  [2277, 'Paul Kelly', 1915],
#  [2267, 'James McConnell', 1915],
#  [2282, 'Yuri Vladimirovich Linnik', 1915],
#  [2263, 'Evgenii Mikhailovich Lifshitz', 1915],
#  [2280, 'Warren Brothers', 1915],
#  [2258, 'Aleksandr Yakovlevich Povzner', 1915],
#  [2261, 'Boris Khvedelidze', 1915],
#  [2308, 'Clarence Francis Stephens', 1917],
#  [2332, 'Yurii Alekseevich Mitropolskii', 1917],
#  [2325, 'Nikolai Sergeevitch Krylov', 1917],
#  [2323, 'Moshe Livsic', 1917],
#  [2322, 'Luna Isaac Mishoe', 1917],
#  [2357, 'Vincent McRae', 1918],
#  [2340, 'Hsien C Wang', 1918],
#  [2355, 'Sheila Power Tinney', 1918],
#  [2356, 'Tibor Szele', 1918],
#  [2337, 'Geoffrey Kneebone', 1918],
#  [2342, 'Ivan Vidav', 1918],
#  [2344, 'Jacy Monteiro', 1918],
#  [2361, 'Alexander Andreevich Samarskii', 1919],
#  [2362, 'Clifford Ambrose Truesdell III', 1919],
#  [2364, 'Erwin Hiebert', 1919],
#  [2366, 'Georgii Dmitrievich Suvorov', 1919],
#  [2370, 'Jaap Seidel', 1919],
#  [2371, 'Jim Wilkinson', 1919],
#  [2377, 'Raimundo Chela', 1919],
#  [2380, 'Wen-Tsun Wu', 1919],
#  [2360, 'Aleksei Vasilevich Pogorelov', 1919],
#  [2372, 'Julia Bowman Robinson', 1919],
#  [2388, 'Calyampudi Radhakrishna Rao', 1920],
#  [2394, 'George Butcher', 1920],
#  [2397, 'Jeremiah Certaine', 1920],
#  [2408, 'Udita Narayana Singh', 1920],
#  [2407, 'Sree Pillai', 1920],
#  [2410, 'Wolfgang Gaschütz', 1920],
#  [2389, 'Donald Pack', 1920],
#  [2402, "Mark Krasnosel'skii", 1920],
#  [2387, 'Bill Boone', 1920],
#  [2386, 'Basil Rennie', 1920],
#  [2424, 'Horst Tietz', 1921],
#  [2420, 'Ferenc Radó', 1921],
#  [2422, 'Harry Reuter', 1921],
#  [2423, 'Henri Garnir', 1921],
#  [2414, 'Bent Christiansen', 1921],
#  [2427, 'John Quill Taylor King', 1921],
#  [2449, 'Jack Warga', 1922],
#  [2455, 'Olga Alexandrovna Ladyzhenskaya', 1922],
#  [2457, 'Vladimir Aleksandrovich Marchenko', 1922],
#  [2452, 'Lazar Matveevich Gluskin', 1922],
#  [2459, 'Aleksei Alekseevich Dezin', 1923],
#  [2480, 'Kuo-Tsai Chen', 1923],
#  [2474, 'Henri Cabannes', 1923],
#  [2458, 'Adegoke Olubummo', 1923],
#  [2462, 'Blagoj Popov', 1923],
#  [2477, 'Igor Rostislavovich Shafarevich', 1923],
#  [2481, 'Mikhail Iosiphovich Kadets', 1923],
#  [2465, 'Dan Mostow', 1923],
#  [2468, 'Enrico Magenes', 1923],
#  [2461, 'Beauregard Stubblefield', 1923],
#  [2491, 'Yitz Herstein', 1923],
#  [2489, 'Vasilii Sergeevich Vladimirov', 1923],
#  [2467, 'Dionisio Gallarati', 1923],
#  [2501, 'Evgenii B Dynkin', 1924],
#  [2514, 'Nikolai Nikolaevich Krasovskii', 1924],
#  [2515, 'Norrie Everitt', 1924],
#  [2499, 'Elena Moldovan Popoviciu', 1924],
#  [2496, 'Benoit Mandelbrot', 1924],
#  [2516, 'Ottó Steinfeld', 1924],
#  [2497, 'Clive William Kilmister', 1924],
#  [2529, 'Guri Ivanovich Marchuk', 1925],
#  [2531, 'Hans-Jürgen Hoehnke', 1925],
#  [2540, 'Olga Arsenievna Oleinik', 1925],
#  [2523, 'Elza Furtado Gomide', 1925],
#  [2544, 'Shanti Swarup Gupta', 1925],
#  [2520, 'Adelina Gutiérrez Moreno', 1925],
#  [2522, 'Chris Zeeman', 1925],
#  [2525, 'Fred Wright', 1925],
#  [2533, 'John Torrence Tate', 1925],
#  [2524, 'Eugene Graham', 1925],
#  [2558, 'James Clunie', 1926],
#  [2557, 'J A Green', 1926],
#  [2567, 'John Shepherdson', 1926],
#  [2556, 'Ivo Babuska', 1926],
#  [2547, 'Calogero Vinti', 1926],
#  [2574, 'Rebeca Cherep de Guber', 1926],
#  [2575, 'Rex Tims', 1926],
#  [2569, 'Magdalena Mouján', 1926],
#  [2583, 'Benjamin Moiseiwitsch', 1927],
#  [2592, 'Gyula Maurer', 1927],
#  [2590, 'Friedrich Horn', 1927],
#  [2588, 'Frank Levin', 1927],
#  [2605, 'Slamet Dajono', 1927],
#  [2585, 'Carlos Benjamin de Lyra', 1927],
#  [2602, 'Mikhail Mikhailovich Postnikov', 1927],
#  [2600, 'Marguerite Straus Frank', 1927],
#  [2586, 'Dimitrei D Stancu', 1927],
#  [2598, 'Joan Sylvia Lyttle Birman', 1927],
#  [2581, 'Alexander Ivanovich Skopin', 1927],
#  [2591, 'Geoffrey Shephard', 1927],
#  [2584, 'Brian Griffiths', 1927],
#  [2610, 'Charles Bell', 1928],
#  [2626, 'John F Nash', 1928],
#  [2637, 'Paul Butzer', 1928],
#  [2613, 'Donald Greenspan', 1928],
#  [2612, 'Chukwuka Okonjo', 1928],
#  [2611, 'Charles Costley', 1928],
#  [2632, 'Manuel Valdivia', 1928],
#  [2621, 'Iain Adamson', 1928],
#  [2640, 'Aleksei Kostrikin', 1929],
#  [2647, 'Elemér Kiss', 1929],
#  [2651, 'Ilya Iosifovich Piatetski-Shapiro', 1929],
#  [2652, 'Jock Hoe', 1929],
#  [2646, 'Douglas Munn', 1929],
#  [2661, 'Yurii Vasilevich Prokhorov', 1929],
#  [2653, 'Laurence Raymond Harper', 1929],
#  [2655, 'Margaret Rayner', 1929],
#  [2662, 'Anatolii Asirovich Goldberg', 1930],
#  [2663, 'Anatolii Volodymyrovych Skorokhod', 1930],
#  [2670, 'Gregory Maxwell Kelly', 1930],
#  [2676, 'James Ezeilo', 1930],
#  [2678, 'Juan Jorge Schäffer', 1930],
#  [2672, 'Ismail Mohamed', 1930],
#  [2665, 'Bruce Kellogg', 1930],
#  [2664, 'Bill Morton', 1930],
#  [2684, 'Satoshi Suzuki', 1930],
#  [2681, 'Norman Alling', 1930],
#  [2699, 'James Murray', 1931],
#  [2706, 'Valentina Mikhailovna Borok', 1931],
#  [2726, 'Mary Warner', 1932],
#  [2725, 'Marian Țarină', 1932],
#  [2718, 'Joachim Neubüser', 1932],
#  [2713, 'Gilberto Loibel', 1932],
#  [2747, 'Ray Vanstone', 1933],
#  [2737, 'Frederick Justin Almgren', 1933],
#  [2742, 'John Frankland Rigby', 1933],
#  [2745, 'Mikhail Moiseevich Lesokhin', 1933],
#  [2743, 'Joshua Leslie', 1933],
#  [2735, 'Dorothy Foster', 1933],
#  [2738, 'Gary Roach', 1933],
#  [2752, 'Iossif Vladimirovich Ostrovskii', 1934],
#  [2760, 'Soraya Sherif', 1934],
#  [2755, 'Ludwig Faddeev', 1934],
#  [2751, 'Ene-Margit Tiit', 1934],
#  [2773, 'Nicolas Bourbaki', 1935],
#  [2768, 'Hitoshi Kumano-Go', 1935],
#  [2764, 'Bronius Grigelionis', 1935],
#  [2777, 'Yakov Grigorevich Sinai', 1935],
#  [2769, 'John Hildebrant', 1935],
#  [2771, 'Louise Szmir Hay', 1935],
#  [2790, 'Oleksandr Mikolaiovich Sharkovsky', 1936],
#  [2786, 'Judita Cofman', 1936],
#  [2793, 'Richard Schelp', 1936],
#  [2792, 'Peter Ladislaw Hammer', 1936],
#  [2791, 'Pavel Tichy', 1936],
#  [2778, 'Alexander Aleksandrovich Kirillov', 1936],
#  [2780, 'Dmitrii Viktorovich Anosov', 1936],
#  [2797, 'Umirzak Sultangazin', 1936],
#  [2796, 'Terry Wall', 1936],
#  [2810, 'John Knopfmacher', 1937],
#  [2814, 'Sunday Iyahen', 1937],
#  [2813, 'Ron Book', 1937],
#  [2812, 'Moshé Flato', 1937],
#  [2811, 'Leonid Andreevich Pastur', 1937],
#  [2817, 'Yuri Ivanovich Manin', 1937],
#  [2807, 'Horace Mochizuki', 1937],
#  [2806, 'Evgenii Yakovlevich Khruslov', 1937],
#  [2829, 'Hans Meinhardt', 1938],
#  [2818, 'Alex Craik', 1938],
#  [2822, 'Chidambaram Padmanabhan Ramanujam', 1938],
#  [2821, 'Bella Abramovna Subbotovskaya', 1938],
#  [2820, 'Anatoly Mykhailovych Samoilenko', 1938],
#  [2827, 'Fischer Sheffey Black', 1938],
#  [2842, 'Hendrika Swart', 1939],
#  [2837, 'Brian Sleeman', 1939],
#  [2847, 'Mary Lee Wheat Gray', 1939],
#  [2838, 'Calixto Calderón', 1939],
#  [2843, 'Herbert Pahlings', 1939],
#  [2853, 'Franciszek Szafraniec', 1940],
#  [2855, 'Linda Goldway Keen', 1940],
#  [2857, 'Aderemi Kuku', 1941],
#  [2862, 'George Olatokunbo Okikiolu', 1941],
#  [2861, 'Domokos Szász', 1941],
#  [2860, 'Derek Waller', 1941],
#  [2873, 'Patrick Keast', 1942],
#  [2875, 'Steve Rallis', 1942],
#  [2867, 'Alexandru Lupas', 1942],
#  [2877, 'Timothy Pedley', 1942],
#  [2878, 'Vitaly Vitalievich Fedorchuk', 1942],
#  [2882, 'Mikhael Leonidovich Gromov', 1943],
#  [2886, 'Margaret Hilary Ashworth Millington', 1944],
#  [2884, 'Abram Naumovich Trakhtman', 1944],
#  [2892, "John O'Connor", 1945],
#  [2902, 'Bill Thurston', 1946],
#  [2901, 'Anzelm Iwanik', 1946],
#  [2915, 'Ovide Arino', 1947],
#  [2919, 'Yuri Vladimirovich Matiyasevich', 1947],
#  [2917, 'Robert Edward Bowen', 1947],
#  [2916, 'Palle Jorgensen', 1947],
#  [2924, 'Laszlo Lovász', 1948],
#  [2923, 'John Carr', 1948],
#  [2932, 'Fritz Grunewald', 1949],
#  [2935, 'Qamil Haxhibeqiri', 1949],
#  [2937, 'Andrei Andreevich Bolibrukh', 1950],
#  [2943, 'Viktor Aleksandrovich Gorbunov', 1950],
#  [2939, 'Gamal Ismail', 1950],
#  [2941, 'Milojica Jacimovic', 1950],
#  [2948, 'Stein Arild Stromme', 1951],
#  [2950, 'Emilio Cafaro', 1952],
#  [2955, 'Dončo Dimovski', 1954],
#  [2960, 'Pavel Krejčí', 1954],
#  [2972, 'Akos Seress', 1958],
#  [2975, 'Benoît Perthame', 1959],
#  [2976, 'Lene Vestergaard Hau', 1959],
#  [2981, 'Juha Heinonen', 1960],
#  [2987, 'Richard Taylor', 1962],
#  [2990, 'Haim Nessyahu', 1964],
#  [2989, 'Artūras Dubickas', 1964],
#  [2994, 'Katherine Okikiolu', 1965],
#  [2995, 'Grigori Yakovlevich Perelman', 1966],
#  [2999, 'Marie Françoise Ouedraogo', 1967],
#  [3002, 'Andrei Yuryevich Okounkov', 1969],
#  [3003, 'David Cariolaro', 1969],
#  [3010, 'Qëndrim Gashi', 1984]]

# %%
### Query on just last or long name 
q_result= []
for t_pers in df_values: #[30:40]:
    
    p = list(t_pers)
    
    parts = p[1].replace("'", ' ')\
                .replace('-', ' ').replace('  ', ' ').split(' ')
    pp = [part for part in parts if len(part) > 2][-1]
    # print(pp)
    ppt = '"'+pp+'"'
    
    q = """
        SELECT DISTINCT ?s ?label ( substr(str(?date), 1, 4)  as ?birthYear) ?dct 
        WHERE {
                    # ?s a dbo:Person;
                           rdfs:label ?label . 
             OPTIONAL {?s   dbo:birthDate|dbp:birthDate ?date.}
              OPTIONAL { ?s dcterms:subject ?dct.
              FILTER (contains(str(?dct), 'births'))
        }
                   # FILTER (lang(?label) IN ('en', 'de', 'fr', 'it', 'es' )). 
                    # ?label bif:contains '(""" + ppt + """)'
        }
        """

    
    try:
        sparql = SPARQLWrapper(endpoint)
        sparql.setQuery(q)
        sparql.setReturnFormat(JSON)
        sparql.setMethod('POST')
        qr = sparql.queryAndConvert()
        r = [l for l in spqf.sparql_result_to_list(qr)]
        q_result.append(p + [r[:20]])
    except Exception as e:
        
        print(e)

        ttt = p + [str(e)]
        with open("data/logs_1.csv", "a") as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
            wr.writerow(ttt)

# %%
len(q_result), q_result[90:100]
# Out:
# (735,
#  [[357, 'Nicole-Reine Etable de Labrière', 1723, []],
#   [380,
#    'Monteiro da Rocha',
#    1734,
#    [['http://dbpedia.org/resource/Caio_Vidal',
#      'Caio Vidal Rocha',
#      '2000',
#      'http://dbpedia.org/resource/Category:2000_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'José Cayetano Valadés Rocha',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carla_Salomé_Rocha',
#      'Carla Salomé Rocha',
#      '1990',
#      'http://dbpedia.org/resource/Category:1990_births'],
#     ['http://dbpedia.org/resource/Carla_Salomé_Rocha',
#      'Carla Salomé Rocha',
#      '1990',
#      'http://dbpedia.org/resource/Category:1990_births'],
#     ['http://dbpedia.org/resource/Carla_Salomé_Rocha',
#      'Carla Salomé Rocha',
#      '1990',
#      'http://dbpedia.org/resource/Category:1990_births'],
#     ['http://dbpedia.org/resource/Carles_Fontserè',
#      'José Cayetano Valadés Rocha',
#      '1916',
#      'http://dbpedia.org/resource/Category:1916_births'],
#     ['http://dbpedia.org/resource/Carlo_Pellion_di_Persano',
#      'José Cayetano Valadés Rocha',
#      '1806',
#      'http://dbpedia.org/resource/Category:1806_births'],
#     ['http://dbpedia.org/resource/Carlos_Mayolo',
#      'José Cayetano Valadés Rocha',
#      '1945',
#      'http://dbpedia.org/resource/Category:1945_births'],
#     ['http://dbpedia.org/resource/Carlos_Robles_(Colombian_footballer)',
#      'Carlos Robles Rocha',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Carmen_Campagne',
#      'José Cayetano Valadés Rocha',
#      '1959',
#      'http://dbpedia.org/resource/Category:1959_births'],
#     ['http://dbpedia.org/resource/Cate_Shortland',
#      'José Cayetano Valadés Rocha',
#      '1968',
#      'http://dbpedia.org/resource/Category:1968_births'],
#     ['http://dbpedia.org/resource/Robert_McCormick_Adams_Jr.',
#      'José Cayetano Valadés Rocha',
#      '1926',
#      'http://dbpedia.org/resource/Category:1926_births'],
#     ['http://dbpedia.org/resource/Robert_de_la_Rocha',
#      'Robert de la Rocha',
#      '1937',
#      'http://dbpedia.org/resource/Category:1937_births'],
#     ['http://dbpedia.org/resource/Robert_de_la_Rocha',
#      'Roberto de la Rocha',
#      '1937',
#      'http://dbpedia.org/resource/Category:1937_births'],
#     ['http://dbpedia.org/resource/Roberto_Rocha',
#      'Roberto Rocha',
#      '1965',
#      'http://dbpedia.org/resource/Category:1965_births'],
#     ['http://dbpedia.org/resource/Roberto_Rocha',
#      'Roberto Rocha',
#      '1965',
#      'http://dbpedia.org/resource/Category:1965_births'],
#     ['http://dbpedia.org/resource/Rodrigo_Rocha',
#      'Rodrigo Rocha',
#      '1985',
#      'http://dbpedia.org/resource/Category:1985_births'],
#     ['http://dbpedia.org/resource/Rodrigo_Tiuí',
#      'Rodrigo Bonifácio da Rocha',
#      '1985',
#      'http://dbpedia.org/resource/Category:1985_births'],
#     ['http://dbpedia.org/resource/Romeu_Rocha',
#      'Romeu Rocha',
#      '1986',
#      'http://dbpedia.org/resource/Category:1986_births'],
#     ['http://dbpedia.org/resource/Rosângela_Rocha',
#      'Rosângela Rocha',
#      '1962',
#      'http://dbpedia.org/resource/Category:1962_births']]],
#   [382,
#    'Antonio Mario Lorgna',
#    1735,
#    [['http://dbpedia.org/resource/Giocondo_Pio_Lorgna',
#      'Giocondo Lorgna',
#      '1870',
#      'http://dbpedia.org/resource/Category:1870_births'],
#     ['http://dbpedia.org/resource/Giocondo_Pio_Lorgna',
#      'Giocondo Pio Lorgna',
#      '1870',
#      'http://dbpedia.org/resource/Category:1870_births'],
#     ['http://dbpedia.org/resource/Antonio_Maria_Lorgna',
#      'Antonio Maria Lorgna',
#      '1735',
#      'http://dbpedia.org/resource/Category:1735_births'],
#     ['http://dbpedia.org/resource/Antonio_Maria_Lorgna',
#      'Antonio Maria Lorgna',
#      '1735',
#      'http://dbpedia.org/resource/Category:1735_births'],
#     ['http://dbpedia.org/resource/Antonio_Maria_Lorgna',
#      'Antonio Maria Lorgna',
#      '1735',
#      'http://dbpedia.org/resource/Category:1735_births'],
#     ['http://dbpedia.org/resource/Antonio_Maria_Lorgna',
#      'Antonio Maria Lorgna',
#      '1735',
#      'http://dbpedia.org/resource/Category:1735_births'],
#     ['http://dbpedia.org/resource/Antonio_Maria_Lorgna',
#      'Antonio Maria Lorgna',
#      '1735',
#      'http://dbpedia.org/resource/Category:1735_births'],
#     ['http://dbpedia.org/resource/Antonio_Maria_Lorgna',
#      'Antonio Maria Lorgna',
#      '1735',
#      'http://dbpedia.org/resource/Category:1735_births']]],
#   [381,
#    'Alexandre-Theophile Vandermonde',
#    1735,
#    [['http://dbpedia.org/resource/Charles-Augustin_Vandermonde',
#      'Charles-Augustin Vandermonde',
#      '',
#      'http://dbpedia.org/resource/Category:1727_births'],
#     ['http://dbpedia.org/resource/Charles-Augustin_Vandermonde',
#      'Charles-Augustin Vandermonde',
#      '',
#      'http://dbpedia.org/resource/Category:1727_births']]],
#   [394,
#    'Pietro Giannini',
#    1740,
#    [['http://dbpedia.org/resource/Eli_Giannini',
#      'Eli Giannini',
#      '1956',
#      'http://dbpedia.org/resource/Category:1956_births'],
#     ['http://dbpedia.org/resource/Dennis_Giannini',
#      'Dennis Giannini',
#      '1950',
#      'http://dbpedia.org/resource/Category:1950_births'],
#     ['http://dbpedia.org/resource/Humberto_Giannini',
#      'Humberto Giannini',
#      '1927',
#      'http://dbpedia.org/resource/Category:1927_births'],
#     ['http://dbpedia.org/resource/Humberto_Giannini',
#      'Humberto Giannini',
#      '1927',
#      'http://dbpedia.org/resource/Category:1927_births'],
#     ['http://dbpedia.org/resource/Humberto_Giannini',
#      'Humberto Giannini',
#      '1927',
#      'http://dbpedia.org/resource/Category:1927_births'],
#     ['http://dbpedia.org/resource/Jorge_Giannini',
#      'Jorge Giannini',
#      '1948',
#      'http://dbpedia.org/resource/Category:1948_births'],
#     ['http://dbpedia.org/resource/Vittorio_Giannini',
#      'Vittorio Giannini',
#      '',
#      'http://dbpedia.org/resource/Category:1903_births'],
#     ['http://dbpedia.org/resource/Vittorio_Giannini',
#      'Vittorio Giannini',
#      '',
#      'http://dbpedia.org/resource/Category:1903_births'],
#     ['http://dbpedia.org/resource/Vittorio_Giannini',
#      'Vittorio Giannini',
#      '',
#      'http://dbpedia.org/resource/Category:1903_births'],
#     ['http://dbpedia.org/resource/Vittorio_Giannini',
#      'Vittorio Giannini',
#      '',
#      'http://dbpedia.org/resource/Category:1903_births'],
#     ['http://dbpedia.org/resource/Vittorio_Giannini',
#      'Vittorio Giannini',
#      '',
#      'http://dbpedia.org/resource/Category:1903_births'],
#     ['http://dbpedia.org/resource/Massimo_Severo_Giannini',
#      'Massimo Severo Giannini',
#      '1915',
#      'http://dbpedia.org/resource/Category:1915_births'],
#     ['http://dbpedia.org/resource/Massimo_Severo_Giannini',
#      'Massimo Severo Giannini',
#      '1915',
#      'http://dbpedia.org/resource/Category:1915_births'],
#     ['http://dbpedia.org/resource/Giancarlo_Giannini',
#      'Giancarlo Giannini',
#      '1942',
#      'http://dbpedia.org/resource/Category:1942_births'],
#     ['http://dbpedia.org/resource/Giancarlo_Giannini',
#      'Giancarlo Giannini',
#      '1942',
#      'http://dbpedia.org/resource/Category:1942_births'],
#     ['http://dbpedia.org/resource/Giancarlo_Giannini',
#      'Giancarlo Giannini',
#      '1942',
#      'http://dbpedia.org/resource/Category:1942_births'],
#     ['http://dbpedia.org/resource/Giancarlo_Giannini',
#      'Giancarlo Giannini',
#      '1942',
#      'http://dbpedia.org/resource/Category:1942_births'],
#     ['http://dbpedia.org/resource/Giancarlo_Giannini',
#      'Giancarlo Giannini',
#      '1942',
#      'http://dbpedia.org/resource/Category:1942_births'],
#     ['http://dbpedia.org/resource/Giancarlo_Giannini',
#      'Giancarlo Giannini',
#      '1942',
#      'http://dbpedia.org/resource/Category:1942_births'],
#     ['http://dbpedia.org/resource/Giancarlo_Giannini',
#      'Giancarlo Giannini',
#      '1942',
#      'http://dbpedia.org/resource/Category:1942_births']]],
#   [396,
#    'John Wilson',
#    1741,
#    [['http://dbpedia.org/resource/Cairine_Wilson',
#      'Cairine Wilson',
#      '1885',
#      'http://dbpedia.org/resource/Category:1885_births'],
#     ['http://dbpedia.org/resource/Cairine_Wilson',
#      'Cairine Wilson',
#      '1885',
#      'http://dbpedia.org/resource/Category:1885_births'],
#     ['http://dbpedia.org/resource/Cairine_Wilson',
#      'Cairine Wilson',
#      '1885',
#      'http://dbpedia.org/resource/Category:1885_births'],
#     ['http://dbpedia.org/resource/Cairine_Wilson',
#      'Cairine Wilson',
#      '1885',
#      'http://dbpedia.org/resource/Category:1885_births'],
#     ['http://dbpedia.org/resource/Cairine_Wilson',
#      'Cairine Wilson',
#      '1885',
#      'http://dbpedia.org/resource/Category:1885_births'],
#     ['http://dbpedia.org/resource/Cairine_Wilson',
#      'Cairine Wilson',
#      '1885',
#      'http://dbpedia.org/resource/Category:1885_births'],
#     ['http://dbpedia.org/resource/Cal_Wilson',
#      'Cal Wilson',
#      '1970',
#      'http://dbpedia.org/resource/Category:1970_births'],
#     ['http://dbpedia.org/resource/Caleb_Wilson',
#      'Caleb Wilson',
#      '1996',
#      'http://dbpedia.org/resource/Category:1996_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson (pemain sepak bola kelahiran 1992)',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births'],
#     ['http://dbpedia.org/resource/Callum_Wilson',
#      'Callum Wilson',
#      '1992',
#      'http://dbpedia.org/resource/Category:1992_births']]],
#   [399,
#    'Johann(III) Bernoulli',
#    1744,
#    [['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Daniel_Bernoulli',
#      'Daniel Bernoulli',
#      '1700',
#      'http://dbpedia.org/resource/Category:1700_births'],
#     ['http://dbpedia.org/resource/Hans_Benno_Bernoulli',
#      'Hans Bernoulli',
#      '1876',
#      'http://dbpedia.org/resource/Category:1876_births'],
#     ['http://dbpedia.org/resource/Hans_Benno_Bernoulli',
#      'Hans Bernoulli',
#      '1876',
#      'http://dbpedia.org/resource/Category:1876_births'],
#     ['http://dbpedia.org/resource/Hans_Benno_Bernoulli',
#      'Hans Benno Bernoulli',
#      '1876',
#      'http://dbpedia.org/resource/Category:1876_births'],
#     ['http://dbpedia.org/resource/Jacob_Bernoulli',
#      'Jakob Bernoulli',
#      '1655',
#      'http://dbpedia.org/resource/Category:1655_births'],
#     ['http://dbpedia.org/resource/Jacob_Bernoulli',
#      'Jacob Bernoulli',
#      '1655',
#      'http://dbpedia.org/resource/Category:1655_births']]],
#   [401, 'Adrien Quentin Buée', 1745, []],
#   [417,
#    'Lorenzo Mascheroni',
#    1750,
#    [['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Ernesto_Mascheroni',
#      'Ernesto Mascheroni',
#      '1907',
#      'http://dbpedia.org/resource/Category:1907_births'],
#     ['http://dbpedia.org/resource/Fabio_Mascheroni',
#      'Fabio Mascheroni',
#      '1977',
#      'http://dbpedia.org/resource/Category:1977_births'],
#     ['http://dbpedia.org/resource/Oliviero_Mascheroni',
#      'Oliviero Mascheroni',
#      '1914',
#      'http://dbpedia.org/resource/Category:1914_births'],
#     ['http://dbpedia.org/resource/Oliviero_Mascheroni',
#      'Oliviero Mascheroni',
#      '1914',
#      'http://dbpedia.org/resource/Category:1914_births'],
#     ['http://dbpedia.org/resource/Leonardo_Mascheroni',
#      'Leonardo Mascheroni',
#      '',
#      'http://dbpedia.org/resource/Category:1935_births'],
#     ['http://dbpedia.org/resource/Leonardo_Mascheroni',
#      'Leonardo Mascheroni',
#      '',
#      'http://dbpedia.org/resource/Category:1935_births'],
#     ['http://dbpedia.org/resource/Angelo_Mascheroni',
#      'Angelo Mascheroni',
#      '',
#      'http://dbpedia.org/resource/Category:1855_births'],
#     ['http://dbpedia.org/resource/Angelo_Mascheroni',
#      'Angelo Mascheroni',
#      '',
#      'http://dbpedia.org/resource/Category:1855_births'],
#     ['http://dbpedia.org/resource/Angelo_Mascheroni',
#      'Angelo Mascheroni',
#      '',
#      'http://dbpedia.org/resource/Category:1855_births'],
#     ['http://dbpedia.org/resource/Edoardo_Mascheroni',
#      'Edoardo Mascheroni',
#      '',
#      'http://dbpedia.org/resource/Category:1852_births']]],
#   [419,
#    'William Morgan',
#    1750,
#    [['http://dbpedia.org/resource/Candice_Morgan',
#      'Candice Morgan',
#      '1980',
#      'http://dbpedia.org/resource/Category:1980_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'Lina Morgan',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'Lina Morgan',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'Lina Morgan',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'Lina Morgan',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'Lina Morgan',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'Lina Morgan',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carey_Morgan',
#      'Carey Morgan',
#      '1884',
#      'http://dbpedia.org/resource/Category:1884_births'],
#     ['http://dbpedia.org/resource/Carles_Fontserè',
#      'Lina Morgan',
#      '1916',
#      'http://dbpedia.org/resource/Category:1916_births'],
#     ['http://dbpedia.org/resource/Carles_Fontserè',
#      'Lina Morgan',
#      '1916',
#      'http://dbpedia.org/resource/Category:1916_births'],
#     ['http://dbpedia.org/resource/Carles_Fontserè',
#      'Lina Morgan',
#      '1916',
#      'http://dbpedia.org/resource/Category:1916_births'],
#     ['http://dbpedia.org/resource/Carles_Fontserè',
#      'Lina Morgan',
#      '1916',
#      'http://dbpedia.org/resource/Category:1916_births'],
#     ['http://dbpedia.org/resource/Carles_Fontserè',
#      'Lina Morgan',
#      '1916',
#      'http://dbpedia.org/resource/Category:1916_births'],
#     ['http://dbpedia.org/resource/Carles_Fontserè',
#      'Lina Morgan',
#      '1916',
#      'http://dbpedia.org/resource/Category:1916_births'],
#     ['http://dbpedia.org/resource/Carlo_Pellion_di_Persano',
#      'Lina Morgan',
#      '1806',
#      'http://dbpedia.org/resource/Category:1806_births'],
#     ['http://dbpedia.org/resource/Carlo_Pellion_di_Persano',
#      'Lina Morgan',
#      '1806',
#      'http://dbpedia.org/resource/Category:1806_births'],
#     ['http://dbpedia.org/resource/Carlo_Pellion_di_Persano',
#      'Lina Morgan',
#      '1806',
#      'http://dbpedia.org/resource/Category:1806_births'],
#     ['http://dbpedia.org/resource/Carlo_Pellion_di_Persano',
#      'Lina Morgan',
#      '1806',
#      'http://dbpedia.org/resource/Category:1806_births'],
#     ['http://dbpedia.org/resource/Carlo_Pellion_di_Persano',
#      'Lina Morgan',
#      '1806',
#      'http://dbpedia.org/resource/Category:1806_births'],
#     ['http://dbpedia.org/resource/Carlo_Pellion_di_Persano',
#      'Lina Morgan',
#      '1806',
#      'http://dbpedia.org/resource/Category:1806_births']]]])

# %% [markdown]
# ### New identification attempt

# %%
l_match = []
l_no_match_alternative = []
l_no_match = []
for r in q_result:  #[:20]:
    
    lm = []
    if len(r[3]) > 0:
        # for each element in the DBPedia answer
        for e in r[3]:
            
            # take the date if it exists
            if e[2]:
                d3 = e[2]
                try:
                    ### Restrict time span for better precision ! 
                    if ((r[2] <= int(d3) + 0 ) and (r[2] >= int(d3) - 0 )):
                        lm =[r[0],r[1],r[2], d3, e[1], e[0]]
                        l_match.append(lm)
                except Exception as e:
                    print(r[0],r[1],r[2],e)
                    
            if len(lm) > 0:
                break

        if len(lm) == 0:
            l_no_match_alternative.append(r)
    else:
        l_no_match.append(r)
# Out:
# 2 Jia Xian 1010 invalid literal for int() with base 10: '--04'
# 2 Jia Xian 1010 invalid literal for int() with base 10: '--04'
# 2 Jia Xian 1010 invalid literal for int() with base 10: '--04'
# 2 Jia Xian 1010 invalid literal for int() with base 10: '--04'
# 2 Jia Xian 1010 invalid literal for int() with base 10: '--03'
# 6 Shen Kua 1031 invalid literal for int() with base 10: 'Nove'
# 16 Al-Samawal 1130 invalid literal for int() with base 10: 'c. 1'
# 16 Al-Samawal 1130 invalid literal for int() with base 10: 'c. 1'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 17 Sharaf al-Din al-Tusi 1135 invalid literal for int() with base 10: 'http'
# 22 Li Zhi 1192 invalid literal for int() with base 10: '--12'
# 22 Li Zhi 1192 invalid literal for int() with base 10: '--12'
# 22 Li Zhi 1192 invalid literal for int() with base 10: '--12'
# 22 Li Zhi 1192 invalid literal for int() with base 10: '--12'
# 22 Li Zhi 1192 invalid literal for int() with base 10: '--12'
# 22 Li Zhi 1192 invalid literal for int() with base 10: '--12'
# 22 Li Zhi 1192 invalid literal for int() with base 10: '--12'
# 22 Li Zhi 1192 invalid literal for int() with base 10: 'May '
# 24 Albertus 1200 invalid literal for int() with base 10: 'Albe'
# 28 Johannes Campanus 1220 invalid literal for int() with base 10: 'c. 1'
# 28 Johannes Campanus 1220 invalid literal for int() with base 10: 'c. 1'
# 28 Johannes Campanus 1220 invalid literal for int() with base 10: 'c. 1'
# 28 Johannes Campanus 1220 invalid literal for int() with base 10: 'c. 1'
# 28 Johannes Campanus 1220 invalid literal for int() with base 10: 'c. 1'
# 28 Johannes Campanus 1220 invalid literal for int() with base 10: 'c. 1'
# 29 Muhyi l'din al-Maghribi 1220 invalid literal for int() with base 10: 'Betw'
# 29 Muhyi l'din al-Maghribi 1220 invalid literal for int() with base 10: 'Betw'
# 29 Muhyi l'din al-Maghribi 1220 invalid literal for int() with base 10: 'c. 1'
# 29 Muhyi l'din al-Maghribi 1220 invalid literal for int() with base 10: 'c. 1'
# 29 Muhyi l'din al-Maghribi 1220 invalid literal for int() with base 10: 'c. 1'
# 29 Muhyi l'din al-Maghribi 1220 invalid literal for int() with base 10: 'c. 1'
# 35 Shams al-Din al-Samarqandi 1250 invalid literal for int() with base 10: 'Unkn'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 42 Thomas Bradwardine 1295 invalid literal for int() with base 10: 'c. 1'
# 44 Al-Khalili 1320 invalid literal for int() with base 10: '--11'
# 44 Al-Khalili 1320 invalid literal for int() with base 10: 'c.'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 45 Nicholas Oresme 1323 invalid literal for int() with base 10: 'c. 1'
# 46 Mahendra Suri 1340 invalid literal for int() with base 10: '?'
# 46 Mahendra Suri 1340 invalid literal for int() with base 10: '?'
# 46 Mahendra Suri 1340 invalid literal for int() with base 10: '?'
# 46 Mahendra Suri 1340 invalid literal for int() with base 10: '?'
# 48 Madhava 1350 invalid literal for int() with base 10: 'Febr'
# 52 al-Kashi 1390 invalid literal for int() with base 10: 'befo'
# 52 al-Kashi 1390 invalid literal for int() with base 10: 'befo'
# 52 al-Kashi 1390 invalid literal for int() with base 10: 'befo'
# 70 John Maior 1469 invalid literal for int() with base 10: 'Augu'
# 70 John Maior 1469 invalid literal for int() with base 10: 'Augu'
# 70 John Maior 1469 invalid literal for int() with base 10: 'c. 9'
# 99 Cheng Dawei 1533 invalid literal for int() with base 10: 'Augu'
# 101 Egnatio Danti 1536 invalid literal for int() with base 10: 'Apri'
# 101 Egnatio Danti 1536 invalid literal for int() with base 10: 'Apri'
# 101 Egnatio Danti 1536 invalid literal for int() with base 10: 'Apri'
# 101 Egnatio Danti 1536 invalid literal for int() with base 10: 'Apri'
# 101 Egnatio Danti 1536 invalid literal for int() with base 10: 'Apri'
# 101 Egnatio Danti 1536 invalid literal for int() with base 10: 'Apri'
# 101 Egnatio Danti 1536 invalid literal for int() with base 10: 'Apri'
# 106 Thomas Allen 1540 invalid literal for int() with base 10: 'Dece'
# 106 Thomas Allen 1540 invalid literal for int() with base 10: 'Dece'
# 131 Xu Guang-qi 1562 invalid literal for int() with base 10: 'Unkn'
# 167 Claude Hardy 1598 invalid literal for int() with base 10: '--07'
# 503 John Walsh 1786 invalid literal for int() with base 10: 'c.19'
# 506 John Cruickshank 1787 invalid literal for int() with base 10: 'Sept'
# 506 John Cruickshank 1787 invalid literal for int() with base 10: 'Sept'
# 764 James Moriarty 1835 invalid literal for int() with base 10: 'Augu'
# 783 Jenő Hunyadi 1838 invalid literal for int() with base 10: 'c. 1'
# 783 Jenő Hunyadi 1838 invalid literal for int() with base 10: 'c. 1'
# 783 Jenő Hunyadi 1838 invalid literal for int() with base 10: 'c. 1'
# 832 James Stuart 1843 invalid literal for int() with base 10: 'c. 1'
# 832 James Stuart 1843 invalid literal for int() with base 10: 'c. 1'
# 832 James Stuart 1843 invalid literal for int() with base 10: 'c. 1'
# 907 Scott Lang 1850 invalid literal for int() with base 10: 'Unkn'
# 909 Sophie Willock Bryant 1850 invalid literal for int() with base 10: 'unkn'
# 909 Sophie Willock Bryant 1850 invalid literal for int() with base 10: 'unkn'
# 992 William Thomson 1856 invalid literal for int() with base 10: 'ca. '
# 1034 Frank Carey 1860 invalid literal for int() with base 10: 'http'
# 1065 William Peddie 1861 invalid literal for int() with base 10: 'Janu'
# 1166 Ralph Sampson 1866 invalid literal for int() with base 10: '--10'
# 1166 Ralph Sampson 1866 invalid literal for int() with base 10: '--10'
# 1204 William Leslie Thomson 1868 invalid literal for int() with base 10: 'ca. '
# 1285 Robert d'Adhémar 1874 invalid literal for int() with base 10: 'Febr'
# 1285 Robert d'Adhémar 1874 invalid literal for int() with base 10: 'Febr'
# 1285 Robert d'Adhémar 1874 invalid literal for int() with base 10: 'Febr'
# 1285 Robert d'Adhémar 1874 invalid literal for int() with base 10: 'Febr'
# 1311 Evelyn Cave-Browne-Cave 1876 invalid literal for int() with base 10: 'c. 1'
# 1328 G H Hardy 1877 invalid literal for int() with base 10: '--07'
# 1365 David Picken 1879 invalid literal for int() with base 10: 'Marc'
# 1365 David Picken 1879 invalid literal for int() with base 10: 'Janu'
# 1548 William Brash 1888 invalid literal for int() with base 10: 'Dece'
# 1573 Thomas Lancaster Wren 1889 invalid literal for int() with base 10: '--10'
# 1573 Thomas Lancaster Wren 1889 invalid literal for int() with base 10: '--10'
# 1573 Thomas Lancaster Wren 1889 invalid literal for int() with base 10: '--10'
# 1573 Thomas Lancaster Wren 1889 invalid literal for int() with base 10: '--10'
# 1574 Vyacheslaw Vassilievich Stepanov 1889 invalid literal for int() with base 10: 'Augu'
# 1574 Vyacheslaw Vassilievich Stepanov 1889 invalid literal for int() with base 10: '--11'
# 1606 Otto Yulyevich Schmidt 1891 invalid literal for int() with base 10: '--06'
# 1606 Otto Yulyevich Schmidt 1891 invalid literal for int() with base 10: '--06'
# 1606 Otto Yulyevich Schmidt 1891 invalid literal for int() with base 10: '--06'
# 1606 Otto Yulyevich Schmidt 1891 invalid literal for int() with base 10: '--06'
# 1606 Otto Yulyevich Schmidt 1891 invalid literal for int() with base 10: '--06'
# 1606 Otto Yulyevich Schmidt 1891 invalid literal for int() with base 10: '--06'
# 1600 James Cassels 1891 invalid literal for int() with base 10: 'Febr'
# 1656 Harry Schmidt 1894 invalid literal for int() with base 10: '--06'
# 1656 Harry Schmidt 1894 invalid literal for int() with base 10: '--06'
# 1656 Harry Schmidt 1894 invalid literal for int() with base 10: '--06'
# 1656 Harry Schmidt 1894 invalid literal for int() with base 10: '--06'
# 1656 Harry Schmidt 1894 invalid literal for int() with base 10: '--06'
# 1656 Harry Schmidt 1894 invalid literal for int() with base 10: '--06'
# 1905 Demetrios Kappos 1904 invalid literal for int() with base 10: 'Marc'
# 1960 Margaret E Boyle 1905 invalid literal for int() with base 10: 'Octo'
# 1966 Serge Mikhalovich Nikolski 1905 invalid literal for int() with base 10: '--10'
# 1981 Carlo Federici 1906 invalid literal for int() with base 10: '--02'
# 1981 Carlo Federici 1906 invalid literal for int() with base 10: '--02'
# 1974 Adolph Pavlovich Yushkevich 1906 invalid literal for int() with base 10: '--02'
# 1974 Adolph Pavlovich Yushkevich 1906 invalid literal for int() with base 10: '--02'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'Sept'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'Sept'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'befo'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'befo'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'befo'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'befo'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'befo'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'befo'
# 2049 Alfred Hoblitzelle Clifford 1908 invalid literal for int() with base 10: 'befo'
# 2079 Victor Amazaspovich Ambartsumian 1908 invalid literal for int() with base 10: '--09'
# 2079 Victor Amazaspovich Ambartsumian 1908 invalid literal for int() with base 10: '--09'
# 2079 Victor Amazaspovich Ambartsumian 1908 invalid literal for int() with base 10: '--09'
# 2079 Victor Amazaspovich Ambartsumian 1908 invalid literal for int() with base 10: '--09'
# 2085 Bill Penney 1909 invalid literal for int() with base 10: 'c. 1'
# 2136 Nikolai Vladimirovich Efimov 1910 invalid literal for int() with base 10: '--09'
# 2136 Nikolai Vladimirovich Efimov 1910 invalid literal for int() with base 10: '--09'
# 2267 James McConnell 1915 invalid literal for int() with base 10: 'c. 1'
# 2280 Warren Brothers 1915 invalid literal for int() with base 10: 'Mark'
# 2280 Warren Brothers 1915 invalid literal for int() with base 10: 'Jimm'
# 2337 Geoffrey Kneebone 1918 invalid literal for int() with base 10: 'Febr'
# 2337 Geoffrey Kneebone 1918 invalid literal for int() with base 10: '--03'
# 2371 Jim Wilkinson 1919 invalid literal for int() with base 10: '--07'
# 2371 Jim Wilkinson 1919 invalid literal for int() with base 10: '--07'
# 2371 Jim Wilkinson 1919 invalid literal for int() with base 10: '--07'
# 2388 Calyampudi Radhakrishna Rao 1920 invalid literal for int() with base 10: 'c. 1'
# 2533 John Torrence Tate 1925 invalid literal for int() with base 10: 'c.'
# 2611 Charles Costley 1928 invalid literal for int() with base 10: 'Quar'
# 2672 Ismail Mohamed 1930 invalid literal for int() with base 10: 'c. 1'
# 2773 Nicolas Bourbaki 1935 invalid literal for int() with base 10: 'c. 1'
# 2773 Nicolas Bourbaki 1935 invalid literal for int() with base 10: 'c. 1'
# 2773 Nicolas Bourbaki 1935 invalid literal for int() with base 10: 'c. 1'
# 2777 Yakov Grigorevich Sinai 1935 invalid literal for int() with base 10: '?'
# 2827 Fischer Sheffey Black 1938 invalid literal for int() with base 10: 'c.'
# 2902 Bill Thurston 1946 invalid literal for int() with base 10: 'Thir'

# %%
### Persons with no query answer
len(l_no_match), l_no_match[:5]
# Out:
# (91,
#  [[15, 'Gherard', 1114, []],
#   [50, 'Paramesvara', 1370, []],
#   [55, 'Nicholas Kryffs', 1401, []],
#   [73, 'Charles de Bouvelles', 1471, []],
#   [82, 'Petrus Apianus', 1495, []]])

# %%
len(l_match), l_match[:5]
# Out:
# (117,
#  [[6,
#    'Shen Kua',
#    1031,
#    '1031',
#    'Šen Kua',
#    'http://dbpedia.org/resource/Shen_Kuo'],
#   [94,
#    'Peter Ramus',
#    1515,
#    '1515',
#    'Petrus Ramus',
#    'http://dbpedia.org/resource/Petrus_Ramus'],
#   [221,
#    'Johann Hudde',
#    1628,
#    '1628',
#    'Johannes Hudde',
#    'http://dbpedia.org/resource/Johannes_Hudde'],
#   [382,
#    'Antonio Mario Lorgna',
#    1735,
#    '1735',
#    'Antonio Maria Lorgna',
#    'http://dbpedia.org/resource/Antonio_Maria_Lorgna'],
#   [430,
#    'Nikolai Fuss',
#    1755,
#    '1755',
#    'Nicolas Fuss',
#    'http://dbpedia.org/resource/Nicolas_Fuss']])

# %%
df_match_3 = pd.DataFrame(l_match)
df_match_3.columns = ['pk_mathshistory', 'name_year_mathshistory', 
                    'birth_year_mathshistory', 'birth_year_dbpedia', 'name_year_dbpedia', 'uri' ]
df_match_3.head()
# Out:
#    pk_mathshistory name_year_mathshistory  birth_year_mathshistory  \
# 0                6               Shen Kua                     1031
# 1               94            Peter Ramus                     1515
# 2              221           Johann Hudde                     1628
# 3              382   Antonio Mario Lorgna                     1735
# 4              430           Nikolai Fuss                     1755
#
#   birth_year_dbpedia     name_year_dbpedia  \
# 0               1031               Šen Kua
# 1               1515          Petrus Ramus
# 2               1628        Johannes Hudde
# 3               1735  Antonio Maria Lorgna
# 4               1755          Nicolas Fuss
#
#                                                 uri
# 0              http://dbpedia.org/resource/Shen_Kuo
# 1          http://dbpedia.org/resource/Petrus_Ramus
# 2        http://dbpedia.org/resource/Johannes_Hudde
# 3  http://dbpedia.org/resource/Antonio_Maria_Lorgna
# 4          http://dbpedia.org/resource/Nicolas_Fuss

# %%
## Explorer les données importées: on voit que les différences des noms sont importantes
# Configuration:  https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(df_match_3.sort_values(by='birth_year_mathshistory'), classes="display", scrollY="200px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="d38a4b10-2db1-4f3a-9950-7b5d871f7362" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pk_mathshistory</th>
#       <th>name_year_mathshistory</th>
#       <th>birth_year_mathshistory</th>
#       <th>birth_year_dbpedia</th>
#       <th>name_year_dbpedia</th>
#       <th>uri</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>pk_mathshistory</th><th>name_year_mathshistory</th><th>birth_year_mathshistory</th><th>birth_year_dbpedia</th><th>name_year_dbpedia</th><th>uri</th></tfoot></table>
# <script>
#     // We use a namespace per table (= the next curly bracket)
#     // to avoid conflicts between the various tables' data & dt_args
#     {
#         // Define the table data
#         const data = [[0, 6, "Shen Kua", 1031, "1031", "\u0160en Kua", "http://dbpedia.org/resource/Shen_Kuo"], [1, 94, "Peter Ramus", 1515, "1515", "Petrus Ramus", "http://dbpedia.org/resource/Petrus_Ramus"], [2, 221, "Johann Hudde", 1628, "1628", "Johannes Hudde", "http://dbpedia.org/resource/Johannes_Hudde"], [3, 382, "Antonio Mario Lorgna", 1735, "1735", "Antonio Maria Lorgna", "http://dbpedia.org/resource/Antonio_Maria_Lorgna"], [4, 430, "Nikolai Fuss", 1755, "1755", "Nicolas Fuss", "http://dbpedia.org/resource/Nicolas_Fuss"], [5, 446, "John Farey", 1766, "1766", "Joseph Farey", "http://dbpedia.org/resource/Joseph_Farey"], [6, 502, "Jean-Nicolas Nicollet", 1786, "1786", "Joseph Nicolas Nicollet", "http://dbpedia.org/resource/Joseph_Nicollet"], [7, 518, "Charles Hughes Terrot", 1790, "1790", "Charles Terrot", "http://dbpedia.org/resource/Charles_Terrot"], [8, 533, "Nikolai Ivanovich Lobachevsky", 1792, "1792", "Nikolai Lobachevsky", "http://dbpedia.org/resource/Nikolai_Lobachevsky"], [9, 553, "Nikolai Dmetrievich Brashman", 1796, "1796", "Nikolai Brashman", "http://dbpedia.org/resource/Nikolai_Brashman"], [10, 577, "Mikhail Vasilevich Ostrogradski", 1801, "1801", "Michai\u0142 Ostrogradski", "http://dbpedia.org/resource/Mikhail_Ostrogradsky"], [11, 599, "James Booth", 1806, "1806", "Evangeline Booth", "http://dbpedia.org/resource/Carlo_Pellion_di_Persano"], [12, 604, "J\u00f3zeph Petzval", 1807, "1807", "Josef Maximilian Petzval", "http://dbpedia.org/resource/Joseph_Petzval"], [13, 632, "Fernando Pio Rosellini", 1814, "1814", "Ferdinando Pio Rosellini", "http://dbpedia.org/resource/Ferdinando_Pio_Rosellini"], [14, 687, "August Yulevich Davidov", 1823, "1823", "August Davidov", "http://dbpedia.org/resource/August_Davidov"], [15, 707, "Mikhail Egorovich Vashchenko-Zakharchenko", 1825, "1825", "Mikhail Vaschenko-Zakharchenko", "http://dbpedia.org/resource/Mikhail_Vaschenko-Zakharchenko"], [16, 775, "Nicolai Vasilievich Bugaev", 1837, "1837", "Nikolai Bugaev", "http://dbpedia.org/resource/Nikolai_Bugaev"], [17, 770, "Aleksandr Nikolaevich Korkin", 1837, "1837", "Aleksandr Korkin", "http://dbpedia.org/resource/Aleksandr_Korkin"], [18, 840, "George-Henri Halphen", 1844, "1844", "Georges Henri Halphen", "http://dbpedia.org/resource/Georges_Henri_Halphen"], [19, 889, "L\u00f3r\u00e1nd E\u00f6tv\u00f6s", 1848, "1848", "Lor\u00e1nd E\u00f6tv\u00f6s", "http://dbpedia.org/resource/Lor\u00e1nd_E\u00f6tv\u00f6s"], [20, 959, "Ivan \u015aleszy\u0144ski", 1854, "1854", "Jan \u015aleszy\u0144ski", "http://dbpedia.org/resource/Jan_\u015aleszy\u0144ski"], [21, 994, "Aleksandr Mikhailovich Lyapunov", 1857, "1857", "Aleksandr Lyapunov", "http://dbpedia.org/resource/Aleksandr_Lyapunov"], [22, 998, "Henry Ernest Dudeney", 1857, "1857", "Henry Dudeney", "http://dbpedia.org/resource/Henry_Dudeney"], [23, 1027, "Samuil Osipovich Shatunovsky", 1859, "1859", "Samuil Shatunovsky", "http://dbpedia.org/resource/Samuil_Shatunovsky"], [24, 1071, "Fritz (Friedrich) B\u00fctzberger", 1862, "1862", "Fritz B\u00fctzberger", "http://dbpedia.org/resource/Fritz_B\u00fctzberger"], [25, 1213, "Sergei Alekseevich Chaplygin", 1869, "1869", "Sergey Chaplygin", "http://dbpedia.org/resource/Sergey_Chaplygin"], [26, 1206, "Benjamin Fedorovich Kagan", 1869, "1869", "Weniamin Fjodorowitsch Kagan", "http://dbpedia.org/resource/Benjamin_Kagan"], [27, 1254, "John Meiklejohn", 1872, "1872", "Alexander Meiklejohn", "http://dbpedia.org/resource/Alexander_Meiklejohn"], [28, 1286, "Andre-Louis Cholesky", 1875, "1875", "Andr\u00e9-Louis Cholesky", "http://dbpedia.org/resource/Andr\u00e9-Louis_Cholesky"], [29, 1377, "Evgeny Evgenievich Slutsky", 1880, "1880", "Eugen Slutsky", "http://dbpedia.org/resource/Eugen_Slutsky"], [30, 1550, "Yakov Davydovich Tamarkin", 1888, "1888", "Jacob Tamarkin", "http://dbpedia.org/resource/Jacob_Tamarkin"], [31, 1553, "Andrei Razmadze", 1889, "1889", "Andrea Razmadze", "http://dbpedia.org/resource/Andrea_Razmadze"], [32, 1570, "Ren\u00e9 Eug\u00e8ne Ga ...

# %% [markdown]
# #### Again new match using additional information

# %%
l_match_2 = []
l_no_match_alternative_2 = []
l_no_match_2 = []
for r in l_no_match_alternative:
    
    lm = []
    # for each element in the DBPedia answer
    for e in r[3]:

        # take the date if it exists
        if e[3] and 'birth' in e[3]:
            
            try:
                d3 = str(re.findall(r'\d{4}', e[3])[0])
                # print(d3)
                if (str(r[2])[:3] == str(d3)[:3]):
                    lm =[r[0],r[1],r[2], d3, e[1], e[0]]
                    l_match_2.append(lm)
            except Exception as e:
                print(r[0],r[1],r[2],e)
        if len(lm) > 0:
            break

    if len(lm) == 0:
        l_no_match_alternative_2.append(r)

# %%
len(l_match_2), l_match_2[:5]
# Out:
# (127,
#  [[23,
#    'John Sacrobosco',
#    1195,
#    '1195',
#    'Sacrobosco',
#    'http://dbpedia.org/resource/Johannes_de_Sacrobosco'],
#   [28,
#    'Johannes Campanus',
#    1220,
#    '1220',
#    'Campanus van Novara',
#    'http://dbpedia.org/resource/Campanus_of_Novara'],
#   [45,
#    'Nicholas Oresme',
#    1323,
#    '1320',
#    'Mikołaj z Oresme',
#    'http://dbpedia.org/resource/Nicole_Oresme'],
#   [88,
#    'Frederico Commandino',
#    1506,
#    '1509',
#    'Federico Commandino',
#    'http://dbpedia.org/resource/Federico_Commandino'],
#   [101,
#    'Egnatio Danti',
#    1536,
#    '1530',
#    'Vincenzo Danti',
#    'http://dbpedia.org/resource/Vincenzo_Danti']])

# %%
df_match_4 = pd.DataFrame(l_match_2)
df_match_4.columns = ['pk_mathshistory', 'name_year_mathshistory', 
                    'birth_year_mathshistory', 'birth_year_dbpedia', 'name_year_dbpedia', 'uri' ]
df_match_4.head()
# Out:
#    pk_mathshistory name_year_mathshistory  birth_year_mathshistory  \
# 0               23        John Sacrobosco                     1195
# 1               28      Johannes Campanus                     1220
# 2               45        Nicholas Oresme                     1323
# 3               88   Frederico Commandino                     1506
# 4              101          Egnatio Danti                     1536
#
#   birth_year_dbpedia    name_year_dbpedia  \
# 0               1195           Sacrobosco
# 1               1220  Campanus van Novara
# 2               1320     Mikołaj z Oresme
# 3               1509  Federico Commandino
# 4               1530       Vincenzo Danti
#
#                                                  uri
# 0  http://dbpedia.org/resource/Johannes_de_Sacrob...
# 1     http://dbpedia.org/resource/Campanus_of_Novara
# 2          http://dbpedia.org/resource/Nicole_Oresme
# 3    http://dbpedia.org/resource/Federico_Commandino
# 4         http://dbpedia.org/resource/Vincenzo_Danti

# %%
## Explorer les données importées: on voit que les différences des noms sont importantes
# Configuration:  https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(df_match_4.sort_values(by='birth_year_mathshistory'), classes="display", scrollY="200px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="1d8ea58a-22a8-4657-9e11-1b865c8623ae" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pk_mathshistory</th>
#       <th>name_year_mathshistory</th>
#       <th>birth_year_mathshistory</th>
#       <th>birth_year_dbpedia</th>
#       <th>name_year_dbpedia</th>
#       <th>uri</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>pk_mathshistory</th><th>name_year_mathshistory</th><th>birth_year_mathshistory</th><th>birth_year_dbpedia</th><th>name_year_dbpedia</th><th>uri</th></tfoot></table>
# <script>
#     // We use a namespace per table (= the next curly bracket)
#     // to avoid conflicts between the various tables' data & dt_args
#     {
#         // Define the table data
#         const data = [[0, 23, "John Sacrobosco", 1195, "1195", "Sacrobosco", "http://dbpedia.org/resource/Johannes_de_Sacrobosco"], [1, 28, "Johannes Campanus", 1220, "1220", "Campanus van Novara", "http://dbpedia.org/resource/Campanus_of_Novara"], [2, 45, "Nicholas Oresme", 1323, "1320", "Miko\u0142aj z Oresme", "http://dbpedia.org/resource/Nicole_Oresme"], [3, 88, "Frederico Commandino", 1506, "1509", "Federico Commandino", "http://dbpedia.org/resource/Federico_Commandino"], [4, 101, "Egnatio Danti", 1536, "1530", "Vincenzo Danti", "http://dbpedia.org/resource/Vincenzo_Danti"], [5, 129, "Philip van Lansberge", 1561, "1561", "Philippe van Lansberge", "http://dbpedia.org/resource/Philippe_van_Lansberge"], [6, 188, "Andrea Tacquet", 1612, "1612", "Andr\u00e9 Tacquet", "http://dbpedia.org/resource/Andr\u00e9_Tacquet"], [7, 274, "Leonty Filippovich Magnitsky", 1669, "1669", "Leonty Magnitsky", "http://dbpedia.org/resource/Leonty_Magnitsky"], [8, 336, "Giordano Riccati", 1709, "1707", "Vincenzo Riccati", "http://dbpedia.org/resource/Vincenzo_Riccati"], [9, 485, "Joz\u00e9f Ho\u00ebn\u00e9 Wronski", 1778, "1778", "Josef Ho\u00ebn\u00e9-Wronski", "http://dbpedia.org/resource/J\u00f3zef_Maria_Hoene-Wro\u0144ski"], [10, 539, "Franz Adolph Taurinus", 1794, "1794", "Franz Taurinus", "http://dbpedia.org/resource/Franz_Taurinus"], [11, 730, "Thomas Bond Sprague", 1830, "1833", "Benona Sprague", "http://dbpedia.org/resource/Benona_Sprague"], [12, 764, "James Moriarty", 1835, "1837", "David B. Moriarty", "http://dbpedia.org/resource/David_B._Moriarty"], [13, 824, "Otto Stolz", 1842, "1844", "Frank Stolz", "http://dbpedia.org/resource/Frank_Stolz"], [14, 833, "John S Mackay", 1843, "1840", "Robert Mackay (businessman)", "http://dbpedia.org/resource/Robert_Mackay_(businessman)"], [15, 865, "Platon Sergeevich Poretsky", 1846, "1846", "Platon Poretsky", "http://dbpedia.org/resource/Platon_Poretsky"], [16, 872, "George Greenhill", 1847, "1849", "Walter Greenhill", "http://dbpedia.org/resource/Walter_Greenhill"], [17, 870, "Egor Ivanovich Zolotarev", 1847, "1847", "Yegor Ivanovich Zolotarev", "http://dbpedia.org/resource/Yegor_Ivanovich_Zolotarev"], [18, 880, "\u00c9douard Benjamin Baillaud", 1848, "1848", "Benjamin Baillaud", "http://dbpedia.org/resource/Benjamin_Baillaud"], [19, 925, "James Taylor", 1851, "1857", "Calvin B. Taylor", "http://dbpedia.org/resource/Calvin_B._Taylor"], [20, 1016, "Boris Yakovlevic Bukreev", 1859, "1859", "Boris Yakovlevich Bukreev", "http://dbpedia.org/resource/Boris_Yakovlevich_Bukreev"], [21, 1112, "Matthew Fry", 1863, "1866", "Roger Fry", "http://dbpedia.org/resource/Roger_Fry"], [22, 1124, "Robert Hardie", 1864, "1866", "Mabel Hardie", "http://dbpedia.org/resource/Mabel_Hardie"], [23, 1173, "Gury Vasilievich Kolosov", 1867, "1867", "Gury Kolosov", "http://dbpedia.org/resource/Gury_Kolosov"], [24, 1172, "Dmitrii Matveevich Sintsov", 1867, "1867", "Dmitri Sintsov", "http://dbpedia.org/resource/Dmitrii_Sintsov"], [25, 1204, "William Leslie Thomson", 1868, "1867", "Robert Thomson Robinson", "http://dbpedia.org/resource/Robert_Thomson_Robinson"], [26, 1216, "David J Tweedie", 1870, "1877", "Hugh Tweedie", "http://dbpedia.org/resource/Hugh_Tweedie"], [27, 1243, "V Ramaswami Aiyar", 1871, "1879", "Chetpat Aiyar", "http://dbpedia.org/resource/C._P._Ramaswami_Iyer"], [28, 1257, "Onorato Nicoletti", 1872, "1871", "Major Nicoletti", "http://dbpedia.org/resource/Jos\u00e9_Nicoletti_Filho"], [29, 1262, "Alfred Young", 1873, "1871", "Cal Young", "http://dbpedia.org/resource/Cal_Young"], [30, 1285, "Robert d'Adh\u00e9mar", 1874, "1873", "Louis-Alfred-Adh\u00e9mar Rivet", "http://dbpedia.org/resource/Louis-Alfred-Adh\u00e9mar_Rivet"], [31, 1291, "Ernst Fischer", 1875, "1876", "Carl Fischer (pemeran)", "http://dbpedia.org/resource/Carl_Fischer_(actor)"], [32, 1287, "Archibald Milne", 1875, "1873", "Billy Milne (footballer, born 1873)", "http://dbpedia.org/resource/Billy_Milne_(footballer,_born_1873)"], [33, 1311, "Evelyn Cave-Br ...

# %%
l_no_match
# Out:
# []

# %%
l_match

# %%
lr = []
for r in q_result[:5]:
    # if len(r) > 1:
    print(len(r[1:]))
# Out:
# 1
# 1
# 1
# 2
# 0

# %%
lr = pd.Series([len(r[1:]) for r in q_result]); len(lr)
# Out:
# 3009

# %%
lr.describe()
# Out:
# count    3009.000000
# mean        1.714191
# std         3.360252
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        20.000000
# dtype: float64

# %%
len(lr[lr==0]), len(lr[lr > 1])
# Out:
# (702, 534)

# %%
lr[lr > 1].describe()
# Out:
# count    534.000000
# mean       6.338951
# std        6.060305
# min        2.000000
# 25%        2.000000
# 50%        3.000000
# 75%        8.000000
# max       20.000000
# dtype: float64

# %%
df_result = pd.DataFrame(q_result); df_result.head()
# Out:
#                                         0  \
# 0                [31, Guo Shoujing, 1231]
# 1                 [32, Ramon Llull, 1235]
# 2            [33, Jacob ben Tibbon, 1236]
# 3                    [34, Yang Hui, 1238]
# 4  [35, Shams al-Din al-Samarqandi, 1250]
#
#                                                    1  \
# 0  [http://dbpedia.org/resource/Guo_Shoujing, Guo...
# 1  [http://dbpedia.org/resource/Ramon_Llull, Ramo...
# 2                                               None
# 3  [http://dbpedia.org/resource/Yang_Hui, Yang Hu...
# 4                                               None
#
#                                                    2  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [http://dbpedia.org/resource/Yang_Gyeong-hui, ...
# 4                                               None
#
#                                                    3  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [http://dbpedia.org/resource/Yang_Hui-cheon, Y...
# 4                                               None
#
#                                                    4  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [http://dbpedia.org/resource/Yang_Hui-chun, Ya...
# 4                                               None
#
#                                                    5  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [http://dbpedia.org/resource/Yang_Hui_(figure_...
# 4                                               None
#
#                                                    6  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [http://dbpedia.org/resource/Yang_Kyong-hui, Y...
# 4                                               None
#
#                                                    7
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [http://dbpedia.org/resource/Yang-Hui_He, Yang...
# 4                                               None

# %% [markdown]
# ## Wikidata

# %% [markdown]
# ```SPARQL
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# select distinct ?item ?itemLabel ?birthDate ?year
# where {
#     ?item wdt:P31 wd:Q5.  # Any instance of a human.
#     ?item wdt:P106 wd:Q170790;
#           wdt:P569 ?birthDate.
# #    ?birthPlace wdt:P31 ?birthPlaceType.
# #   filter not exists {?birthPlace a wdno:P6}.
#
# BIND(REPLACE(str(?birthDate), "(.*)([0-9]{4})(.*)", "$2") AS ?year)
# # FILTER(?year > 1537 )
# ### Filtrage sur les années comme entiers si souhaité
# FILTER(xsd:integer(?year) > ("1537"^^xsd:integer - 2)  && (xsd:integer(?year) < "1537"^^xsd:integer + 2))
# SERVICE wikibase:label { bd:serviceParam wikibase:language "en,nl" }
#
# }
# ORDER BY ?year
# LIMIT 50
# ```

# %% [markdown]
# ```SPARQL
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# select ?item ?itemLabel ?birthDate ?year
# where {
#     {
# select distinct ?item ?itemLabel ?birthDate ?year
# where {
#      ?item wdt:P31 wd:Q5.  # Any instance of a human.
#     # ?item wdt:P106 wd:Q170790 OR wd:Q333);
#      ?item     wdt:P569 ?birthDate.
# #    ?birthPlace wdt:P31 ?birthPlaceType.
# #   filter not exists {?birthPlace a wdno:P6}.
#
#    BIND(REPLACE(str(?birthDate), "(.*)([0-9]{4})(.*)", "$2") AS ?year)
# # FILTER(?year > 1537 )
# ### Filtrage sur les années comme entiers si souhaité
#
#     SERVICE wikibase:label { bd:serviceParam wikibase:language "en,nl" }
#        }
#     }
# FILTER(contains("Roberval" , ?itemLabel) && xsd:integer(?year) > ("1537"^^xsd:integer - 2)  && (xsd:integer(?year) < "1537"^^xsd:integer + 2))
# }
#
# ORDER BY ?year
# LIMIT 50
#
# ```

# %% [markdown]
# ```SPARQL
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# SELECT * WHERE {
#   ?sub a foaf:Person .
#   ?sub rdfs:label ?lbl ;
#  dbp:birthDate ?birthDate.
#   ?lbl bif:contains "'danti'".
# ?birthDate bif:contains "'1536'".
# #   ?lbl bif:contains "'*gnat*' AND 'dant*'" .
#  # FILTER (?lbl LIKE '%gill%roberva%')
# #FILTER (CONTAINS(str(?birthDate), '1536'))
# filter(langMatches(lang(?lbl), "en"))
# }
# LIMIT 10
# ```

# %%
q2 = """
SELECT pk_mathshistory, "name", dates, url FROM astronomers.mathshistory WHERE xml_is_well_formed(page_html_txt) IS FALSE ;
"""

# %%
with conn.cursor() as curs:
    try:   
        ### Décommenter pour nouvelle exécution
        # curs.execute(qu)
        # conn.commit()
    except Exception as e:
        print(e)

# %%
qu = """UPDATE astronomers.mathshistory SET page_html = page_html_txt::XML
WHERE xml_is_well_formed(page_html_txt) IS TRUE ;"""

# %%
q3 = """
SELECT name, dates, 
(xpath('//dt[text()="Born"]/following-sibling::dd/a/text()', page_html))[1]::text as lieu_naiss,
(xpath('//dt[text()="Born"]/following-sibling::dd/a/@href', page_html))[1]::text as url_lieu_naiss
FROM astronomers.mathshistory WHERE substr(dates, 1, 4)::INTEGER BETWEEN 1601 and 1650;
"""

# %%
result = sql_explore(q3)
print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 result = sql_explore(q3)
#       2 print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')
#
# NameError: name 'sql_explore' is not defined

# %%
conn.close()
