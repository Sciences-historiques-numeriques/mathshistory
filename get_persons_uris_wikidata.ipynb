# %% [markdown]
# # Link persons to wikidata URIs
#
# * Find URIs of resources in Wikidata corresponding to the persons metioned in the biographies

# %%
import psycopg2
from psycopg2.extras import execute_batch

from importlib import reload
# from matplotlib import pyplot as plt

import spacy

import pandas as pd
import re
import csv
from itables import init_notebook_mode, show

# %%
### itables : activation facultative avec la fonction show()
init_notebook_mode(all_interactive=False)
# Out:
# <script>
#   // Create a pending promise immediately (this script is not deferred).
#   window.dataTablePromise = new Promise((resolve) => {
#     window.__resolveDataTablePromise__ = resolve;
#   });
# </script>
# <script type="module">
#   // Module scripts are automatically deferred, so this code will not execute immediately.
#   // See https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Modules#other_differences_between_modules_and_standard_scripts
#   if ($.prototype.DataTable === undefined) {
#       const dt = (await import("data:text/javascript;base64,...")).default;
#       dt(window.$);
#       // Resolve the pending promise above, indicating that DataTable is now ready to be used.
#       window.__resolveDataTablePromise__();
#   }
# </script>
# <style>table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{height:1em;width:1em;margin-top:-9px;display:inline-block;color:white;border:.15em solid white;border-radius:1em;box-shadow:0 0 .2em #444;box-sizing:content-box;text-align:center;text-indent:0 !important;font-family:"Courier New",Courier,monospace;line-height:1em;content:"+";background-color:#31b131}table.dataTable tr.dt-hasChild td.dt-control:before{content:"-";background-color:#d33333}table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc,table.dataTable thead>tr>th.sorting_asc_disabled,table.dataTable thead>tr>th.sorting_desc_disabled,table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>td.sorting_asc_disabled,table.dataTable thead>tr>td.sorting_desc_disabled{cursor:pointer;position:relative;padding-right:26px}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after{position:absolute;display:block;opacity:.125;right:10px;line-height:9px;font-size:.8em}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:before{bottom:50%;content:"▲"}table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:after{top:50%;content:"▼"}table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:after{opacity:.6}table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting_asc_disabled:before{display:none}table.dataTable thead>tr>th:active,table.dataTable thead>tr>td:active{outline:none}div.dataTables_scrollBody table.dataTable thead>tr>th:before,div.dataTables_scrollBody table.dataTable thead>tr>th:after,div.dataTables_scrollBody table.dataTable thead>tr>td:before,div.dataTables_scrollBody table.dataTable thead>tr>td:after{display:none}div.dataTables_processing{position:absolute;top:50%;left:50%;width:200px;margin-left:-100px;margin-top:-26px;text-align:center; ...

# %%
import postgresql_functions as pgf
import settings as stt

# %%
# reload(pgf)

# %%
conn = psycopg2.connect(host="localhost", port = 5432, database="espace_intellectuel", 
                        user="postgres", password=stt.dbw)

# %%
conn.close()

# %% [markdown]
# ### Get persons list from database

# %%
q2 = """
select pk_mathshistory, "name", substring(dates, 1, 4)::INT as birth_date
from mathshistory.mathshistory m 
order by birth_date
"""

# %%
### Get the list of persons with birth year
with conn.cursor() as curs:
    curs.execute(q2)
    rs = curs.fetchall()

# %%
rs[100:103]
# Out:
# [(101, 'Egnatio Danti', 1536),
#  (102, 'Francesco Barozzi', 1537),
#  (103, 'Christopher Clavius', 1538)]

# %%
mats = [[s[1] + ' birthYear ' + str(s[2]), s[0]]   for s in rs]
mats[101:111]
# Out:
# [['Francesco Barozzi birthYear 1537', 102],
#  ['Christopher Clavius birthYear 1538', 103],
#  ['François Viète birthYear 1540', 104],
#  ['Ludolph Van Ceulen birthYear 1540', 105],
#  ['Thomas Allen birthYear 1540', 106],
#  ['Guidobaldo del Monte birthYear 1545', 107],
#  ['Paul Wittich birthYear 1546', 108],
#  ['Tycho Brahe birthYear 1546', 110],
#  ['Thomas Digges birthYear 1546', 109],
#  ["Baha' al-Din al-Amili birthYear 1547", 111]]

# %% [markdown]
# ## Tapioca

# %%
nlpt = spacy.blank('en')
nlpt.add_pipe('opentapioca')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/francesco/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/francesco/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
doc = nlpt('. '.join(mats[101:111]))

# %%
for span in doc.ents:
    print((span.text, span.kb_id_, span.label_, span._.description, span._.score))
# Out:
# ('Christopher Clavius', 'Q76728', 'PERSON', ['German astronomer and mathematician (1538–1612)'], 0.2945102219102421)
# ('François Viète', 'Q188623', 'PERSON', ['French mathematician'], 0.44839082305086986)
# ('Ludolph Van Ceulen', 'Q310771', 'PERSON', ['German-Dutch mathematician'], 1.2828819202702326)
# ('Thomas Allen', 'Q953628', 'PERSON', ['English operatic baritone'], 0.040562816761049114)
# ('Guidobaldo del Monte', 'Q266017', 'PERSON', ['Italian mathematician, astronomer and philosopher'], 0.9464905171587287)
# ('Paul Wittich', 'Q88089', 'PERSON', ['German astronomer'], 0.21548868504353458)
# ('Tycho Brahe', 'Q36620', 'PERSON', ['Danish astronomer and alchemist, 1546–1601'], 0.619930193466644)
# ('Thomas Digges', 'Q531345', 'PERSON', ['English mathematician and astronomer (c.1546–1595)'], 0.06281734695954888)

# %%
pers_list = []
for p in mats[101:111]:
    doc = nlpt(p[0])
    for span in doc.ents:
        pers_list.append([p[1], span.text, span.kb_id_, span.label_, span._.description, span._.score])

# %%
len(pers_list), pers_list[:2]
# Out:
# (6,
#  [[103,
#    'Christopher Clavius',
#    'Q76728',
#    'PERSON',
#    ['German astronomer and mathematician (1538–1612)'],
#    0.5445257934961686],
#   [104,
#    'François Viète',
#    'Q188623',
#    'PERSON',
#    ['French mathematician'],
#    0.5093603884317542]])

# %%
len(mats)
# Out:
# 3010

# %%
pers_list = []
errors = []
for p in mats:
    try:
        doc = nlpt(p[0])
        for span in doc.ents:
            pers_list.append([p[1], span.text, span.kb_id_, span.label_, span._.description, span._.score])
    except Exception as e:
        errors.append([p[1]],e )
# Out:
# WARNING:spacyopentapioca.entity_linker:The OpenTapioca-entity "I" (6, 8) does not fit the span "Il'ich" (6, 12) in spaCy. EXPANDED!
# WARNING:spacyopentapioca.entity_linker:The OpenTapioca-entity "G" (20, 27) does not fit the span "Lavrent'ev" (20, 30) in spaCy. EXPANDED!
# WARNING:spacyopentapioca.entity_linker:The OpenTapioca-entity "I" (5, 7) does not fit the span "Il'ich" (5, 11) in spaCy. EXPANDED!
# WARNING:spacyopentapioca.entity_linker:The OpenTapioca-entity "N" (7, 12) does not fit the span "Vital'evich" (7, 18) in spaCy. EXPANDED!
# WARNING:spacyopentapioca.entity_linker:The OpenTapioca-entity "I" (5, 7) does not fit the span "Il'ich" (5, 11) in spaCy. EXPANDED!

# %%
len(errors), len(pers_list)
# Out:
# (0, 1687)

# %%
df_pers_list = pd.DataFrame(pers_list)
df_pers_list.columns = ['pk_mathshistory', 'name', 'id_wikidata', 'ner_type', 'notice', 'score']
df_pers_list.head()
# Out:
#    pk_mathshistory                  name id_wikidata ner_type  \
# 0                3  Hermann of Reichenau      Q68490   PERSON
# 1                7          Omar Khayyam      Q35900   PERSON
# 2                9     Abraham bar Hiyya      Q31439   PERSON
# 3               12              Ben Ezra   Q28643144   PERSON
# 4               13       Jabir ibn Aflah     Q288111   PERSON
#
#                                               notice     score
# 0  [German 11th-century Benedictine monk, histori...  0.201611
# 1       [Persian mathematician and poet (1048–1131)]  0.283835
# 2                     [mathematician and astronomer]  1.011805
# 3                                               None  0.604074
# 4          [Al-Andalus mathematician and astronomer]  1.305197

# %%
df_pers_list.groupby(by='ner_type').size()
# Out:
# ner_type
# LOC         27
# ORG          3
# ORGLOC       5
# PERSON    1652
# dtype: int64

# %%
df_pers_list[df_pers_list.ner_type == 'ORGLOC']
# Out:
#       pk_mathshistory          name id_wikidata ner_type  \
# 163               320  La Condamine   Q99308636   ORGLOC
# 177               365   Paolo Frisi   Q52808196   ORGLOC
# 368               786      Thorvald   Q97892379   ORGLOC
# 1022             1910      McVittie  Q115262287   ORGLOC
# 1480             2658      Spinadel  Q109572312   ORGLOC
#
#                                                  notice     score
# 163   [former commune of the Principality of Monaco ...  0.700431
# 177   [high school in Milano in the province of Mila...  0.098529
# 368       [Cheese Makers in Upper Moutere, New Zealand]  0.297530
# 1022           [geographic township in Ontario, Canada]  0.120945
# 1480                 [former commune in Cantal, France]  0.122470

# %% [markdown]
# https://www.wikidata.org/entity/Q52808196

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(df_pers_list[df_pers_list.ner_type == 'PERSON'].sort_values(by='pk_mathshistory'), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="02beca9d-82a4-4791-9766-49f235db57c7" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pk_mathshistory</th>
#       <th>name</th>
#       <th>id_wikidata</th>
#       <th>ner_type</th>
#       <th>notice</th>
#       <th>score</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>pk_mathshistory</th><th>name</th><th>id_wikidata</th><th>ner_type</th><th>notice</th><th>score</th></tfoot></table>
# <script>
#     // We use a namespace per table (= the next curly bracket)
#     // to avoid conflicts between the various tables' data & dt_args
#     {
#         // Define the table data
#         const data = [[0, 3, "Hermann of Reichenau", "Q68490", "PERSON", "[German 11th-century Benedictine monk, historian, astronomer, mathematician, poet, and musical composer]", 0.201611], [1, 7, "Omar Khayyam", "Q35900", "PERSON", "[Persian mathematician and poet (1048\u20131131)]", 0.283835], [2, 9, "Abraham bar Hiyya", "Q31439", "PERSON", "[mathematician and astronomer]", 1.011805], [3, 12, "Ben Ezra", "Q28643144", "PERSON", "None", 0.604074], [4, 13, "Jabir ibn Aflah", "Q288111", "PERSON", "[Al-Andalus mathematician and astronomer]", 1.305197], [6, 22, "Li Zhi", "Q9703", "PERSON", "[Emperor of the Tang Dynasty (628-683) (r. 649-683)]", 0.01516], [8, 26, "Qin Jiushao", "Q565225", "PERSON", "[mathematician of Southern Song dynasty, wrote Shu shu jiu zhang (1247)]", 0.047302], [9, 30, "Jordanus Nemorarius", "Q1232954", "PERSON", "[mathematician]", 0.651114], [10, 32, "Ramon Llull", "Q193660", "PERSON", "[Majorcan writer and philosopher]", 0.578652], [12, 39, "Zhao Youqin", "Q17040371", "PERSON", "[Yuan dynasty astronomer-mathematician]", 0.802069], [14, 40, "Levi ben Gerson", "Q353633", "PERSON", "[medieval Jewish philosopher]", 0.947355], [13, 41, "William of Ockham", "Q43936", "PERSON", "[English Franciscan friar and theologian (c.1287\u20131347)]", 0.561952], [15, 43, "Albert of Saxony", "Q168657", "PERSON", "[King of Saxony]", 0.428493], [16, 51, "Filippo Brunelleschi", "Q174330", "PERSON", "[Italian architect, sculptor and engineer]", 0.69935], [17, 53, "Ulugh Beg", "Q486088", "PERSON", "[Timurid sultan, astronomer and mathematician (1394\u20131449)]", 0.338912], [18, 56, "Ali Qushji", "Q423644", "PERSON", "[Ottoman astronomer and mathematician]", 0.001541], [19, 57, "Leone Battista Alberti", "Q182046", "PERSON", "[Italian architect (1404-1472)]", 1.30339], [20, 59, "Piero della Francesca", "Q5822", "PERSON", "[Italian painter and mathematician (c. 1416-1492)]", 0.977445], [21, 61, "Piero Borgi", "Q3903185", "PERSON", "[Italian mathematician]", 0.150517], [22, 64, "Luca Pacioli", "Q87620", "PERSON", "[Italian father of accounting]", 0.448739], [23, 65, "Nicolas Chuquet", "Q1986557", "PERSON", "[mathematician]", 0.371517], [24, 66, "Leonardo da Vinci", "Q762", "PERSON", "[Italian Renaissance polymath (1452-1519)]", 1.552669], [25, 68, "Scipione del Ferro", "Q318083", "PERSON", "[Italian mathematician]", 0.728541], [26, 70, "Maior", "Q11934653", "PERSON", "[ancient Greek philosopher]", 0.120378], [27, 72, "Albrecht D\u00fcrer", "Q5580", "PERSON", "[German painter, printmaker, mathematician, and theorist]", 0.529866], [28, 74, "Nicolaus Copernicus", "Q619", "PERSON", "[Polish mathematician and astronomer (1473\u20131543)]", 0.799727], [29, 75, "Cuthbert Tunstall", "Q725592", "PERSON", "[English bishop, administrator and royal advisor]", 0.177477], [30, 76, "Juan de Ortega", "Q68909484", "PERSON", "[Roman Catholic bishop]", 0.104331], [31, 77, "Gaspar Lax", "Q1495249", "PERSON", "[Spanish mathematician, logician, and philosopher]", 0.399762], [32, 80, "Francesco Maurolico", "Q736315", "PERSON", "[Greek mathematician and astronomer]", 0.780542], [33, 82, "Petrus Apianus", "Q58662", "PERSON", "[German astronomer, mathematician and cartographer]", 0.476374], [34, 83, "Christoff Rudolff", "Q27337", "PERSON", "[author of the first German textbook on algebra]", 1.09212], [35, 88, "Frederico Commandino", "Q671745", "PERSON", "[Italian mathematician]", 0.447439], [36, 89, "Gemma Frisius", "Q455406", "PERSON", "[Dutch scientist]", 0.387692], [37, 90, "Robert Recorde", "Q318192", "PERSON", "[Welsh mathematician and inventor of the symbol '=']", 0.741618], [38, 91, "Erasmus Reinhold", "Q544169", "PERSON", "[German astronomer and mathematician]", 0.39504], [39, 92, "Gerard Mercator", "Q6353", "PERSON", "[Dutch cartographer, philosopher and mathematician (1512\u20131594)]", 0.42519], [40, 93, "Georg Joachim Rheticus", "Q93588", "PERSON", "[Austrian astronomist and mathematician]", 1.644217], [41, 94, "Peter", "Q33923", "PERSON", "[1st ...

# %%
d_file = "data/pers_wikidata.csv"

# %%
df_pers_list[df_pers_list.ner_type == 'PERSON'].to_csv(d_file)

# %%
df_pers = df_pers_list[df_pers_list.ner_type == 'PERSON']

# %%
df_pers['notice_agg'] = df_pers.notice.apply(lambda x: '; '.join(x) if x else '')

# %%
df_pers['uri'] = df_pers.id_wikidata.apply(lambda x: 'https://www.wikidata.org/entity/'+x)

# %%
df_pers.head()
# Out:
#    pk_mathshistory                  name id_wikidata ner_type  \
# 0                3  Hermann of Reichenau      Q68490   PERSON
# 1                7          Omar Khayyam      Q35900   PERSON
# 2                9     Abraham bar Hiyya      Q31439   PERSON
# 3               12              Ben Ezra   Q28643144   PERSON
# 4               13       Jabir ibn Aflah     Q288111   PERSON
#
#                                               notice     score  \
# 0  [German 11th-century Benedictine monk, histori...  0.201611
# 1       [Persian mathematician and poet (1048–1131)]  0.283835
# 2                     [mathematician and astronomer]  1.011805
# 3                                               None  0.604074
# 4          [Al-Andalus mathematician and astronomer]  1.305197
#
#                                           notice_agg  \
# 0  German 11th-century Benedictine monk, historia...
# 1         Persian mathematician and poet (1048–1131)
# 2                       mathematician and astronomer
# 3
# 4            Al-Andalus mathematician and astronomer
#
#                                          uri
# 0     https://www.wikidata.org/entity/Q68490
# 1     https://www.wikidata.org/entity/Q35900
# 2     https://www.wikidata.org/entity/Q31439
# 3  https://www.wikidata.org/entity/Q28643144
# 4    https://www.wikidata.org/entity/Q288111

# %%
cp = df_pers.groupby(by='pk_mathshistory').size()

# %%
### pas de doublons
cp.describe()
# Out:
# count    1652.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# dtype: float64

# %% [markdown]
# ## Import into database

# %% [markdown]
# ### Create a new table

# %%
cq = """
create table if not exists mathshistory.wikidata (id integer, name varchar, uri varchar, notice text, score float);
"""

# %%
with conn.cursor() as cur:
    cur.execute(cq)

# %%
conn.rollback()

# %%
conn.commit()

# %% [markdown]
# ### Prepare and insert tuples

# %%
lv = df_pers[['pk_mathshistory', 'name', 'uri',  'notice_agg', 'score']].values.tolist()
len(lv), lv[:3]
# Out:
# (1652,
#  [[3,
#    'Hermann of Reichenau',
#    'https://www.wikidata.org/entity/Q68490',
#    'German 11th-century Benedictine monk, historian, astronomer, mathematician, poet, and musical composer',
#    0.20161108761658275],
#   [7,
#    'Omar Khayyam',
#    'https://www.wikidata.org/entity/Q35900',
#    'Persian mathematician and poet (1048–1131)',
#    0.2838350995879192],
#   [9,
#    'Abraham bar Hiyya',
#    'https://www.wikidata.org/entity/Q31439',
#    'mathematician and astronomer',
#    1.0118052171061187]])

# %%
tuples = [tuple(e) for e in lv] ; len(tuples), tuples[:3]
# Out:
# (1652,
#  [(3,
#    'Hermann of Reichenau',
#    'https://www.wikidata.org/entity/Q68490',
#    'German 11th-century Benedictine monk, historian, astronomer, mathematician, poet, and musical composer',
#    0.20161108761658275),
#   (7,
#    'Omar Khayyam',
#    'https://www.wikidata.org/entity/Q35900',
#    'Persian mathematician and poet (1048–1131)',
#    0.2838350995879192),
#   (9,
#    'Abraham bar Hiyya',
#    'https://www.wikidata.org/entity/Q31439',
#    'mathematician and astronomer',
#    1.0118052171061187)])

# %%
with conn.cursor() as cur:
    execute_batch(cur, """INSERT INTO mathshistory.wikidata (id, name, uri, notice, score) VALUES (%s, %s, %s, %s, %s)""", tuples)

# %%
conn.rollback()

# %%
conn.commit()

# %%
iq = """
insert into mathshistory."statement" (fk_subject_instance, text_value, fk_property, fk_graph, import_metadata)
select id, uri, 1, 3011, '20230627_2_wd'  from mathshistory.wikidata;
"""

# %%
with conn.cursor() as cur:
    ### Commented to avoid disruption
    # cur.execute(iq)

# %%
conn.commit()
