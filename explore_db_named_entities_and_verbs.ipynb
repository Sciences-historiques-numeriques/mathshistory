# %% [markdown]
# # Explore named entities and verbs
#
# In this notebook I explore the detection and linking of named entities
#
#
# * I use the pip_spacy environment to be able to use plugins and extensions not available in Conda

# %%
from importlib import reload
import pandas as pd

import psycopg2
import settings as stt

from itables import init_notebook_mode, show
import re

from time import strftime, gmtime

# %%
import postgresql_functions as pgf

# %%
# reload(pgf)

# %% [markdown]
# ## Explore verbs
# Get a list of named entities contiaining the term _University_

# %%
### connect to the local database
conn = psycopg2.connect(host="localhost", port = 5432, database="espace_intellectuel", 
                        user="postgres", password=stt.dbw)
#conn

# %%
# conn.close()

# %%
q = """-- frequency of verbs
select t_lemma, count(*) as freq 
from mathshistory.coref_token ct 
where ct.t_pos_ ='VERB'
group by t_lemma 
order by freq desc;"""

# %%
q = """
-- frequency of verbs and of their synctactic roles
select concat_ws(' : ', t_lemma, lower(t_dep_)) , count(*) as freq 
from mathshistory.coref_token ct 
where ct.t_pos_ ='VERB'
group by t_lemma , t_dep_ 
order by freq desc;
"""

# %%
result = pgf.sql_explore(q, conn)
# print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')

# %%
ne = pd.DataFrame(result[0])
ne.columns = ['verb', 'freq']
ne.head()
# Out:
#              verb  freq
# 0    write : root  6927
# 1     have : root  6424
# 2  publish : root  5386
# 3   become : root  4224
# 4     give : root  4077

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(ne.sort_values(by='freq', ascending=False), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="65165c25-7e0e-4464-a38e-ca79068b9bfa" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>freq</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>name</th><th>freq</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[6, "7362: Tycho now studied astronomy with Bartholomew Schultz at Leipzig who taught Tycho some tricks to obtain more accurate observations. ", "{{Tycho,789,Tycho,PROPN,nsubj,studied,VERB,791,VBD},{now,790,now,ADV,advmod,studied,VERB,791,VBD},{studied,791,study,VERB,ROOT,studied,VERB,791,VBD},{astronomy,792,astronomy,NOUN,dobj,studied,VERB,791,VBD},{with,793,with,ADP,prep,studied,VERB,791,VBD},{Bartholomew,794,Bartholomew,PROPN,compound,Schultz,PROPN,795,NNP},{Schultz,795,Schultz,PROPN,pobj,with,ADP,793,IN},{at,796,at,ADP,prep,Schultz,PROPN,795,NNP},{Leipzig,797,Leipzig,PROPN,pobj,at,ADP,796,IN},{who,798,who,PRON,nsubj,taught,VERB,799,VBD},{taught,799,teach,VERB,relcl,Schultz,PROPN,795,NNP},{Tycho,800,Tycho,PROPN,dobj,taught,VERB,799,VBD},{some,801,some,DET,det,tricks,NOUN,802,NNS},{tricks,802,trick,NOUN,dobj,taught,VERB,799,VBD},{to,803,to,PART,aux,obtain,VERB,804,VB},{obtain,804,obtain,VERB,xcomp,taught,VERB,799,VBD},{more,805,more,ADV,advmod,accurate,ADJ,806,JJ},{accurate,806,accurate,ADJ,amod,observations,NOUN,807,NNS},{observations,807,observation,NOUN,dobj,obtain,VERB,804,VB},{.,808,.,PUNCT,punct,studied,VERB,791,VBD}}"], [5, "7353: There, following the wishes of Otte uncle, Otte studied law but also studied a variety of other subjects and became interested in astronomy. ", "{{There,501,there,ADV,advmod,studied,VERB,511,VBD},{\",\",502,\",\",PUNCT,punct,studied,VERB,511,VBD},{following,503,follow,VERB,prep,studied,VERB,511,VBD},{the,504,the,DET,det,wishes,NOUN,505,NNS},{wishes,505,wish,NOUN,pobj,following,VERB,503,VBG},{of,506,of,ADP,prep,wishes,NOUN,505,NNS},{Otte,507,Otte,PROPN,compound,uncle,NOUN,508,NN},{uncle,508,uncle,NOUN,pobj,of,ADP,506,IN},{\",\",509,\",\",PUNCT,punct,uncle,NOUN,508,NN},{Otte,510,Otte,PROPN,nsubj,studied,VERB,511,VBD},{studied,511,study,VERB,ROOT,studied,VERB,511,VBD},{law,512,law,NOUN,dobj,studied,VERB,511,VBD},{but,513,but,CCONJ,cc,studied,VERB,511,VBD},{also,514,also,ADV,advmod,studied,VERB,515,VBD},{studied,515,study,VERB,conj,studied,VERB,511,VBD},{a,516,a,DET,det,variety,NOUN,517,NN},{variety,517,variety,NOUN,dobj,studied,VERB,515,VBD},{of,518,of,ADP,prep,variety,NOUN,517,NN},{other,519,other,ADJ,amod,subjects,NOUN,520,NNS},{subjects,520,subject,NOUN,pobj,of,ADP,518,IN},{and,521,and,CCONJ,cc,studied,VERB,515,VBD},{became,522,become,VERB,conj,studied,VERB,515,VBD},{interested,523,interested,ADJ,acomp,became,VERB,522,VBD},{in,524,in,ADP,prep,interested,ADJ,523,JJ},{astronomy,525,astronomy,NOUN,pobj,in,ADP,524,IN},{.,526,.,PUNCT,punct,studied,VERB,511,VBD}}"], [19, "9405: Then clerk studied at Antwerp with Michel Coignet, being there in 1599, following which clerk went to Paris in 1600 where clerk was greatly influenced by Fran\u00e7ois Vi\u00e8te. ", "{{Then,420,then,ADV,advmod,studied,VERB,422,VBD},{clerk,421,clerk,NOUN,nsubj,studied,VERB,422,VBD},{studied,422,study,VERB,ROOT,studied,VERB,422,VBD},{at,423,at,ADP,prep,studied,VERB,422,VBD},{Antwerp,424,Antwerp,PROPN,pobj,at,ADP,423,IN},{with,425,with,ADP,prep,studied,VERB,422,VBD},{Michel,426,Michel,PROPN,compound,Coignet,PROPN,427,NNP},{Coignet,427,Coignet,PROPN,pobj,with,ADP,425,IN},{\",\",428,\",\",PUNCT,punct,studied,VERB,422,VBD},{being,429,be,AUX,advcl,studied,VERB,422,VBD},{there,430,there,ADV,advmod,being,AUX,429,VBG},{in,431,in,ADP,prep,being,AUX,429,VBG},{1599,432,1599,NUM,pobj,in,ADP,431,IN},{\",\",433,\",\",PUNCT,punct,being,AUX,429,VBG},{following,434,follow,VERB,advmod,went,VERB,437,VBD},{which,435,which,DET,det,clerk,NOUN,436,NN},{clerk,436,clerk,NOUN,nsubj,went,VERB,437,VBD},{went,437,go,VERB,advcl,being,AUX,429,VBG},{to,438,to,ADP,prep,went,VERB,437,VBD},{Paris,439,Paris,PROPN,pobj,to,ADP,438,IN},{in,440,in,ADP,prep,went,VERB,437,VBD},{1600,441,1600,NUM,pobj,in,ADP,440,IN},{where,442,where,SCONJ,advmod,influenced,VERB,446,VBN},{clerk,443,clerk,NOUN,nsubjpass,influenced,VERB,446,VBN},{was,444,be,AUX,auxpass,influenced,VERB,446,VBN},{greatly,445,greatly,ADV,advmod,influenced,VERB,446,VBN},{influenced,446,inf ...

# %%
verb = 'study'

### ROOT, xcomp
dependency = "and ct.t_dep_ in ('ROOT')\n"

# %%
q = f"""
with tw1 as (
select cs.pk_sentence, cs.sentence
from mathshistory.coref_sentence cs, mathshistory.coref_token ct 
where ct.fk_sentence = cs.pk_sentence
{dependency}   --and ct.t_dep_ = 'ROOT'
and ct.t_lemma = '{verb}'
offset 50
limit 20)
select concat(tw1.pk_sentence::varchar, ': ', tw1.sentence) sent, 
    array_agg(array[ct.t_text, ct.t_index::varchar, ct.t_lemma, ct.t_pos_ , ct.t_dep_,
    ct.t_head_text, t_head_pos_, t_head_i::varchar, ct.t_head_tag_]
    order by ct.t_index asc)::text token
from tw1, mathshistory.coref_token ct 
where ct.fk_sentence = tw1.pk_sentence
group by tw1.pk_sentence, tw1.sentence;
"""

# print(q)

# %%
result = pgf.sql_explore(q, conn)
# print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:1]}')
dfq = pd.DataFrame(result[0])

# %%
dfq['new']=dfq[1].apply(lambda x : [i.split(',') for i in (re.sub('{|}}$', '', x)).split('},')])
# print(dfq['new'][0])

# %%
dfq['text'] = dfq['new'].apply(lambda x : [(i[0].upper() + '  (' + ','.join([e.lower() for e in i[1:]]) + ')  ') for i in x])
dfq = dfq[[0,'text']]

# %%
dfq.iloc[0]
# Out:
# 0       6391: Benedetti studied the first four books o...
# text    [BENEDETTI  (99,benedetti,propn,nsubj,studied,...
# Name: 0, dtype: object

# %%
dfq.columns = ['sentence', 'tokens']
len(dfq)
# Out:
# 20

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(dfq.sort_values(by='sentence', ascending=False), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="b4ef346e-9c86-4046-ba1f-87f144f2ac9f" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sentence</th>
#       <th>tokens</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>sentence</th><th>tokens</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[19, "9405: Then clerk studied at Antwerp with Michel Coignet, being there in 1599, following which clerk went to Paris in 1600 where clerk was greatly influenced by Fran\u00e7ois Vi\u00e8te. ", "[THEN  (420,then,adv,advmod,studied,verb,422,vbd)  , CLERK  (421,clerk,noun,nsubj,studied,verb,422,vbd)  , STUDIED  (422,study,verb,root,studied,verb,422,vbd)  , AT  (423,at,adp,prep,studied,verb,422,vbd)  , ANTWERP  (424,antwerp,propn,pobj,at,adp,423,in)  , WITH  (425,with,adp,prep,studied,verb,422,vbd)  , MICHEL  (426,michel,propn,compound,coignet,propn,427,nnp)  , COIGNET  (427,coignet,propn,pobj,with,adp,425,in)  , \"  (\",428,\",\",punct,punct,studied,verb,422,vbd)  , BEING  (429,be,aux,advcl,studied,verb,422,vbd)  , THERE  (430,there,adv,advmod,being,aux,429,vbg)  , IN  (431,in,adp,prep,being,aux,429,vbg)  , 1599  (432,1599,num,pobj,in,adp,431,in)  , \"  (\",433,\",\",punct,punct,being,aux,429,vbg)  , FOLLOWING  (434,follow,verb,advmod,went,verb,437,vbd)  , WHICH  (435,which,det,det,clerk,noun,436,nn)  , CLERK  (436,clerk,noun,nsubj,went,verb,437,vbd)  , WENT  (437,go,verb,advcl,being,aux,429,vbg)  , TO  (438,to,adp,prep,went,verb,437,vbd)  , PARIS  (439,paris,propn,pobj,to,adp,438,in)  , IN  (440,in,adp,prep,went,verb,437,vbd)  , 1600  (441,1600,num,pobj,in,adp,440,in)  , WHERE  (442,where,sconj,advmod,influenced,verb,446,vbn)  , CLERK  (443,clerk,noun,nsubjpass,influenced,verb,446,vbn)  , WAS  (444,be,aux,auxpass,influenced,verb,446,vbn)  , GREATLY  (445,greatly,adv,advmod,influenced,verb,446,vbn)  , INFLUENCED  (446,influence,verb,relcl,1600,num,441,cd)  , BY  (447,by,adp,agent,influenced,verb,446,vbn)  , FRAN\u00c7OIS  (448,fran\u00e7ois,propn,compound,vi\u00e8te,propn,449,nnp)  , VI\u00c8TE  (449,vi\u00e8te,propn,pobj,by,adp,447,in)  , .  (450,.,punct,punct,studied,verb,422,vbd)  ]"], [18, "9323: Between 1596 and 1599, Biancani was studying at the Jesuit College in Padua. ", "[BETWEEN  (65,between,adp,prep,studying,verb,72,vbg)  , 1596  (66,1596,num,pobj,between,adp,65,in)  , AND  (67,and,cconj,cc,1596,num,66,cd)  , 1599  (68,1599,num,conj,1596,num,66,cd)  , \"  (\",69,\",\",punct,punct,studying,verb,72,vbg)  , BIANCANI  (70,biancani,propn,nsubj,studying,verb,72,vbg)  , WAS  (71,be,aux,aux,studying,verb,72,vbg)  , STUDYING  (72,study,verb,root,studying,verb,72,vbg)  , AT  (73,at,adp,prep,studying,verb,72,vbg)  , THE  (74,the,det,det,college,propn,76,nnp)  , JESUIT  (75,jesuit,propn,compound,college,propn,76,nnp)  , COLLEGE  (76,college,propn,pobj,at,adp,73,in)  , IN  (77,in,adp,prep,college,propn,76,nnp)  , PADUA  (78,padua,propn,pobj,in,adp,77,in)  , .  (79,.,punct,punct,studying,verb,72,vbg)  ]"], [17, "9322: Biancani studied mathematics, taught by the famous Christopher Clavius at the Jesuit Collegio Romano in Rome. ", "[BIANCANI  (47,biancani,propn,nsubj,studied,verb,48,vbd)  , STUDIED  (48,study,verb,root,studied,verb,48,vbd)  , MATHEMATICS  (49,mathematic,noun,dobj,studied,verb,48,vbd)  , \"  (\",50,\",\",punct,punct,mathematics,noun,49,nns)  , TAUGHT  (51,teach,verb,acl,mathematics,noun,49,nns)  , BY  (52,by,adp,agent,taught,verb,51,vbn)  , THE  (53,the,det,det,clavius,propn,56,nnp)  , FAMOUS  (54,famous,adj,amod,clavius,propn,56,nnp)  , CHRISTOPHER  (55,christopher,propn,compound,clavius,propn,56,nnp)  , CLAVIUS  (56,clavius,propn,pobj,by,adp,52,in)  , AT  (57,at,adp,prep,clavius,propn,56,nnp)  , THE  (58,the,det,det,romano,propn,61,nnp)  , JESUIT  (59,jesuit,propn,compound,romano,propn,61,nnp)  , COLLEGIO  (60,collegio,propn,compound,romano,propn,61,nnp)  , ROMANO  (61,romano,propn,pobj,at,adp,57,in)  , IN  (62,in,adp,prep,romano,propn,61,nnp)  , ROME  (63,rome,propn,pobj,in,adp,62,in)  , .  (64,.,punct,punct,studied,verb,48,vbd)  ]"], [16, "8823: Liddel studied under Wittich at Wroc\u0142aw for over a year before returning to Frankfurt an der Oder . ", "[LIDDEL  (817,liddel,propn,nsubj,studied,verb,818,vbd)  , STUDIED  (818,study,verb,root,studied,verb,818,vbd)  , UNDER  (819,under,adp,prep,studi ...

# %% [markdown]
# ## Get named entites from database related to 'University'
#
# Get a list of named entities contiaining the term _University_

# %%
### connect to the local database
conn = psycopg2.connect(host="localhost", port = 5432, database="espace_intellectuel", 
                        user="postgres", password=stt.dbw)
#conn

# %%
q1 = """
with tw1 as (
select pk_sentence,st_id, fk_mathshistory, sentence 
from mathshistory.coref_sentence cs
where sentence ~ 'University'
--limit 200
), tw2 as (
select ct.t_text tx, concat_ws(' ', ct.t_index, ct.t_pos_, ct.t_dep_, ct.t_head_text, ct.t_head_i),
ct1.t_text tx1 , concat_ws(' ', ct1.t_index, ct1.t_pos_, ct1.t_dep_, ct1.t_head_text, ct1.t_head_i) ,
ct2.t_text tx2, concat_ws(' ', ct2.t_index, ct2.t_pos_, ct2.t_dep_, ct2.t_head_text, ct2.t_head_i) ,
ct3.t_text tx3, concat_ws(' ', ct3.t_index, ct3.t_pos_, ct3.t_dep_, ct3.t_head_text, ct3.t_head_i) , 
ct4.t_text tx4, concat_ws(' ', ct4.t_index, ct4.t_pos_, ct4.t_dep_, ct4.t_head_text, ct4.t_head_i) ,
ct5.t_text tx5, concat_ws(' ', ct5.t_index, ct5.t_pos_, ct5.t_dep_, ct5.t_head_text, ct5.t_head_i)
from mathshistory.coref_token ct 
join tw1 on ct.fk_sentence = tw1.pk_sentence
join mathshistory.coref_token ct1 on ct1.fk_sentence = tw1.pk_sentence and ct1.t_head_i = ct.t_index 
join mathshistory.coref_token ct2 on ct2.fk_sentence = tw1.pk_sentence and ct2.t_index = ct1.t_index +1
left join mathshistory.coref_token ct3 on ct3.fk_sentence = tw1.pk_sentence 
		and ct3.t_index = ct2.t_index +1 and ct3.t_pos_ = 'PROPN'
left join mathshistory.coref_token ct4 on ct4.fk_sentence = tw1.pk_sentence 
		and ct4.t_index = ct3.t_index +1 and ct4.t_pos_ = 'PROPN'
left join mathshistory.coref_token ct5 on ct5.fk_sentence = tw1.pk_sentence 
		and ct5.t_index = ct4.t_index +1 and ct5.t_pos_ = 'PROPN'
where ct.t_text = 'University'
and ct1.t_dep_ ='prep'
and ct1.t_text in ('of')) --, 'at', 'in'
select concat_ws(' ', tx, tx1, tx2,tx3,tx4, tx5) ne, count(*) eff
from tw2
group by tx, tx1, tx2, tx3,tx3,tx4, tx5
order by eff desc;
"""

# %%
result = pgf.sql_explore(q1, conn)
print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')
# Out:
# Lines count: 825, errors count: 0,
# First lines: [('University of California', 357), ('University of Berlin', 337), ('University of Chicago', 315), ('University of London', 259), ('University of Cambridge', 253)]

# %%
ne = pd.DataFrame(result[0])
ne.columns = ['name', 'freq']
ne.head()
# Out:
#                        name  freq
# 0  University of California   357
# 1      University of Berlin   337
# 2     University of Chicago   315
# 3      University of London   259
# 4   University of Cambridge   253

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(ne.sort_values(by='freq', ascending=False), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="1a2a8c76-f46b-4cef-8fd0-1138226b6841" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>freq</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>name</th><th>freq</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "University of California", 357], [1, "University of Berlin", 337], [2, "University of Chicago", 315], [3, "University of London", 259], [4, "University of Cambridge", 253], [5, "University of Edinburgh", 229], [6, "University of St Andrews", 183], [7, "University of Vienna", 179], [8, "University of Michigan", 173], [9, "University of G\u00f6ttingen", 170], [10, "University of Paris", 148], [11, "University of Warsaw", 131], [12, "University of Wisconsin", 127], [13, "University of Illinois", 126], [14, "University of Oxford", 124], [15, "University of Pennsylvania", 120], [17, "University of Leipzig", 116], [16, "University of Rome", 116], [18, "University of Glasgow", 115], [19, "University of Bologna", 106], [20, "University of Toronto", 104], [21, "University of Texas", 103], [22, "University of Buenos Aires", 102], [23, "University of Pisa", 96], [24, "University of Turin", 92], [25, "University of Manchester", 91], [26, "University of Budapest", 86], [27, "University of Maryland", 85], [28, "University of Prague", 83], [29, "University of Munich", 83], [30, "University of Copenhagen", 78], [31, "University of Washington", 76], [32, "University of Naples", 75], [34, "University of Strasbourg", 71], [33, "University of Leiden", 71], [35, "University of K\u00f6nigsberg", 70], [36, "University of Z\u00fcrich", 68], [38, "University of Amsterdam", 67], [37, "University of Bucharest", 67], [40, "University of Padua", 65], [39, "University of Aberdeen", 65], [42, "University of Heidelberg", 63], [41, "University of S\u00e3o Paulo", 63], [44, "University of Oslo", 61], [43, "University of New York", 61], [45, "University of Halle", 59], [47, "University of Pavia", 58], [46, "University of Athens", 58], [48, "University of Breslau", 57], [49, "University of Cluj", 55], [50, "University of Bonn", 54], [51, "University of Tokyo", 51], [53, "University of Technology", 51], [52, "University of Ibadan", 51], [54, "University of Minnesota", 49], [55, "University of North Carolina", 49], [56, "University of Warwick", 48], [57, "University of Ireland", 45], [58, "University of Moscow", 44], [59, "University of Liverpool", 42], [60, "University of Erlangen", 41], [61, "University of T\u00fcbingen", 40], [62, "University of Hamburg", 39], [63, "University of Giessen", 38], [64, "University of Jena", 37], [67, "University of Li\u00e8ge", 36], [65, "University of British Columbia", 36], [66, "University of Dundee", 36], [68, "University of Jerusalem", 35], [70, "University of Modena", 34], [69, "University of Geneva", 34], [76, "University of Kiev", 33], [72, "University of Groningen", 33], [71, "University of Missouri", 33], [74, "University of Basel", 33], [75, "University of Chile", 33], [73, "University of Freiburg", 33], [77, "University of Lund", 32], [78, "University of Latvia", 31], [79, "University of Frankfurt", 30], [82, "University of Kiel", 29], [83, "University of Cape Town", 29], [81, "University of Pittsburgh", 29], [85, "University of Debrecen", 29], [84, "University of Birmingham", 29], [80, "University of Melbourne", 29], [86, "University of Venezuela", 28], [89, "University of Coimbra", 28], [88, "University of Brazil", 28], [87, "University of Kolozsv\u00e1r", 28], [91, "University of Sydney", 27], [90, "University of Marburg", 27], [93, "University of Florence", 27], [92, "University of Catania", 27], [94, "University of Virginia", 27], [96, "University of the Witwatersrand", 26], [99, "University of Wroc\u0142aw", 26], [98, "University of Lw\u00f3w", 26], [95, "University of M\u00fcnster", 26], [97, "University of Madrid", 26], [100, "University of Utrecht", 25], [103, "University of Iowa", 24], [104, "University of Louvain", 24], [102, "University of Rochester", 24], [101, "University of Helsinki", 24], [107, "University of St Petersburg", 23], [105, "University of Cologne", 23], [111, "University of Dorpat", 23], [110, "University of Leeds", 23], [109, "University of Kansas", 23], [112, "Univer ...

# %% [markdown]
# ## Verbs related to university, academy, etc.

# %%
### university, faculty, college, academy, ...

# the most frequently used is university

term = 'university'

# %%
q = f"""
with tw1 as (
select pk_sentence,st_id, fk_mathshistory, sentence 
from mathshistory.coref_sentence cs
where sentence ~* '{term}'
--limit 200
), tw2 as (
select h1.t_head_text h1_text, concat_ws(' ', h1.t_head_pos_,h1.t_dep_) h1_pos, 
			ct.t_head_text h_text, ct.t_head_pos_ h_pos, ct.t_text tx, concat_ws(' ', ct.t_index, ct.t_pos_, ct.t_dep_, ct.t_head_text, ct.t_head_i, 
			ct.t_head_text, ct.t_head_pos_),
ct1.t_text tx1 , concat_ws(' ', ct1.t_index, ct1.t_pos_, ct1.t_dep_, ct1.t_head_text, ct1.t_head_i) ,
ct2.t_text tx2, concat_ws(' ', ct2.t_index, ct2.t_pos_, ct2.t_dep_, ct2.t_head_text, ct2.t_head_i) ,
ct3.t_text tx3, concat_ws(' ', ct3.t_index, ct3.t_pos_, ct3.t_dep_, ct3.t_head_text, ct3.t_head_i) , 
ct4.t_text tx4, concat_ws(' ', ct4.t_index, ct4.t_pos_, ct4.t_dep_, ct4.t_head_text, ct4.t_head_i) ,
ct5.t_text tx5, concat_ws(' ', ct5.t_index, ct5.t_pos_, ct5.t_dep_, ct5.t_head_text, ct5.t_head_i)
from mathshistory.coref_token ct 
join tw1 on ct.fk_sentence = tw1.pk_sentence
join mathshistory.coref_token ct1 on ct1.fk_sentence = tw1.pk_sentence and ct1.t_head_i = ct.t_index 
--head 2nd level 
join mathshistory.coref_token h1 on h1.fk_sentence = tw1.pk_sentence and h1.t_index = ct.t_head_i 
join mathshistory.coref_token ct2 on ct2.fk_sentence = tw1.pk_sentence and ct2.t_index = ct1.t_index +1
left join mathshistory.coref_token ct3 on ct3.fk_sentence = tw1.pk_sentence 
		and ct3.t_index = ct2.t_index +1 and ct3.t_pos_ = 'PROPN'
left join mathshistory.coref_token ct4 on ct4.fk_sentence = tw1.pk_sentence 
		and ct4.t_index = ct3.t_index +1 and ct4.t_pos_ = 'PROPN'
left join mathshistory.coref_token ct5 on ct5.fk_sentence = tw1.pk_sentence 
		and ct5.t_index = ct4.t_index +1 and ct5.t_pos_ = 'PROPN'
where ct.t_text ~* '{term}'
and ct1.t_dep_ ='prep'
and ct1.t_text in ('of')) --, 'at', 'in'
select h1_text, h1_pos, h_text, h_pos, tx, tx1, tx2,tx3,tx4, tx5, count(*) eff
from tw2
group by h1_text, h1_pos, h_text, h_pos, tx, tx1, tx2, tx3,tx3,tx4, tx5
order by eff desc;
"""

# %%
result = pgf.sql_explore(q, conn)
# print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')

# %%
univ = pd.DataFrame(result[0])
univ.columns=['h1_text', 'h1_pos', 'h_text', 'h_pos', 'tx', 'tx1', 'tx2','tx3','tx4', 'tx5', 'eff']
univ.head()
# Out:
#         h1_text     h1_pos   h_text h_pos          tx tx1         tx2   tx3  \
# 0       entered  VERB ROOT  entered  VERB  University  of      Berlin  None
# 1       studied  VERB prep       at   ADP  University  of      Berlin  None
# 2     professor  NOUN prep       at   ADP  University  of  California  None
# 3  matriculated  VERB prep       at   ADP  University  of   Edinburgh  None
# 4          went  VERB prep       to   ADP  University  of   Göttingen  None
#
#     tx4   tx5  eff
# 0  None  None   25
# 1  None  None   22
# 2  None  None   21
# 3  None  None   19
# 4  None  None   17

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(univ.sort_values(by='eff', ascending=False), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="42a08c84-a430-40b5-acb4-4b656b5ac928" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>h1_text</th>
#       <th>h1_pos</th>
#       <th>h_text</th>
#       <th>h_pos</th>
#       <th>tx</th>
#       <th>tx1</th>
#       <th>tx2</th>
#       <th>tx3</th>
#       <th>tx4</th>
#       <th>tx5</th>
#       <th>eff</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>h1_text</th><th>h1_pos</th><th>h_text</th><th>h_pos</th><th>tx</th><th>tx1</th><th>tx2</th><th>tx3</th><th>tx4</th><th>tx5</th><th>eff</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "entered", "VERB ROOT", "entered", "VERB", "University", "of", "Berlin", "None", "None", "None", 25], [1, "studied", "VERB prep", "at", "ADP", "University", "of", "Berlin", "None", "None", "None", 22], [2, "professor", "NOUN prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 21], [3, "matriculated", "VERB prep", "at", "ADP", "University", "of", "Edinburgh", "None", "None", "None", 19], [4, "went", "VERB prep", "to", "ADP", "University", "of", "G\u00f6ttingen", "None", "None", "None", 17], [5, "part", "NOUN prep", "of", "ADP", "University", "of", "St", "Andrews", "None", "None", 16], [6, "professor", "NOUN prep", "at", "ADP", "University", "of", "Vienna", "None", "None", "None", 16], [7, "at", "ADP pobj", "College", "PROPN", "University", "of", "London", "None", "None", "None", 16], [8, "went", "VERB prep", "to", "ADP", "University", "of", "Chicago", "None", "None", "None", 15], [9, "spent", "VERB prep", "at", "ADP", "University", "of", "G\u00f6ttingen", "None", "None", "None", 15], [10, "Professor", "PROPN prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 14], [11, "professor", "NOUN prep", "at", "ADP", "University", "of", "Copenhagen", "None", "None", "None", 14], [12, "College", "PROPN prep", "of", "ADP", "University", "of", "London", "None", "None", "None", 14], [15, "appointed", "VERB prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 13], [13, "professor", "NOUN prep", "at", "ADP", "University", "of", "Prague", "None", "None", "None", 13], [14, "held", "VERB prep", "at", "ADP", "University", "of", "Dundee", "None", "None", "None", 13], [16, "entered", "VERB ROOT", "entered", "VERB", "University", "of", "Vienna", "None", "None", "None", 12], [17, "professor", "NOUN prep", "at", "ADP", "University", "of", "Berlin", "None", "None", "None", 12], [18, "spent", "VERB prep", "at", "ADP", "University", "of", "Berlin", "None", "None", "None", 12], [19, "went", "VERB prep", "to", "ADP", "University", "of", "California", "None", "None", "None", 12], [20, "professor", "NOUN prep", "at", "ADP", "University", "of", "Paris", "None", "None", "None", 11], [21, "spent", "VERB prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 11], [22, "awarded", "VERB agent", "by", "ADP", "University", "of", "Cambridge", "None", "None", "None", 11], [23, "appointed", "VERB prep", "to", "ADP", "University", "of", "California", "None", "None", "None", 11], [24, "moved", "VERB prep", "to", "ADP", "University", "of", "California", "None", "None", "None", 11], [25, "studied", "VERB prep", "at", "ADP", "University", "of", "Edinburgh", "None", "None", "None", 11], [28, "professor", "NOUN prep", "at", "ADP", "University", "of", "Amsterdam", "None", "None", "None", 10], [30, "professor", "NOUN prep", "at", "ADP", "University", "of", "Leiden", "None", "None", "None", 10], [29, "professor", "NOUN prep", "at", "ADP", "University", "of", "Illinois", "None", "None", "None", 10], [27, "awarded", "VERB agent", "by", "ADP", "University", "of", "Berlin", "None", "None", "None", 10], [26, "part", "NOUN prep", "of", "ADP", "University", "of", "London", "None", "None", "None", 10], [31, "professor", "NOUN prep", "at", "ADP", "University", "of", "Chicago", "None", "None", "None", 10], [42, "studied", "VERB prep", "at", "ADP", "University", "of", "Vienna", "None", "None", "None", 9], [41, "entered", "VERB ROOT", "entered", "VERB", "University", "of", "Leiden", "None", "None", "None", 9], [40, "study", "VERB prep", "at", "ADP", "University", "of", "Cambridge", "None", "None", "None", 9], [39, "Faculty", "PROPN prep", "of", "ADP", "University", "of", "Buenos", "Aires", "None", "None", 9], [37, "professor", "NOUN prep", "at", "ADP", "University", "of", "Bologna", "None", "None", "None", 9], [36, "professor", "NOUN prep", "at", "ADP", "University", "of", "Wisconsin", "None", "None", "None", 9], [35, "professor", "NOUN prep", "at", "ADP", "University", " ...

# %%
u_verbs_size = univ[['h1_text', 'h_text', 'eff']].groupby(by=['h1_text', 'h_text']).sum()
u_verbs_size.sort_values(by='eff', ascending=False).head()
# Out:
#                    eff
# h1_text   h_text
# professor at       578
# entered   entered  295
# studied   at       264
# Professor at       211
# appointed at       200

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(u_verbs_size.sort_values(by='eff', ascending=False), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="5d3fb518-81dc-46b1-83bf-4a7897052bf0" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>eff</th>
#     </tr>
#     <tr>
#       <th>h1_text</th>
#       <th>h_text</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>h1_text</th><th>h_text</th><th>eff</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [["professor", "at", 578], ["entered", "entered", 295], ["studied", "at", 264], ["Professor", "at", 211], ["appointed", "at", 200], ["awarded", "by", 176], ["went", "to", 158], ["spent", "at", 153], ["appointed", "to", 151], ["moved", "to", 144], ["received", "from", 131], ["awarded", "from", 121], ["taught", "at", 119], ["held", "at", 117], ["lecturer", "at", 110], ["study", "at", 91], ["student", "at", 85], ["professorship", "at", 83], ["position", "at", 82], ["graduated", "from", 82], ["returned", "to", 78], ["was", "at", 74], ["submitted", "to", 74], ["chair", "at", 67], ["teaching", "at", 65], ["part", "of", 64], ["Faculty", "of", 61], ["assistant", "at", 61], ["studying", "at", 60], ["matriculated", "at", 59], ["Institute", "of", 57], ["University", "University", 55], ["worked", "at", 49], ["Department", "of", 48], ["began", "at", 48], ["became", "at", 47], ["Department", "at", 45], ["offered", "at", 44], ["College", "of", 41], ["accepted", "at", 40], ["studies", "at", 40], ["post", "at", 39], ["remained", "at", 38], ["Sciences", "of", 37], ["at", "College", 37], ["at", "University", 36], ["rector", "of", 36], ["attended", "attended", 36], ["undertake", "at", 36], ["appointment", "at", 35], ["take", "at", 34], ["gave", "at", 34], ["awarded", "awarded", 33], ["Lecturer", "at", 33], ["spend", "at", 32], ["degree", "from", 32], ["given", "at", 32], ["lectured", "at", 31], ["habilitated", "at", 30], ["Ph.D.", "from", 30], ["was", "was", 30], ["graduated", "entered", 29], ["at", "at", 29], ["teach", "at", 29], ["obtained", "from", 28], ["entered", "at", 26], ["founded", "founded", 26], ["work", "at", 26], ["Faculty", "at", 24], ["took", "at", 24], ["enrolled", "at", 24], ["docent", "at", 24], ["years", "at", 24], ["from", "from", 23], ["Chancellor", "of", 23], ["Institute", "at", 22], ["retired", "from", 22], ["returning", "to", 22], ["doctorate", "from", 22], ["degree", "at", 22], ["School", "at", 22], ["attended", "at", 22], ["Privatdozent", "at", 21], ["educated", "at", 21], ["Science", "of", 21], ["undergraduate", "at", 20], ["students", "at", 20], ["instructor", "at", 20], ["spending", "at", 20], ["from", "University", 20], ["graduating", "from", 19], ["attended", "entered", 19], ["working", "at", 19], ["Ph.D.", "at", 19], ["before", "entering", 18], ["Chair", "at", 18], ["left", "left", 18], ["go", "to", 17], ["research", "at", 17], ["analysis", "at", 17], ["including", "University", 17], ["was", "entered", 17], ["faculty", "of", 16], ["Ph.D.", "by", 16], ["lecture", "at", 15], ["degree", "by", 15], ["visited", "visited", 15], ["visit", "to", 15], ["presented", "to", 15], ["became", "became", 15], ["year", "at", 15], ["moving", "to", 15], ["School", "of", 14], ["joined", "at", 14], ["lectures", "at", 14], ["Fellow", "at", 14], ["Professor", "in", 14], ["completed", "entered", 14], ["time", "at", 14], ["return", "to", 13], ["retired", "at", 13], ["undertook", "at", 13], ["staff", "at", 13], ["transferred", "to", 12], ["college", "of", 12], ["privatdozent", "at", 12], ["professor", "in", 12], ["Instructor", "at", 12], ["degrees", "from", 12], ["Rector", "of", 12], ["department", "at", 12], ["named", "at", 12], ["by", "by", 12], ["going", "to", 11], ["campus", "of", 11], ["hold", "at", 11], ["staff", "of", 11], ["Degree", "at", 11], ["offer", "from", 11], ["lecturing", "at", 11], ["by", "University", 11], ["completed", "at", 11], ["career", "at", 11], ["published", "by", 10], ["undertaking", "at", 10], ["doctorate", "at", 10], ["continued", "at", 10], ["courses", "at", 10], ["colleague", "at", 10], ["taught", "At", 10], ["taking", "at", 10], ["chair", "in", 10], ["lectureship", "at", 9], ["at", "Institute", 9], ["examinations", "of", 9], ["Serre", "University", 9], ["moved", "at", 9], ["graduate", "of", 9], ["promoted", "at", 9], ["Mathematics", "of", 9], ["met", "at", 9], ["fellow", "at", 9], ["Department", "in", 9], ["appointment", "to", 8], ["seminar", "at", 8], ["Assistant", "at", 8], ["course", "at",  ...

# %% [markdown]
# ## Verbs and their synctactic role

# %%
q = """
with tw1 as (
select pk_sentence,st_id, fk_mathshistory, sentence 
from mathshistory.coref_sentence cs
where sentence ~ 'University'
--limit 200
), tw2 as (
select h1.t_head_text h1_text, concat_ws(' ', h1.t_head_pos_,h1.t_dep_) h1_pos, 
			ct.t_head_text h_text, ct.t_head_pos_ h_pos, ct.t_text tx, concat_ws(' ', ct.t_index, ct.t_pos_, ct.t_dep_, ct.t_head_text, ct.t_head_i, 
			ct.t_head_text, ct.t_head_pos_),
ct1.t_text tx1 , concat_ws(' ', ct1.t_index, ct1.t_pos_, ct1.t_dep_, ct1.t_head_text, ct1.t_head_i) ,
ct2.t_text tx2, concat_ws(' ', ct2.t_index, ct2.t_pos_, ct2.t_dep_, ct2.t_head_text, ct2.t_head_i) ,
ct3.t_text tx3, concat_ws(' ', ct3.t_index, ct3.t_pos_, ct3.t_dep_, ct3.t_head_text, ct3.t_head_i) , 
ct4.t_text tx4, concat_ws(' ', ct4.t_index, ct4.t_pos_, ct4.t_dep_, ct4.t_head_text, ct4.t_head_i) ,
ct5.t_text tx5, concat_ws(' ', ct5.t_index, ct5.t_pos_, ct5.t_dep_, ct5.t_head_text, ct5.t_head_i)
from mathshistory.coref_token ct 
join tw1 on ct.fk_sentence = tw1.pk_sentence
join mathshistory.coref_token ct1 on ct1.fk_sentence = tw1.pk_sentence and ct1.t_head_i = ct.t_index 
--head 2nd level 
join mathshistory.coref_token h1 on h1.fk_sentence = tw1.pk_sentence and h1.t_index = ct.t_head_i 
join mathshistory.coref_token ct2 on ct2.fk_sentence = tw1.pk_sentence and ct2.t_index = ct1.t_index +1
left join mathshistory.coref_token ct3 on ct3.fk_sentence = tw1.pk_sentence 
		and ct3.t_index = ct2.t_index +1 and ct3.t_pos_ = 'PROPN'
left join mathshistory.coref_token ct4 on ct4.fk_sentence = tw1.pk_sentence 
		and ct4.t_index = ct3.t_index +1 and ct4.t_pos_ = 'PROPN'
left join mathshistory.coref_token ct5 on ct5.fk_sentence = tw1.pk_sentence 
		and ct5.t_index = ct4.t_index +1 and ct5.t_pos_ = 'PROPN'
where ct.t_text = 'University'
and ct1.t_dep_ ='prep'
and ct1.t_text in ('of')) --, 'at', 'in'
select h1_text, h1_pos, h_text, h_pos, tx, tx1, tx2,tx3,tx4, tx5, count(*) eff
from tw2
group by h1_text, h1_pos, h_text, h_pos, tx, tx1, tx2, tx3,tx3,tx4, tx5
order by eff desc;
"""

# %%
result = pgf.sql_explore(q, conn)
# print(f'Lines count: {len(result[0])}, errors count: {len(result[1])}, \nFirst lines: {result[0][:5]}')

# %%
univ = pd.DataFrame(result[0])
univ.columns=['h1_text', 'h1_pos', 'h_text', 'h_pos', 'tx', 'tx1', 'tx2','tx3','tx4', 'tx5', 'eff']
univ.head()
# Out:
#         h1_text     h1_pos   h_text h_pos          tx tx1         tx2   tx3  \
# 0       entered  VERB ROOT  entered  VERB  University  of      Berlin  None
# 1       studied  VERB prep       at   ADP  University  of      Berlin  None
# 2     professor  NOUN prep       at   ADP  University  of  California  None
# 3  matriculated  VERB prep       at   ADP  University  of   Edinburgh  None
# 4          went  VERB prep       to   ADP  University  of   Göttingen  None
#
#     tx4   tx5  eff
# 0  None  None   25
# 1  None  None   22
# 2  None  None   21
# 3  None  None   19
# 4  None  None   17

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(univ.sort_values(by='eff', ascending=False), classes="display",

     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     scrollY="400px", scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="93f43365-4852-4855-b005-b60cb6d23260" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>h1_text</th>
#       <th>h1_pos</th>
#       <th>h_text</th>
#       <th>h_pos</th>
#       <th>tx</th>
#       <th>tx1</th>
#       <th>tx2</th>
#       <th>tx3</th>
#       <th>tx4</th>
#       <th>tx5</th>
#       <th>eff</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>h1_text</th><th>h1_pos</th><th>h_text</th><th>h_pos</th><th>tx</th><th>tx1</th><th>tx2</th><th>tx3</th><th>tx4</th><th>tx5</th><th>eff</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "entered", "VERB ROOT", "entered", "VERB", "University", "of", "Berlin", "None", "None", "None", 25], [1, "studied", "VERB prep", "at", "ADP", "University", "of", "Berlin", "None", "None", "None", 22], [2, "professor", "NOUN prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 21], [3, "matriculated", "VERB prep", "at", "ADP", "University", "of", "Edinburgh", "None", "None", "None", 19], [4, "went", "VERB prep", "to", "ADP", "University", "of", "G\u00f6ttingen", "None", "None", "None", 17], [5, "at", "ADP pobj", "College", "PROPN", "University", "of", "London", "None", "None", "None", 16], [6, "part", "NOUN prep", "of", "ADP", "University", "of", "St", "Andrews", "None", "None", 16], [7, "professor", "NOUN prep", "at", "ADP", "University", "of", "Vienna", "None", "None", "None", 16], [8, "went", "VERB prep", "to", "ADP", "University", "of", "Chicago", "None", "None", "None", 15], [9, "spent", "VERB prep", "at", "ADP", "University", "of", "G\u00f6ttingen", "None", "None", "None", 15], [10, "Professor", "PROPN prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 14], [11, "professor", "NOUN prep", "at", "ADP", "University", "of", "Copenhagen", "None", "None", "None", 14], [12, "College", "PROPN prep", "of", "ADP", "University", "of", "London", "None", "None", "None", 14], [14, "appointed", "VERB prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 13], [13, "professor", "NOUN prep", "at", "ADP", "University", "of", "Prague", "None", "None", "None", 13], [15, "held", "VERB prep", "at", "ADP", "University", "of", "Dundee", "None", "None", "None", 13], [16, "spent", "VERB prep", "at", "ADP", "University", "of", "Berlin", "None", "None", "None", 12], [18, "entered", "VERB ROOT", "entered", "VERB", "University", "of", "Vienna", "None", "None", "None", 12], [17, "went", "VERB prep", "to", "ADP", "University", "of", "California", "None", "None", "None", 12], [19, "professor", "NOUN prep", "at", "ADP", "University", "of", "Berlin", "None", "None", "None", 12], [22, "studied", "VERB prep", "at", "ADP", "University", "of", "Edinburgh", "None", "None", "None", 11], [25, "awarded", "VERB agent", "by", "ADP", "University", "of", "Cambridge", "None", "None", "None", 11], [23, "spent", "VERB prep", "at", "ADP", "University", "of", "California", "None", "None", "None", 11], [21, "professor", "NOUN prep", "at", "ADP", "University", "of", "Paris", "None", "None", "None", 11], [20, "appointed", "VERB prep", "to", "ADP", "University", "of", "California", "None", "None", "None", 11], [24, "moved", "VERB prep", "to", "ADP", "University", "of", "California", "None", "None", "None", 11], [26, "professor", "NOUN prep", "at", "ADP", "University", "of", "Illinois", "None", "None", "None", 10], [27, "professor", "NOUN prep", "at", "ADP", "University", "of", "Amsterdam", "None", "None", "None", 10], [28, "professor", "NOUN prep", "at", "ADP", "University", "of", "Leiden", "None", "None", "None", 10], [29, "professor", "NOUN prep", "at", "ADP", "University", "of", "Chicago", "None", "None", "None", 10], [30, "part", "NOUN prep", "of", "ADP", "University", "of", "London", "None", "None", "None", 10], [31, "awarded", "VERB agent", "by", "ADP", "University", "of", "Berlin", "None", "None", "None", 10], [42, "studied", "VERB prep", "at", "ADP", "University", "of", "G\u00f6ttingen", "None", "None", "None", 9], [41, "professor", "NOUN prep", "at", "ADP", "University", "of", "Wisconsin", "None", "None", "None", 9], [40, "entered", "VERB ROOT", "entered", "VERB", "University", "of", "Edinburgh", "None", "None", "None", 9], [39, "studied", "VERB prep", "at", "ADP", "University", "of", "Vienna", "None", "None", "None", 9], [38, "professor", "NOUN prep", "at", "ADP", "University", "of", "Bologna", "None", "None", "None", 9], [37, "entered", "VERB ROOT", "entered", "VERB", "University", "of", "Leipzig", "None", "None", "None", 9], [36, "entered", "VERB ROOT", "entered", "VER ...
